# %% [markdown]
# # Data Processing

# %%
#!/usr/bin/env python3
import time
from multiprocessing import cpu_count
from typing import Union, NamedTuple

from torch.utils import data
from torch import Tensor
from typing import Tuple
import torch
import torch.backends.cudnn
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
import torchvision.datasets
from torch.optim.optimizer import Optimizer
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms
from torch.utils.data import Dataset

import argparse
from pathlib import Path

from PIL import Image
from torchvision import transforms

import matplotlib.pyplot as plt

torch.backends.cudnn.benchmark = True


def crop_to_region(coords: Tuple[int], img: Tensor, crop_size: int=42) -> Tensor:
    """ 
    Given coordinates in the form Tuple[int](y, x), return a cropped
    sample of the input imaged centred at (y, x), matching the input size.
    Args:
        coords (Tuple[int]): The input coordinates (y, x) where the crop will be
        centred.
        img (Tensor): The input image, either 3x400x400, 3x250x250, 3x150x150
        crop_size (int, optional): The size of the returned crop. Defaults to 42.

    Returns:
        Tensor: The image cropped with central coordinates at (y, x) of size 
        (3 x size x size) # is size here referring to 42?
    """
    _, H, W = img.shape
    y, x = coords
    y_min, x_min = max(0, y-crop_size//2), max(0, x-crop_size//2)
    y_max, x_max = min(H, y+crop_size//2), min(W, x+crop_size//2)
    region = img[:, y_min:y_max, x_min:x_max]
    if region.shape[1] < crop_size:
        to_pad = crop_size - region.shape[1]
        padding = (0, 0, to_pad, 0) if (y-crop_size//2) < 0 else (0, 0, 0, to_pad)
        region = F.pad(region, padding, mode='replicate')

    if region.shape[2] < crop_size:
        to_pad = crop_size - region.shape[2]
        padding = (to_pad, 0, 0, 0) if (x-crop_size//2) < 0 else (0, to_pad, 0, 0)
        region = F.pad(region, padding, mode='replicate')
    return region

class MIT(data.Dataset):
    def __init__(self, dataset_path: str):
        """
        Given the dataset path, create the MIT dataset. Creates the
        variable self.dataset which is a list of dictionaries with three keys:
            1) X: For train the crop of image. This is of shape [3, 3, 42, 42]. The 
                first dim represents the crop across each different scale
                (400x400, 250x250, 150x150), the second dim is the colour
                channels C, followed by H and W (42x42). For inference, this is 
                the full size image of shape [3, H, W].
            2) y: The label for the crop. 1 = a fixation point, 0 = a
                non-fixation point. -1 = Unlabelled i.e. val and test
            3) file: The file name the crops were extracted from.
            
        If the dataset belongs to val or test, there are 4 additional keys:
            1) X_400: The image resized to 400x400
            2) X_250: The image resized to 250x250
            3) X_150: The image resized to 150x150
            4) spatial_coords: The centre coordinates of all 50x50 (2500) crops
            
        These additional keys help to load the different scales within the
        dataloader itself in a timely manner. Precomputing all crops requires too
        much storage for the lab machines, and resizing/cropping on the fly
        slows down the dataloader, so this is a happy balance.
        Args:
            dataset_path (str): Path to train/val/test.pth.tar
        """
        self.dataset = torch.load(dataset_path, weights_only=True)
        self.mode = 'train' if 'train' in dataset_path else 'inference'
        self.num_crops = 2500 if self.mode == 'inference' else 1

    def __getitem__(self, index) -> Tuple[Tensor, int]:
        """
        Given the index from the DataLoader, return the image crop(s) and label
        Args:
            index (int): the dataset index provided by the PyTorch DataLoader.
        Returns:
            Tuple[Tensor, int]: A two-element tuple consisting of: 
                1) img (Tensor): The image crop of shape [3, 3, 42, 42]. The 
                first dim represents the crop across each different scale
                (400x400, 250x250, 150x150), the second dim is the colour
                channels C, followed by H and W (42x42).
                2) label (int): The label for this crop. 1 = a fixation point, 
                0 = a non-fixation point. -1 = Unlabelled i.e. val and test.
        """
        sample_index = index // self.num_crops
        # print(sample_index)
        
        img = self.dataset[sample_index]['X']
        
        # Inference crops are not precomputed due to file size, do here instead
        if self.mode == 'inference': 
            _, H, W = img.shape
            crop_index = index % self.num_crops
            crop_y, crop_x = self.dataset[sample_index]['spatial_coords'][crop_index]
            scales = []
            for size in ['X_400', 'X_250', 'X_150']:
                scaled_img = self.dataset[sample_index][size]
                y_ratio, x_ratio = scaled_img.shape[1] / H, scaled_img.shape[2] / W
                
                # Need to rescale the crops central coordinate.
                scaled_coords = (int(y_ratio * crop_y), int(x_ratio * crop_x))
                crops = crop_to_region(scaled_coords, scaled_img)
                scales.append(crops)
            img = torch.stack(scales, axis=1)
            
        label = self.dataset[sample_index]['y']

        return img, label

    def __len__(self):
        """
        Returns the length of the dataset (length of the list of dictionaries * number
        of crops). 
        __len()__ always needs to be defined so that the DataLoader
            can create the batches
        Returns:
            len(self.dataset) (int): the length of the list of dictionaries * number of
            crops.
        """
        return len(self.dataset) * self.num_crops


trainingdata = MIT("data/train_data.pth.tar")
valdata = MIT("data/val_data.pth.tar")
testingdata = MIT("data/test_data.pth.tar")


class NormalisedDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


# each element in self.dataset dictionary which has three components so just get X and y component (so X component 3x3x42x42 and y is label) -> inputs to the CNN


# print(trainingdata.dataset[0]['y'])
# print(trainingdata.dataset[0]['X'])

# %% [markdown]
# # Data Augmentation

# %%
import numpy as np
import statistics

training_data_augmented = trainingdata.dataset * 2
for i in range(len(trainingdata.dataset), len(training_data_augmented)):
    training_data_augmented[i]['X'] = torch.flip(training_data_augmented[i]['X'], dims=[3])
    
print('done')

red_channel = ([sample['X'][:, 0, :, :] for sample in training_data_augmented])
blue_channel = ([sample['X'][:, 1, :, :] for sample in training_data_augmented])
green_channel = ([sample['X'][:, 2, :, :] for sample in training_data_augmented])

normalised_training_data = training_data_augmented

# red channel is a list of 3x42x42 i.e each resolution 42x42 image only the red channel, likewise with the blue and green channel
# so want the mean of the red channels, blue and green channel

def channel_mean(x):
    return (torch.stack(x).mean().item())

def channel_std(x):
    return (torch.stack(x).std().item())

# def channel_mean(x):
#     channel_sum = 0 # sum is 0 to begin with
#     for i in range(0, len(x)): # go through each item in the list
#         item = x[i] # extract 3x42x42 list
#         for j in range(0, 3): # find the sum of each element of the 3x42x42 list and increment to the running sum
#             for k in range(0, 42):
#                 for l in range(0,42):
#                     channel_sum += item[j][k][l].item()
                    
#     return (channel_sum / (len(x)*3*42*42)) # mean of x i.e. total of all values / number of values 

red_mean = channel_mean(red_channel)
blue_mean = channel_mean(blue_channel)
green_mean = channel_mean(green_channel)

red_std = channel_std(red_channel)
blue_std = channel_std(blue_channel)
green_std = channel_std(green_channel)

print(red_mean, blue_mean, green_mean, red_std, blue_std, green_std)

for i in range(0, len(normalised_training_data)): # goes through the current list
    training_data_X = normalised_training_data[i]['X'] # gets the 3x3x42x42 X
    training_data_X[:,0,:,:] = (training_data_X[:,0,:,:] - red_mean) / red_std # gets red channel values and normalises them
    training_data_X[:, 1, :,:] = (training_data_X[:,1,:,:] - blue_mean) / blue_std
    training_data_X[:, 2, :,:] = (training_data_X[:,2,:,:] - green_mean) / green_std
    
    normalised_training_data[i]['X'] = training_data_X
    #print('in loop')

final_data = trainingdata
final_data.dataset = normalised_training_data

print('hello')
# Out:
# done
# 0.01992413029074669 -0.003527479013428092 -0.011873003095388412 0.9579979777336121 0.948402464389801 0.9503791928291321
# hello

# %%
k = 0

# %%
k += 1

# %%
# visualise training data for sanity check

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

X = trainingdata.dataset[k]['X'][1].permute(1, 2, 0).numpy() * 255
y = trainingdata.dataset[k]['y']

print(y)

axes[0].imshow(X)
axes[0].set_title('X')
axes[0].axis('off')  # Turn off axis ticks

# axes[0].imshow(y)
# axes[0].set_title('y')
# axes[0].axis('off')  # Turn off axis ticks
plt.show()

# %% [markdown]
# # Format Files and Generate Ground Truth

# %%
# this code generates the ground truth dictionary for inference datasets indexed by file name (formatted so they end with _fixMap.jpg)
# ensure the predictions dictionary matches this format for file name

def format_file_name_fixMap_jpg(filename):
    return f"{filename[:-5]}_fixMap.jpg"

def get_filenames_fixMap_jpg(dataset: Dataset):
    filenames = [format_file_name_fixMap_jpg(sample['file']) for sample in dataset]

    return filenames

def get_ground_truth_dict(dataset: Dataset):

    filenames = get_filenames_fixMap_jpg(dataset)

    ground_truth_dict = {}
    transform = transforms.ToTensor()

    for filename in filenames:
        ground_truth_dict[filename] = transform(Image.open(f"data/ALLFIXATIONMAPS/ALLFIXATIONMAPS/{filename}")).squeeze() * 255
    
    return ground_truth_dict

# to show usage
# print(list(get_ground_truth_dict(get_filenames_fixMap_jpg(valdata.dataset)).values())[7].shape)

val_ground_truth_dict = get_ground_truth_dict(valdata.dataset)
test_ground_truth_dict = get_ground_truth_dict(testingdata.dataset)

print(list(get_ground_truth_dict(valdata.dataset).values())[0].shape)
print(valdata.dataset[0]['X'].shape)
# Out:
# torch.Size([768, 1024])
# torch.Size([3, 768, 1024])

# %% [markdown]
# # Define ROC-AUC Evaluation

# %%
# metrics code


import numpy as np
from scipy.integrate import simpson


def roc_auc(pred, target, n_points=20, include_prior=False):
        """
        Calculates the Reciever-Operating-Characteristic (ROC) area under
        the curve (AUC) by numerical integration.
        """

        target = np.array(target)/255
                
        # generated = pred
        # changed above comment line to below one as above was throwing error
        generated = np.array(pred)
        # min max normalisation
        generated = (generated - generated.min())/(generated.max() - generated.min())

        def roc(p=0.1):
            x = generated.reshape(-1) > p
            t = target.reshape(-1) > p

            return np.sum(x==t)/len(t)

        calculate_roc = np.vectorize(roc)

        x = np.linspace(0, 1, n_points)
        auc = simpson(calculate_roc(x))/n_points

        return auc

def calculate_auc(preds, targets):
	"""
	inputs -- 2 dictionary with prediction and target images. The 2 dictionaries have the  same number of keys, where each key identifies a unique image. 
	The predictions have the predicted fixation maps while the targets have the ground truth fixation maps which are available from "https://people.csail.mit.edu/tjudd/WherePeopleLook/" 
	"""
	assert preds.keys() == targets.keys()
	mean_auc = 0
	for key in preds.keys():
		mean_auc += roc_auc(preds[key], targets[key])
	mean_auc /= len(preds.keys())
	return mean_auc

# %% [markdown]
# # Model checkpointing

# %%
val_model_path = "./model/val/model.pth"
val_auc_path = "./model/val/auc_score"
test_model_path = "./model/test/model.pth"
test_auc_path = "./model/test/auc_score"

all_models_path = "./data/models/"

def checkpoint_model(model, auc, is_test):
    model_path = ""
    auc_path = ""

    if is_test:
        model_path = test_model_path
        auc_path = test_auc_path

        if auc > 0.65:
            torch.save(model, f"{all_models_path}model_test_{str(auc)[:5]}.pth")
    else:
        model_path = val_model_path
        auc_path = val_auc_path

        if auc > 0.65:
            torch.save(model, f"{all_models_path}model_val_{str(auc)[:5]}.pth")

    # scoreboard type checkpointing
    path = Path(auc_path)  # Path to the file you want to check

    if path.exists():
        with open(auc_path, 'r+', encoding='utf-8') as file:
            
            old_auc = float(file.read().strip())

            if auc > old_auc:
                torch.save(model, model_path)
                
                file.truncate(0)
                file.seek(0)
                file.write(str(auc))
    else:
        torch.save(model, model_path)
    
        with open(auc_path, 'w', encoding='utf-8') as file:
            file.write(str(auc))

# %% [markdown]
# # Initialise and Train Mr-CNN
#
# ### To see logs:
# module load anaconda \
# pip install tensorboard \
# python3 -m tensorboard.main --logdir=./logs \

# %%
from torchviz import make_dot

parser = argparse.ArgumentParser(
    description="Train a simple CNN on CIFAR-10",
    formatter_class=argparse.ArgumentDefaultsHelpFormatter,
)
default_dataset_dir = Path.home() / ".cache" / "torch" / "datasets"
parser.add_argument("--dataset-root", default=default_dataset_dir)
parser.add_argument("--log-dir", default=Path("logs"), type=Path)
parser.add_argument("--learning-rate", default=2e-4, type=float, help="Learning rate")
parser.add_argument(
    "--batch-size",
    default=256,
    type=int,
    help="Number of images within each mini-batch",
)
parser.add_argument(
    "--epochs",
    default=70,
    type=int,
    help="Number of epochs (passes through the entire dataset) to train for",
)
parser.add_argument(
    "--val-frequency",
    default=2,
    type=int,
    help="How frequently to test the model on the validation set in number of epochs",
)
parser.add_argument(
    "--log-frequency",
    default=10,
    type=int,
    help="How frequently to save logs to tensorboard in number of steps",
)
parser.add_argument(
    "--print-frequency",
    default=10,
    type=int,
    help="How frequently to print progress to the command line in number of steps",
)
parser.add_argument(
    "-j",
    "--worker-count",
    default=0, #cpu_count(), #note make this 0 if not using lab machine
    type=int,
    help="Number of worker processes used to load data.",
)
parser.add_argument("--sgd-momentum", default=0.9, type=float)
parser.add_argument("--data-aug-hflip", action="store_true")
parser.add_argument("--dropout", default=0.25, type=float)
parser.add_argument("--max_norm", default=0.1, type=float)



class ImageShape(NamedTuple):
    height: int
    width: int
    channels: int


if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
else:
    DEVICE = torch.device("cpu")

# to save and manually evaluate trained model
trained_model = 0
test_auc_score = 0

def main(args):

    for i in range(200):

        train_loader = torch.utils.data.DataLoader(
            final_data,
            shuffle=True,
            batch_size=args.batch_size,
            pin_memory=True,
            num_workers=args.worker_count,
        )
        
        print(args)
        
        args.dataset_root.mkdir(parents=True, exist_ok=True)
        
        test_dataset = testingdata.dataset
        
        
        test_loader = torch.utils.data.DataLoader(
            test_dataset,
            shuffle=False,
            batch_size=args.batch_size,
            num_workers=args.worker_count,
            pin_memory=True,
        )

        model = CNN(height=42, width=42, channels=3, class_count=2, dropout=args.dropout)

        # for torchviz visualisation of architecture
        # dummy_input = torch.randn(1, 3, 3, 42, 42)

        # output = model(dummy_input)

        # graph = make_dot(output, params=dict(model.named_parameters()))

        # # Save or render the graph
        # graph.render("cnn_graph_merged", format="png")  # Save as PNG

        # define criterion as Binary Cross Entropy Loss - it does sigmoid as built in
        criterion = nn.BCEWithLogitsLoss()

        # define optimizer
        optimizer = torch.optim.SGD(model.parameters(), lr=args.learning_rate, momentum=args.sgd_momentum, weight_decay=2e-4)

        log_dir = get_summary_writer_log_dir(args)
        print(f"Writing logs to {log_dir}")
        summary_writer = SummaryWriter(
                str(log_dir),
                flush_secs=5
        )
        trainer = Trainer(
            model, train_loader, test_loader, criterion, optimizer, summary_writer, DEVICE
        )

        print("About to train...")
        trainer.train(
            args.epochs,
            args.val_frequency,
            print_frequency=args.print_frequency,
            log_frequency=args.log_frequency,
        )
        print("Finished training.")
        summary_writer.close()

        print("\nTESTING MODEL")
        test_auc = test_model(model, testingdata, test_ground_truth_dict, DEVICE)
        print("AUC:", test_auc, "on test dataset\n")

        # save model locally in notebook for manual evaluation
        checkpoint_model(model, float(test_auc), True)



class Trainer:
    def __init__(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        val_loader: DataLoader,
        criterion: nn.Module,
        optimizer: Optimizer,
        summary_writer: SummaryWriter,
        device: torch.device,
    ):
        self.model = model.to(device)
        self.device = device
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.criterion = criterion
        self.optimizer = optimizer
        self.summary_writer = summary_writer
        self.step = 0


            
    def train(
        self,
        epochs: int,
        val_frequency: int,
        print_frequency: int = 20,
        log_frequency: int = 5,
        start_epoch: int = 0
    ):
        self.model.train()
        
        for epoch in range(start_epoch, epochs):

            self.model.train()
            
            data_load_start_time = time.time()

            epoch_accuracy = 0
            epoch_loss = 0

            for batch, labels in self.train_loader:
                
                batch = batch.to(self.device)
                labels = labels.to(self.device)
                data_load_end_time = time.time()

                # forward pass
                logits = self.model.forward(batch).squeeze()

                # compute loss using criterion
                loss = self.criterion(logits, labels.float())

                # backward pass
                loss.backward()

                # step optimizer and zero out gradient buffer
                self.optimizer.step()
                self.optimizer.zero_grad()


                
                with torch.no_grad():
                    preds = (logits > 0.5).float()
                    accuracy = compute_accuracy(labels, preds)

                data_load_time = data_load_end_time - data_load_start_time
                step_time = time.time() - data_load_end_time
                if ((self.step + 1) % log_frequency) == 0:
                    self.log_metrics(epoch, accuracy, loss, data_load_time, step_time)
                if ((self.step + 1) % print_frequency) == 0:
                    self.print_metrics(epoch, accuracy, loss, data_load_time, step_time)

                self.step += 1
                data_load_start_time = time.time()

                epoch_accuracy += accuracy
                epoch_loss += loss

            #update the momentum in the optimizer so that it linearly increases from 0.9 to 0.99
            update_momentum(self.model, self.optimizer, epoch, epochs, start_momentum=0.9, end_momentum=0.99)

            # apply weight constraints to limit the magnitude of all weights (should we apply per batch or per epoch?)
            apply_max_norm(self.model, 0.1)

            # log epoch accuracy and epoch loss
            epoch_accuracy /= self.train_loader.batch_size
            epoch_loss /= self.train_loader.batch_size
            self.summary_writer.add_scalar("epoch_accuracy", epoch_accuracy, self.step)
            self.summary_writer.add_scalar("epoch_loss", epoch_loss, self.step)

            self.summary_writer.add_scalar("epoch", epoch, self.step)
            if epoch > 23:
                if ((epoch + 1) % val_frequency) == 0:
                    val_auc = self.validate()
                    checkpoint_model(self.model, float(val_auc), False)
                    # log val auc
                    self.summary_writer.add_scalar("val_auc", val_auc, self.step)
                    # self.validate() will put the model in validation mode,
                    # so we have to switch back to train mode afterwards
                    self.model.train()
            else:
                if ((epoch + 1) % 5) == 0:
                    val_auc = self.validate()
                    checkpoint_model(self.model, float(val_auc), False)
                    # log val auc
                    self.summary_writer.add_scalar("val_auc", val_auc, self.step)
                    # self.validate() will put the model in validation mode,
                    # so we have to switch back to train mode afterwards
                    self.model.train()


    
    def print_metrics(self, epoch, accuracy, loss, data_load_time, step_time):
        epoch_step = self.step % len(self.train_loader)
        print(
                f"epoch: [{epoch}], "
                f"step: [{epoch_step}/{len(self.train_loader)}], "
                f"batch loss: {loss:.5f}, "
                f"batch accuracy: {accuracy * 100:2.2f}, "
                f"data load time: "
                f"{data_load_time:.5f}, "
                f"step time: {step_time:.5f}"
        )

    def log_metrics(self, epoch, accuracy, loss, data_load_time, step_time):
        self.summary_writer.add_scalar("epoch", epoch, self.step)
        self.summary_writer.add_scalars(
                "accuracy",
                {"train": accuracy},
                self.step
        )
        self.summary_writer.add_scalars(
                "loss",
                {"train": float(loss.item())},
                self.step
        )
        self.summary_writer.add_scalar(
                "time/data", data_load_time, self.step
        )
        self.summary_writer.add_scalar(
                "time/data", step_time, self.step
        )

    def validate(self):

        print("\nValidating model...")

        auc = test_model(self.model, valdata, val_ground_truth_dict, self.device)

        print("AUC:", auc, "on validation dataset\n")

        return auc

def update_momentum(self, optimizer, epoch, max_epochs, start_momentum=0.9, end_momentum=0.99):
    momentum = start_momentum + (end_momentum - start_momentum) * (epoch / max_epochs)
    for param_group in optimizer.param_groups:
        param_group['momentum'] = momentum

# Apply weight constraints
def apply_max_norm(model, max_norm):
    with torch.no_grad():
        for param in model.parameters():
            if param.requires_grad:
                param.clamp_(-max_norm, max_norm)

def test_model(model, dataMIT, ground_truth_dict, device):
    
    model.eval()

    dataset_size = len(dataMIT.dataset)

    batch_size = 50
    num_batches = int(2500 / batch_size)

    preds_dict = {}

    sigmoid = nn.Sigmoid()

    for i in range (dataset_size):

        # potential bug: getting height and width mixed up, so if results look bad, make sure to check this is right

        formatted_filename = format_file_name_fixMap_jpg(dataMIT.dataset[i]['file'])
        height = dataMIT.dataset[i]['X'].shape[1]
        width = dataMIT.dataset[i]['X'].shape[2]

        rescale_to_img = transforms.Resize((height, width))

        img_crops = torch.stack([dataMIT.__getitem__(i * 2500 + j)[0] for j in range(2500)])

        preds_rows = []

        for j in range(num_batches):
            
            batch = img_crops[j * batch_size:(j * batch_size) + batch_size,:,:,:,:]

            batch = batch.to(device)

            preds = sigmoid(model(batch).detach().cpu().reshape(1, 50))
            # preds = (preds > 0.5).float()
            preds_rows.append(preds)


        sal_map = torch.cat(preds_rows, 0)

        sal_map = rescale_to_img(sal_map.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)    # unsqueezing and squeezing done because transforms.Resize requires (., ., H, W) shape tensor
        sal_map = rescale_to_img(sal_map) * 255


        preds_dict[formatted_filename] = sal_map

    auc = calculate_auc(preds_dict, ground_truth_dict)

    return auc


def compute_accuracy(
    labels: Union[torch.Tensor, np.ndarray], preds: Union[torch.Tensor, np.ndarray]
) -> float:
    """
    Args:
        labels: ``(batch_size, class_count)`` tensor or array containing example labels
        preds: ``(batch_size, class_count)`` tensor or array containing model prediction
    """
    assert len(labels) == len(preds)
    return float((labels == preds).sum()) / len(labels)


def get_summary_writer_log_dir(args: argparse.Namespace) -> str:
    """Get a unique directory that hasn't been logged to before for use with a TB
    SummaryWriter.

    Args:
        args: CLI Arguments

    Returns:
        Subdirectory of log_dir with unique subdirectory name to prevent multiple runs
        from getting logged to the same TB log directory (which you can't easily
        untangle in TB).
    """
    tb_log_dir_prefix = (
    f"CNN_bn_"
    f"bs={args.batch_size}_"
    f"lr={args.learning_rate}_"
    f"momentum=0.9_" +
    ("hflip_" if args.data_aug_hflip else "") +
    f"run_"
)
    i = 0
    while i < 1000:
        tb_log_dir = args.log_dir / (tb_log_dir_prefix + str(i))
        if not tb_log_dir.exists():
            return str(tb_log_dir)
        i += 1
    return str(tb_log_dir)


if __name__ == "__main__":
    args, _ = parser.parse_known_args()
    main(args)
# Out:
# Namespace(dataset_root=PosixPath('/home/qz21635/.cache/torch/datasets'), log_dir=PosixPath('logs'), learning_rate=0.0002, batch_size=256, epochs=70, val_frequency=2, log_frequency=10, print_frequency=10, worker_count=0, sgd_momentum=0.9, data_aug_hflip=False, dropout=0.25, max_norm=0.1)
# Writing logs to logs/CNN_bn_bs=256_lr=0.0002_momentum=0.9_run_0
# About to train...
# epoch: [0], step: [9/189], batch loss: 0.88150, batch accuracy: 57.42, data load time: 0.00327, step time: 0.13564
# epoch: [0], step: [19/189], batch loss: 0.69836, batch accuracy: 66.41, data load time: 0.00327, step time: 0.13476
# epoch: [0], step: [29/189], batch loss: 0.74572, batch accuracy: 65.23, data load time: 0.00334, step time: 0.13662
# epoch: [0], step: [39/189], batch loss: 0.71925, batch accuracy: 72.66, data load time: 0.00345, step time: 0.13476
# epoch: [0], step: [49/189], batch loss: 0.72095, batch accuracy: 67.19, data load time: 0.00344, step time: 0.13697
# epoch: [0], step: [59/189], batch loss: 0.72385, batch accuracy: 67.58, data load time: 0.00348, step time: 0.13486
# epoch: [0], step: [69/189], batch loss: 0.77853, batch accuracy: 64.45, data load time: 0.00355, step time: 0.13619
# epoch: [0], step: [79/189], batch loss: 0.70833, batch accuracy: 69.14, data load time: 0.00362, step time: 0.13840
# epoch: [0], step: [89/189], batch loss: 0.66309, batch accuracy: 68.36, data load time: 0.00348, step time: 0.13563
# epoch: [0], step: [99/189], batch loss: 0.71388, batch accuracy: 65.62, data load time: 0.00340, step time: 0.13433
# epoch: [0], step: [109/189], batch loss: 0.70887, batch accuracy: 69.14, data load time: 0.00336, step time: 0.13697
# epoch: [0], step: [119/189], batch loss: 0.64660, batch accuracy: 73.05, data load time: 0.00357, step time: 0.13452
# epoch: [0], step: [129/189], batch loss: 0.72411, batch accuracy: 66.41, data load time: 0.00350, step time: 0.13596
# epoch: [0], step: [139/189], batch loss: 0.63139, batch accuracy: 69.92, data load time: 0.00558, step time: 0.13426
# epoch: [0], step: [149/189], batch loss: 0.62455, batch accuracy: 71.48, data load time: 0.00344, step time: 0.14142
# epoch: [0], step: [159/189], batch loss: 0.62144, batch accuracy: 71.48, data load time: 0.00343, step time: 0.14422
# epoch: [0], step: [169/189], batch loss: 0.68800, batch accuracy: 69.14, data load time: 0.00354, step time: 0.14331
# epoch: [0], step: [179/189], batch loss: 0.76428, batch accuracy: 67.58, data load time: 0.00347, step time: 0.14365
# epoch: [1], step: [0/189], batch loss: 0.65371, batch accuracy: 65.23, data load time: 0.04351, step time: 0.13254
# epoch: [1], step: [10/189], batch loss: 0.65892, batch accuracy: 64.84, data load time: 0.00447, step time: 0.13442
# epoch: [1], step: [20/189], batch loss: 0.65282, batch accuracy: 64.84, data load time: 0.00401, step time: 0.13542
# epoch: [1], step: [30/189], batch loss: 0.65585, batch accuracy: 63.28, data load time: 0.00431, step time: 0.13779
# epoch: [1], step: [40/189], batch loss: 0.63963, batch accuracy: 68.36, data load time: 0.00556, step time: 0.12387
# epoch: [1], step: [50/189], batch loss: 0.64332, batch accuracy: 66.80, data load time: 0.00522, step time: 0.12393
# epoch: [1], step: [60/189], batch loss: 0.64163, batch accuracy: 69.92, data load time: 0.00553, step time: 0.12937
# epoch: [1], step: [70/189], batch loss: 0.64186, batch accuracy: 66.02, data load time: 0.00570, step time: 0.12933
# epoch: [1], step: [80/189], batch loss: 0.64954, batch accuracy: 71.09, data load time: 0.00579, step time: 0.13359
# epoch: [1], step: [90/189], batch loss: 0.64339, batch accuracy: 63.28, data load time: 0.00528, step time: 0.12981
# epoch: [1], step: [100/189], batch loss: 0.63828, batch accuracy: 64.06, data load time: 0.00520, step time: 0.12981
# epoch: [1], step: [110/189], batch loss: 0.62387, batch accuracy: 73.83, data load time: 0.00524, step time: 0.13066
# epoch: [1], step: [120/189], batch loss: 0.64718, batch accuracy: 61.72, data load time: 0.00540, step time: 0.13377
# epoch: [1], step: [130/189], batch loss: 0.63310, batch accuracy: 67.19, data load time: 0.00524, step time: 0.12953
# epoch: [1], step: [140/189], batch loss: 0.63432, batch accuracy: 66.02, data load time: 0.00521, step time: 0.12973
# epoch: [1], step: [150/189], batch loss: 0.63321, batch accuracy: 66.02, data load time: 0.00531, step time: 0.13067
# epoch: [1], step: [160/189], batch loss: 0.63795, batch accuracy: 65.62, data load time: 0.00524, step time: 0.12942
# epoch: [1], step: [170/189], batch loss: 0.62956, batch accuracy: 66.41, data load time: 0.00547, step time: 0.13369
# epoch: [1], step: [180/189], batch loss: 0.62079, batch accuracy: 67.58, data load time: 0.00483, step time: 0.13147
# epoch: [2], step: [1/189], batch loss: 0.63398, batch accuracy: 66.41, data load time: 0.00402, step time: 0.12489
# epoch: [2], step: [11/189], batch loss: 0.62710, batch accuracy: 67.58, data load time: 0.00385, step time: 0.12544
# epoch: [2], step: [21/189], batch loss: 0.62375, batch accuracy: 66.02, data load time: 0.00376, step time: 0.12511
# epoch: [2], step: [31/189], batch loss: 0.61977, batch accuracy: 66.80, data load time: 0.00393, step time: 0.12480
# epoch: [2], step: [41/189], batch loss: 0.61707, batch accuracy: 69.14, data load time: 0.00545, step time: 0.12484
# epoch: [2], step: [51/189], batch loss: 0.62593, batch accuracy: 64.84, data load time: 0.00555, step time: 0.12533
# epoch: [2], step: [61/189], batch loss: 0.60477, batch accuracy: 71.48, data load time: 0.00524, step time: 0.12478
# epoch: [2], step: [71/189], batch loss: 0.61679, batch accuracy: 64.84, data load time: 0.00506, step time: 0.12695
# epoch: [2], step: [81/189], batch loss: 0.62218, batch accuracy: 64.45, data load time: 0.00513, step time: 0.12415
# epoch: [2], step: [91/189], batch loss: 0.62638, batch accuracy: 66.02, data load time: 0.00501, step time: 0.12471
# epoch: [2], step: [101/189], batch loss: 0.61565, batch accuracy: 67.19, data load time: 0.00503, step time: 0.12537
# epoch: [2], step: [111/189], batch loss: 0.61027, batch accuracy: 70.31, data load time: 0.00495, step time: 0.12546
# epoch: [2], step: [121/189], batch loss: 0.61768, batch accuracy: 64.45, data load time: 0.00500, step time: 0.12506
# epoch: [2], step: [131/189], batch loss: 0.59800, batch accuracy: 69.14, data load time: 0.00507, step time: 0.12620
# epoch: [2], step: [141/189], batch loss: 0.62584, batch accuracy: 60.94, data load time: 0.00509, step time: 0.12494
# epoch: [2], step: [151/189], batch loss: 0.59059, batch accuracy: 72.27, data load time: 0.00509, step time: 0.12547
# epoch: [2], step: [161/189], batch loss: 0.60382, batch accuracy: 71.88, data load time: 0.00511, step time: 0.12471
# epoch: [2], step: [171/189], batch loss: 0.60274, batch accuracy: 65.62, data load time: 0.00511, step time: 0.12583
# epoch: [2], step: [181/189], batch loss: 0.61162, batch accuracy: 69.14, data load time: 0.00513, step time: 0.12596
# epoch: [3], step: [2/189], batch loss: 0.61530, batch accuracy: 64.06, data load time: 0.00405, step time: 0.13524
# epoch: [3], step: [12/189], batch loss: 0.63203, batch accuracy: 62.89, data load time: 0.00375, step time: 0.12660
# epoch: [3], step: [22/189], batch loss: 0.60101, batch accuracy: 69.92, data load time: 0.00388, step time: 0.12584
# epoch: [3], step: [32/189], batch loss: 0.62610, batch accuracy: 67.19, data load time: 0.00385, step time: 0.12624
# epoch: [3], step: [42/189], batch loss: 0.60842, batch accuracy: 68.75, data load time: 0.00377, step time: 0.12579
# epoch: [3], step: [52/189], batch loss: 0.61325, batch accuracy: 64.84, data load time: 0.00548, step time: 0.12608
# epoch: [3], step: [62/189], batch loss: 0.60878, batch accuracy: 67.97, data load time: 0.00532, step time: 0.12519
# epoch: [3], step: [72/189], batch loss: 0.61692, batch accuracy: 64.84, data load time: 0.00505, step time: 0.12599
# epoch: [3], step: [82/189], batch loss: 0.59627, batch accuracy: 65.23, data load time: 0.00519, step time: 0.12579
# epoch: [3], step: [92/189], batch loss: 0.61657, batch accuracy: 61.72, data load time: 0.00513, step time: 0.12597
# epoch: [3], step: [102/189], batch loss: 0.58376, batch accuracy: 72.27, data load time: 0.00511, step time: 0.12559
# epoch: [3], step: [112/189], batch loss: 0.60352, batch accuracy: 64.84, data load time: 0.00501, step time: 0.12684
# epoch: [3], step: [122/189], batch loss: 0.59716, batch accuracy: 67.97, data load time: 0.00515, step time: 0.12560
# epoch: [3], step: [132/189], batch loss: 0.60027, batch accuracy: 67.58, data load time: 0.00501, step time: 0.12517
# epoch: [3], step: [142/189], batch loss: 0.60224, batch accuracy: 66.41, data load time: 0.00495, step time: 0.12652
# epoch: [3], step: [152/189], batch loss: 0.60538, batch accuracy: 67.19, data load time: 0.00511, step time: 0.12499
# epoch: [3], step: [162/189], batch loss: 0.59067, batch accuracy: 67.19, data load time: 0.00513, step time: 0.12523
# epoch: [3], step: [172/189], batch loss: 0.60428, batch accuracy: 62.50, data load time: 0.00515, step time: 0.12553
# epoch: [3], step: [182/189], batch loss: 0.58945, batch accuracy: 66.80, data load time: 0.00496, step time: 0.12623
# epoch: [4], step: [3/189], batch loss: 0.59955, batch accuracy: 69.92, data load time: 0.00314, step time: 0.13085
# epoch: [4], step: [13/189], batch loss: 0.59922, batch accuracy: 64.06, data load time: 0.00395, step time: 0.12525
# epoch: [4], step: [23/189], batch loss: 0.58640, batch accuracy: 70.70, data load time: 0.00382, step time: 0.12542
# epoch: [4], step: [33/189], batch loss: 0.60421, batch accuracy: 64.45, data load time: 0.00387, step time: 0.12568
# epoch: [4], step: [43/189], batch loss: 0.59205, batch accuracy: 62.50, data load time: 0.00295, step time: 0.12620
# epoch: [4], step: [53/189], batch loss: 0.59155, batch accuracy: 66.41, data load time: 0.00536, step time: 0.12641
# epoch: [4], step: [63/189], batch loss: 0.60015, batch accuracy: 65.23, data load time: 0.00534, step time: 0.12573
# epoch: [4], step: [73/189], batch loss: 0.58546, batch accuracy: 66.02, data load time: 0.00505, step time: 0.12599
# epoch: [4], step: [83/189], batch loss: 0.60474, batch accuracy: 64.45, data load time: 0.00517, step time: 0.12719
# epoch: [4], step: [93/189], batch loss: 0.57772, batch accuracy: 69.53, data load time: 0.00513, step time: 0.12560
# epoch: [4], step: [103/189], batch loss: 0.57524, batch accuracy: 70.31, data load time: 0.00496, step time: 0.12674
# epoch: [4], step: [113/189], batch loss: 0.58347, batch accuracy: 71.09, data load time: 0.00503, step time: 0.12607
# epoch: [4], step: [123/189], batch loss: 0.60658, batch accuracy: 64.84, data load time: 0.00500, step time: 0.12559
# epoch: [4], step: [133/189], batch loss: 0.58821, batch accuracy: 64.06, data load time: 0.00515, step time: 0.12551
# epoch: [4], step: [143/189], batch loss: 0.58467, batch accuracy: 68.75, data load time: 0.00496, step time: 0.12528
# epoch: [4], step: [153/189], batch loss: 0.58042, batch accuracy: 67.19, data load time: 0.00519, step time: 0.12600
# epoch: [4], step: [163/189], batch loss: 0.58765, batch accuracy: 67.19, data load time: 0.00503, step time: 0.12601
# epoch: [4], step: [173/189], batch loss: 0.58043, batch accuracy: 64.45, data load time: 0.00492, step time: 0.12630
# epoch: [4], step: [183/189], batch loss: 0.57409, batch accuracy: 68.36, data load time: 0.00554, step time: 0.12616
#
# Validating model...
# AUC: 0.6970435438546523 on validation dataset
#
# epoch: [5], step: [4/189], batch loss: 0.58534, batch accuracy: 69.14, data load time: 0.00313, step time: 0.13088
# epoch: [5], step: [14/189], batch loss: 0.57609, batch accuracy: 67.19, data load time: 0.00316, step time: 0.12473
# epoch: [5], step: [24/189], batch loss: 0.60342, batch accuracy: 61.72, data load time: 0.00318, step time: 0.12508
# epoch: [5], step: [34/189], batch loss: 0.58063, batch accuracy: 67.19, data load time: 0.00315, step time: 0.12500
# epoch: [5], step: [44/189], batch loss: 0.58960, batch accuracy: 63.67, data load time: 0.00312, step time: 0.12523
# epoch: [5], step: [54/189], batch loss: 0.59539, batch accuracy: 66.41, data load time: 0.00316, step time: 0.12560
# epoch: [5], step: [64/189], batch loss: 0.58280, batch accuracy: 69.92, data load time: 0.00296, step time: 0.12573
# epoch: [5], step: [74/189], batch loss: 0.59635, batch accuracy: 64.06, data load time: 0.00310, step time: 0.12492
# epoch: [5], step: [84/189], batch loss: 0.56657, batch accuracy: 66.02, data load time: 0.00314, step time: 0.12505
# epoch: [5], step: [94/189], batch loss: 0.59257, batch accuracy: 64.45, data load time: 0.00315, step time: 0.12558
# epoch: [5], step: [104/189], batch loss: 0.57650, batch accuracy: 67.97, data load time: 0.00305, step time: 0.12553
# epoch: [5], step: [114/189], batch loss: 0.56712, batch accuracy: 67.19, data load time: 0.00312, step time: 0.12600
# epoch: [5], step: [124/189], batch loss: 0.56450, batch accuracy: 67.97, data load time: 0.00310, step time: 0.12542
# epoch: [5], step: [134/189], batch loss: 0.56612, batch accuracy: 67.58, data load time: 0.00301, step time: 0.12602
# epoch: [5], step: [144/189], batch loss: 0.58167, batch accuracy: 65.62, data load time: 0.00310, step time: 0.12533
# epoch: [5], step: [154/189], batch loss: 0.57133, batch accuracy: 67.97, data load time: 0.00324, step time: 0.12719
# epoch: [5], step: [164/189], batch loss: 0.56534, batch accuracy: 65.62, data load time: 0.00312, step time: 0.12578
# epoch: [5], step: [174/189], batch loss: 0.57594, batch accuracy: 66.80, data load time: 0.00299, step time: 0.12570
# epoch: [5], step: [184/189], batch loss: 0.57637, batch accuracy: 65.23, data load time: 0.00376, step time: 0.12632
# epoch: [6], step: [5/189], batch loss: 0.58311, batch accuracy: 60.55, data load time: 0.00302, step time: 0.12573
# epoch: [6], step: [15/189], batch loss: 0.57980, batch accuracy: 67.58, data load time: 0.00296, step time: 0.12583
# epoch: [6], step: [25/189], batch loss: 0.58038, batch accuracy: 66.41, data load time: 0.00297, step time: 0.12559
# epoch: [6], step: [35/189], batch loss: 0.56511, batch accuracy: 68.36, data load time: 0.00292, step time: 0.12786
# epoch: [6], step: [45/189], batch loss: 0.56850, batch accuracy: 69.53, data load time: 0.00315, step time: 0.12632
# epoch: [6], step: [55/189], batch loss: 0.55481, batch accuracy: 69.53, data load time: 0.00289, step time: 0.12594
# epoch: [6], step: [65/189], batch loss: 0.56353, batch accuracy: 67.58, data load time: 0.00308, step time: 0.12567
# epoch: [6], step: [75/189], batch loss: 0.56311, batch accuracy: 69.53, data load time: 0.00310, step time: 0.12572
# epoch: [6], step: [85/189], batch loss: 0.55579, batch accuracy: 67.97, data load time: 0.00301, step time: 0.12654
# epoch: [6], step: [95/189], batch loss: 0.57233, batch accuracy: 65.62, data load time: 0.00298, step time: 0.12599
# epoch: [6], step: [105/189], batch loss: 0.57446, batch accuracy: 67.58, data load time: 0.00304, step time: 0.12614
# epoch: [6], step: [115/189], batch loss: 0.58317, batch accuracy: 66.02, data load time: 0.00307, step time: 0.12588
# epoch: [6], step: [125/189], batch loss: 0.56154, batch accuracy: 67.97, data load time: 0.00324, step time: 0.12519
# epoch: [6], step: [135/189], batch loss: 0.56794, batch accuracy: 68.75, data load time: 0.00303, step time: 0.12679
# epoch: [6], step: [145/189], batch loss: 0.54815, batch accuracy: 72.27, data load time: 0.00300, step time: 0.12633
# epoch: [6], step: [155/189], batch loss: 0.56663, batch accuracy: 67.58, data load time: 0.00326, step time: 0.12602
# epoch: [6], step: [165/189], batch loss: 0.55640, batch accuracy: 70.31, data load time: 0.00313, step time: 0.12590
# epoch: [6], step: [175/189], batch loss: 0.61017, batch accuracy: 61.72, data load time: 0.00309, step time: 0.12599
# epoch: [6], step: [185/189], batch loss: 0.59623, batch accuracy: 62.50, data load time: 0.00380, step time: 0.12609
# epoch: [7], step: [6/189], batch loss: 0.54982, batch accuracy: 67.97, data load time: 0.00306, step time: 0.12625
# epoch: [7], step: [16/189], batch loss: 0.57922, batch accuracy: 63.67, data load time: 0.00300, step time: 0.12766
# epoch: [7], step: [26/189], batch loss: 0.56845, batch accuracy: 64.06, data load time: 0.00284, step time: 0.12595
# epoch: [7], step: [36/189], batch loss: 0.57804, batch accuracy: 64.45, data load time: 0.00337, step time: 0.12643
# epoch: [7], step: [46/189], batch loss: 0.58863, batch accuracy: 66.80, data load time: 0.00322, step time: 0.12601
# epoch: [7], step: [56/189], batch loss: 0.54649, batch accuracy: 67.58, data load time: 0.00305, step time: 0.12600
# epoch: [7], step: [66/189], batch loss: 0.56813, batch accuracy: 67.58, data load time: 0.00314, step time: 0.12604
# epoch: [7], step: [76/189], batch loss: 0.59061, batch accuracy: 68.36, data load time: 0.00332, step time: 0.12641
# epoch: [7], step: [86/189], batch loss: 0.59548, batch accuracy: 59.38, data load time: 0.00301, step time: 0.12710
# epoch: [7], step: [96/189], batch loss: 0.56587, batch accuracy: 67.19, data load time: 0.00304, step time: 0.12644
# epoch: [7], step: [106/189], batch loss: 0.56173, batch accuracy: 68.75, data load time: 0.00308, step time: 0.12581
# epoch: [7], step: [116/189], batch loss: 0.54181, batch accuracy: 67.97, data load time: 0.00299, step time: 0.12637
# epoch: [7], step: [126/189], batch loss: 0.54477, batch accuracy: 68.36, data load time: 0.00307, step time: 0.12664
# epoch: [7], step: [136/189], batch loss: 0.57776, batch accuracy: 65.23, data load time: 0.00297, step time: 0.12630
# epoch: [7], step: [146/189], batch loss: 0.55161, batch accuracy: 68.75, data load time: 0.00301, step time: 0.12654
# epoch: [7], step: [156/189], batch loss: 0.55764, batch accuracy: 68.36, data load time: 0.00304, step time: 0.12653
# epoch: [7], step: [166/189], batch loss: 0.57133, batch accuracy: 66.41, data load time: 0.00310, step time: 0.12631
# epoch: [7], step: [176/189], batch loss: 0.55943, batch accuracy: 68.36, data load time: 0.00312, step time: 0.12633
# epoch: [7], step: [186/189], batch loss: 0.55673, batch accuracy: 65.62, data load time: 0.00322, step time: 0.12786
# epoch: [8], step: [7/189], batch loss: 0.53520, batch accuracy: 71.09, data load time: 0.00311, step time: 0.12548
# epoch: [8], step: [17/189], batch loss: 0.54500, batch accuracy: 70.31, data load time: 0.00302, step time: 0.12644
# epoch: [8], step: [27/189], batch loss: 0.57069, batch accuracy: 66.41, data load time: 0.00289, step time: 0.12643
# epoch: [8], step: [37/189], batch loss: 0.57000, batch accuracy: 67.19, data load time: 0.00336, step time: 0.12673
# epoch: [8], step: [47/189], batch loss: 0.54890, batch accuracy: 71.88, data load time: 0.00311, step time: 0.12708
# epoch: [8], step: [57/189], batch loss: 0.57365, batch accuracy: 65.23, data load time: 0.00300, step time: 0.12629
# epoch: [8], step: [67/189], batch loss: 0.54655, batch accuracy: 68.36, data load time: 0.00296, step time: 0.12761
# epoch: [8], step: [77/189], batch loss: 0.56108, batch accuracy: 67.97, data load time: 0.00300, step time: 0.12660
# epoch: [8], step: [87/189], batch loss: 0.54646, batch accuracy: 68.36, data load time: 0.00303, step time: 0.12684
# epoch: [8], step: [97/189], batch loss: 0.55177, batch accuracy: 71.09, data load time: 0.00303, step time: 0.12642
# epoch: [8], step: [107/189], batch loss: 0.52370, batch accuracy: 68.75, data load time: 0.00305, step time: 0.12661
# epoch: [8], step: [117/189], batch loss: 0.53026, batch accuracy: 70.70, data load time: 0.00298, step time: 0.12680
# epoch: [8], step: [127/189], batch loss: 0.56187, batch accuracy: 67.97, data load time: 0.00299, step time: 0.12719
# epoch: [8], step: [137/189], batch loss: 0.52887, batch accuracy: 75.00, data load time: 0.00299, step time: 0.12779
# epoch: [8], step: [147/189], batch loss: 0.57122, batch accuracy: 63.67, data load time: 0.00319, step time: 0.12646
# epoch: [8], step: [157/189], batch loss: 0.54737, batch accuracy: 69.92, data load time: 0.00307, step time: 0.12660
# epoch: [8], step: [167/189], batch loss: 0.50332, batch accuracy: 73.83, data load time: 0.00290, step time: 0.12743
# epoch: [8], step: [177/189], batch loss: 0.55935, batch accuracy: 64.45, data load time: 0.00301, step time: 0.12620
# epoch: [8], step: [187/189], batch loss: 0.52980, batch accuracy: 71.48, data load time: 0.00326, step time: 0.12649
# epoch: [9], step: [8/189], batch loss: 0.51781, batch accuracy: 73.05, data load time: 0.00308, step time: 0.12592
# epoch: [9], step: [18/189], batch loss: 0.54375, batch accuracy: 69.92, data load time: 0.00298, step time: 0.12817
# epoch: [9], step: [28/189], batch loss: 0.53216, batch accuracy: 70.31, data load time: 0.00318, step time: 0.12647
# epoch: [9], step: [38/189], batch loss: 0.55944, batch accuracy: 65.62, data load time: 0.00301, step time: 0.12749
# epoch: [9], step: [48/189], batch loss: 0.56362, batch accuracy: 66.80, data load time: 0.00302, step time: 0.12759
# epoch: [9], step: [58/189], batch loss: 0.54084, batch accuracy: 64.45, data load time: 0.00305, step time: 0.12660
# epoch: [9], step: [68/189], batch loss: 0.56273, batch accuracy: 72.66, data load time: 0.00299, step time: 0.12633
# epoch: [9], step: [78/189], batch loss: 0.57040, batch accuracy: 64.84, data load time: 0.00331, step time: 0.12668
# epoch: [9], step: [88/189], batch loss: 0.58631, batch accuracy: 64.45, data load time: 0.00314, step time: 0.12680
# epoch: [9], step: [98/189], batch loss: 0.57549, batch accuracy: 63.28, data load time: 0.00307, step time: 0.12653
# epoch: [9], step: [108/189], batch loss: 0.53743, batch accuracy: 67.19, data load time: 0.00323, step time: 0.12673
# epoch: [9], step: [118/189], batch loss: 0.51667, batch accuracy: 69.92, data load time: 0.00298, step time: 0.12717
# epoch: [9], step: [128/189], batch loss: 0.54852, batch accuracy: 67.58, data load time: 0.00310, step time: 0.12708
# epoch: [9], step: [138/189], batch loss: 0.57642, batch accuracy: 65.23, data load time: 0.00296, step time: 0.12661
# epoch: [9], step: [148/189], batch loss: 0.57828, batch accuracy: 68.75, data load time: 0.00290, step time: 0.12759
# epoch: [9], step: [158/189], batch loss: 0.56406, batch accuracy: 67.19, data load time: 0.00314, step time: 0.12639
# epoch: [9], step: [168/189], batch loss: 0.55242, batch accuracy: 67.19, data load time: 0.00313, step time: 0.12659
# epoch: [9], step: [178/189], batch loss: 0.53355, batch accuracy: 72.66, data load time: 0.00303, step time: 0.12660
# epoch: [9], step: [188/189], batch loss: 0.61330, batch accuracy: 61.54, data load time: 0.00203, step time: 0.02692
#
# Validating model...
# AUC: 0.7017655121565894 on validation dataset
#
# epoch: [10], step: [9/189], batch loss: 0.53578, batch accuracy: 65.62, data load time: 0.00324, step time: 0.12593
# epoch: [10], step: [19/189], batch loss: 0.55281, batch accuracy: 67.97, data load time: 0.00311, step time: 0.12547
# epoch: [10], step: [29/189], batch loss: 0.53883, batch accuracy: 71.88, data load time: 0.00309, step time: 0.12503
# epoch: [10], step: [39/189], batch loss: 0.51520, batch accuracy: 71.09, data load time: 0.00300, step time: 0.12559
# epoch: [10], step: [49/189], batch loss: 0.55616, batch accuracy: 61.33, data load time: 0.00308, step time: 0.12537
# epoch: [10], step: [59/189], batch loss: 0.52795, batch accuracy: 69.92, data load time: 0.00309, step time: 0.12556
# epoch: [10], step: [69/189], batch loss: 0.56034, batch accuracy: 65.62, data load time: 0.00300, step time: 0.12499
# epoch: [10], step: [79/189], batch loss: 0.54460, batch accuracy: 70.70, data load time: 0.00299, step time: 0.12755
# epoch: [10], step: [89/189], batch loss: 0.53587, batch accuracy: 73.44, data load time: 0.00294, step time: 0.12534
# epoch: [10], step: [99/189], batch loss: 0.54427, batch accuracy: 67.19, data load time: 0.00340, step time: 0.12555
# epoch: [10], step: [109/189], batch loss: 0.52841, batch accuracy: 68.75, data load time: 0.00297, step time: 0.12618
# epoch: [10], step: [119/189], batch loss: 0.54177, batch accuracy: 67.58, data load time: 0.00312, step time: 0.12596
# epoch: [10], step: [129/189], batch loss: 0.53836, batch accuracy: 66.80, data load time: 0.00312, step time: 0.12559
# epoch: [10], step: [139/189], batch loss: 0.55629, batch accuracy: 67.19, data load time: 0.00296, step time: 0.12566
# epoch: [10], step: [149/189], batch loss: 0.56417, batch accuracy: 65.23, data load time: 0.00307, step time: 0.12666
# epoch: [10], step: [159/189], batch loss: 0.56092, batch accuracy: 69.92, data load time: 0.00313, step time: 0.12586
# epoch: [10], step: [169/189], batch loss: 0.51507, batch accuracy: 68.36, data load time: 0.00287, step time: 0.12622
# epoch: [10], step: [179/189], batch loss: 0.53929, batch accuracy: 67.58, data load time: 0.00299, step time: 0.12569
# epoch: [11], step: [0/189], batch loss: 0.55807, batch accuracy: 68.36, data load time: 0.00869, step time: 0.12582
# epoch: [11], step: [10/189], batch loss: 0.51111, batch accuracy: 70.31, data load time: 0.00310, step time: 0.12616
# epoch: [11], step: [20/189], batch loss: 0.58528, batch accuracy: 62.89, data load time: 0.00298, step time: 0.12585
# epoch: [11], step: [30/189], batch loss: 0.54413, batch accuracy: 68.36, data load time: 0.00301, step time: 0.12627
# epoch: [11], step: [40/189], batch loss: 0.55067, batch accuracy: 65.23, data load time: 0.00302, step time: 0.12636
# epoch: [11], step: [50/189], batch loss: 0.53913, batch accuracy: 69.14, data load time: 0.00307, step time: 0.12538
# epoch: [11], step: [60/189], batch loss: 0.52981, batch accuracy: 69.92, data load time: 0.00298, step time: 0.12598
# epoch: [11], step: [70/189], batch loss: 0.58031, batch accuracy: 66.02, data load time: 0.00312, step time: 0.12593
# epoch: [11], step: [80/189], batch loss: 0.51313, batch accuracy: 75.00, data load time: 0.00308, step time: 0.12589
# epoch: [11], step: [90/189], batch loss: 0.54452, batch accuracy: 69.92, data load time: 0.00306, step time: 0.12619
# epoch: [11], step: [100/189], batch loss: 0.53026, batch accuracy: 70.70, data load time: 0.00304, step time: 0.12639
# epoch: [11], step: [110/189], batch loss: 0.53520, batch accuracy: 66.80, data load time: 0.00290, step time: 0.12620
# epoch: [11], step: [120/189], batch loss: 0.51962, batch accuracy: 71.88, data load time: 0.00323, step time: 0.12654
# epoch: [11], step: [130/189], batch loss: 0.53205, batch accuracy: 67.58, data load time: 0.00306, step time: 0.12630
# epoch: [11], step: [140/189], batch loss: 0.54180, batch accuracy: 68.75, data load time: 0.00315, step time: 0.12637
# epoch: [11], step: [150/189], batch loss: 0.52823, batch accuracy: 71.09, data load time: 0.00304, step time: 0.12612
# epoch: [11], step: [160/189], batch loss: 0.50031, batch accuracy: 72.27, data load time: 0.00300, step time: 0.12598
# epoch: [11], step: [170/189], batch loss: 0.53073, batch accuracy: 66.80, data load time: 0.00319, step time: 0.12702
# epoch: [11], step: [180/189], batch loss: 0.53439, batch accuracy: 65.23, data load time: 0.00305, step time: 0.12579
# epoch: [12], step: [1/189], batch loss: 0.50984, batch accuracy: 74.61, data load time: 0.00296, step time: 0.12636
# epoch: [12], step: [11/189], batch loss: 0.53604, batch accuracy: 69.14, data load time: 0.00301, step time: 0.12672
# epoch: [12], step: [21/189], batch loss: 0.53716, batch accuracy: 64.06, data load time: 0.00311, step time: 0.12619
# epoch: [12], step: [31/189], batch loss: 0.52970, batch accuracy: 67.19, data load time: 0.00322, step time: 0.12620
# epoch: [12], step: [41/189], batch loss: 0.51297, batch accuracy: 72.66, data load time: 0.00298, step time: 0.12680
# epoch: [12], step: [51/189], batch loss: 0.53142, batch accuracy: 64.84, data load time: 0.00293, step time: 0.12608
# epoch: [12], step: [61/189], batch loss: 0.54294, batch accuracy: 69.53, data load time: 0.00307, step time: 0.12652
# epoch: [12], step: [71/189], batch loss: 0.51828, batch accuracy: 71.88, data load time: 0.00304, step time: 0.12570
# epoch: [12], step: [81/189], batch loss: 0.51512, batch accuracy: 72.66, data load time: 0.00295, step time: 0.12661
# epoch: [12], step: [91/189], batch loss: 0.51151, batch accuracy: 68.75, data load time: 0.00313, step time: 0.12618
# epoch: [12], step: [101/189], batch loss: 0.52164, batch accuracy: 68.75, data load time: 0.00299, step time: 0.12635
# epoch: [12], step: [111/189], batch loss: 0.54468, batch accuracy: 69.53, data load time: 0.00299, step time: 0.12635
# epoch: [12], step: [121/189], batch loss: 0.52160, batch accuracy: 67.19, data load time: 0.00289, step time: 0.12787
# epoch: [12], step: [131/189], batch loss: 0.51665, batch accuracy: 69.92, data load time: 0.00305, step time: 0.12649
# epoch: [12], step: [141/189], batch loss: 0.52622, batch accuracy: 69.92, data load time: 0.00300, step time: 0.12632
# epoch: [12], step: [151/189], batch loss: 0.53449, batch accuracy: 74.61, data load time: 0.00300, step time: 0.12713
# epoch: [12], step: [161/189], batch loss: 0.52310, batch accuracy: 71.09, data load time: 0.00303, step time: 0.12657
# epoch: [12], step: [171/189], batch loss: 0.50756, batch accuracy: 75.39, data load time: 0.00298, step time: 0.12662
# epoch: [12], step: [181/189], batch loss: 0.52343, batch accuracy: 74.22, data load time: 0.00302, step time: 0.12649
# epoch: [13], step: [2/189], batch loss: 0.53969, batch accuracy: 68.75, data load time: 0.00309, step time: 0.12879
# epoch: [13], step: [12/189], batch loss: 0.51233, batch accuracy: 71.48, data load time: 0.00310, step time: 0.12663
# epoch: [13], step: [22/189], batch loss: 0.53666, batch accuracy: 65.23, data load time: 0.00296, step time: 0.12676
# epoch: [13], step: [32/189], batch loss: 0.56468, batch accuracy: 68.75, data load time: 0.00304, step time: 0.12658
# epoch: [13], step: [42/189], batch loss: 0.51445, batch accuracy: 73.44, data load time: 0.00290, step time: 0.12694
# epoch: [13], step: [52/189], batch loss: 0.54193, batch accuracy: 65.23, data load time: 0.00311, step time: 0.12666
# epoch: [13], step: [62/189], batch loss: 0.51181, batch accuracy: 72.27, data load time: 0.00300, step time: 0.12679
# epoch: [13], step: [72/189], batch loss: 0.53154, batch accuracy: 68.75, data load time: 0.00307, step time: 0.12674
# epoch: [13], step: [82/189], batch loss: 0.51685, batch accuracy: 67.19, data load time: 0.00298, step time: 0.12645
# epoch: [13], step: [92/189], batch loss: 0.53184, batch accuracy: 68.36, data load time: 0.00301, step time: 0.12649
# epoch: [13], step: [102/189], batch loss: 0.52722, batch accuracy: 66.02, data load time: 0.00297, step time: 0.12819
# epoch: [13], step: [112/189], batch loss: 0.51605, batch accuracy: 69.92, data load time: 0.00305, step time: 0.12705
# epoch: [13], step: [122/189], batch loss: 0.53739, batch accuracy: 68.75, data load time: 0.00296, step time: 0.12702
# epoch: [13], step: [132/189], batch loss: 0.49893, batch accuracy: 71.48, data load time: 0.00297, step time: 0.12688
# epoch: [13], step: [142/189], batch loss: 0.54797, batch accuracy: 68.75, data load time: 0.00307, step time: 0.12635
# epoch: [13], step: [152/189], batch loss: 0.50002, batch accuracy: 71.88, data load time: 0.00299, step time: 0.12662
# epoch: [13], step: [162/189], batch loss: 0.51864, batch accuracy: 70.31, data load time: 0.00302, step time: 0.12692
# epoch: [13], step: [172/189], batch loss: 0.51126, batch accuracy: 71.48, data load time: 0.00307, step time: 0.12625
# epoch: [13], step: [182/189], batch loss: 0.51859, batch accuracy: 67.97, data load time: 0.00304, step time: 0.12641
# epoch: [14], step: [3/189], batch loss: 0.54789, batch accuracy: 70.70, data load time: 0.00301, step time: 0.12684
# epoch: [14], step: [13/189], batch loss: 0.54228, batch accuracy: 65.62, data load time: 0.00287, step time: 0.12640
# epoch: [14], step: [23/189], batch loss: 0.52587, batch accuracy: 68.36, data load time: 0.00311, step time: 0.12639
# epoch: [14], step: [33/189], batch loss: 0.52539, batch accuracy: 69.14, data load time: 0.00305, step time: 0.12661
# epoch: [14], step: [43/189], batch loss: 0.50337, batch accuracy: 73.05, data load time: 0.00303, step time: 0.12686
# epoch: [14], step: [53/189], batch loss: 0.49912, batch accuracy: 74.22, data load time: 0.00308, step time: 0.12660
# epoch: [14], step: [63/189], batch loss: 0.48714, batch accuracy: 73.44, data load time: 0.00312, step time: 0.12710
# epoch: [14], step: [73/189], batch loss: 0.54140, batch accuracy: 69.92, data load time: 0.00295, step time: 0.12687
# epoch: [14], step: [83/189], batch loss: 0.52522, batch accuracy: 66.41, data load time: 0.00301, step time: 0.12775
# epoch: [14], step: [93/189], batch loss: 0.54093, batch accuracy: 68.75, data load time: 0.00307, step time: 0.12722
# epoch: [14], step: [103/189], batch loss: 0.55891, batch accuracy: 69.92, data load time: 0.00306, step time: 0.12669
# epoch: [14], step: [113/189], batch loss: 0.49031, batch accuracy: 75.78, data load time: 0.00314, step time: 0.12700
# epoch: [14], step: [123/189], batch loss: 0.49421, batch accuracy: 73.44, data load time: 0.00298, step time: 0.12695
# epoch: [14], step: [133/189], batch loss: 0.50760, batch accuracy: 69.14, data load time: 0.00292, step time: 0.12694
# epoch: [14], step: [143/189], batch loss: 0.54873, batch accuracy: 70.31, data load time: 0.00291, step time: 0.12716
# epoch: [14], step: [153/189], batch loss: 0.53499, batch accuracy: 68.75, data load time: 0.00310, step time: 0.12663
# epoch: [14], step: [163/189], batch loss: 0.54897, batch accuracy: 69.53, data load time: 0.00308, step time: 0.12675
# epoch: [14], step: [173/189], batch loss: 0.54082, batch accuracy: 69.92, data load time: 0.00296, step time: 0.12732
# epoch: [14], step: [183/189], batch loss: 0.54671, batch accuracy: 66.41, data load time: 0.00299, step time: 0.12848
#
# Validating model...
# AUC: 0.7000456687572739 on validation dataset
#
# epoch: [15], step: [4/189], batch loss: 0.50403, batch accuracy: 70.31, data load time: 0.00301, step time: 0.13222
# epoch: [15], step: [14/189], batch loss: 0.53419, batch accuracy: 70.70, data load time: 0.00302, step time: 0.12492
# epoch: [15], step: [24/189], batch loss: 0.51852, batch accuracy: 70.31, data load time: 0.00305, step time: 0.12532
# epoch: [15], step: [34/189], batch loss: 0.49493, batch accuracy: 71.88, data load time: 0.00300, step time: 0.12577
# epoch: [15], step: [44/189], batch loss: 0.49980, batch accuracy: 78.52, data load time: 0.00307, step time: 0.12501
# epoch: [15], step: [54/189], batch loss: 0.52063, batch accuracy: 68.75, data load time: 0.00302, step time: 0.12614
# epoch: [15], step: [64/189], batch loss: 0.56931, batch accuracy: 65.23, data load time: 0.00311, step time: 0.12558
# epoch: [15], step: [74/189], batch loss: 0.51273, batch accuracy: 68.75, data load time: 0.00296, step time: 0.12582
# epoch: [15], step: [84/189], batch loss: 0.51130, batch accuracy: 70.31, data load time: 0.00299, step time: 0.12562
# epoch: [15], step: [94/189], batch loss: 0.52729, batch accuracy: 68.36, data load time: 0.00300, step time: 0.12515
# epoch: [15], step: [104/189], batch loss: 0.51513, batch accuracy: 68.36, data load time: 0.00301, step time: 0.12534
# epoch: [15], step: [114/189], batch loss: 0.51392, batch accuracy: 75.78, data load time: 0.00301, step time: 0.12579
# epoch: [15], step: [124/189], batch loss: 0.53063, batch accuracy: 70.31, data load time: 0.00317, step time: 0.12714
# epoch: [15], step: [134/189], batch loss: 0.52801, batch accuracy: 64.84, data load time: 0.00315, step time: 0.12581
# epoch: [15], step: [144/189], batch loss: 0.50354, batch accuracy: 71.88, data load time: 0.00301, step time: 0.12569
# epoch: [15], step: [154/189], batch loss: 0.50064, batch accuracy: 69.92, data load time: 0.00304, step time: 0.12521
# epoch: [15], step: [164/189], batch loss: 0.55106, batch accuracy: 66.80, data load time: 0.00301, step time: 0.12567
# epoch: [15], step: [174/189], batch loss: 0.50844, batch accuracy: 71.88, data load time: 0.00303, step time: 0.12558
# epoch: [15], step: [184/189], batch loss: 0.48249, batch accuracy: 73.44, data load time: 0.00297, step time: 0.12594
# epoch: [16], step: [5/189], batch loss: 0.54781, batch accuracy: 66.41, data load time: 0.00299, step time: 0.12692
# epoch: [16], step: [15/189], batch loss: 0.50636, batch accuracy: 72.27, data load time: 0.00294, step time: 0.12565
# epoch: [16], step: [25/189], batch loss: 0.56576, batch accuracy: 64.45, data load time: 0.00297, step time: 0.12611
# epoch: [16], step: [35/189], batch loss: 0.50185, batch accuracy: 70.31, data load time: 0.00288, step time: 0.12621
# epoch: [16], step: [45/189], batch loss: 0.55459, batch accuracy: 67.19, data load time: 0.00317, step time: 0.12615
# epoch: [16], step: [55/189], batch loss: 0.51773, batch accuracy: 73.44, data load time: 0.00308, step time: 0.12624
# epoch: [16], step: [65/189], batch loss: 0.53779, batch accuracy: 68.36, data load time: 0.00300, step time: 0.12600
# epoch: [16], step: [75/189], batch loss: 0.49168, batch accuracy: 75.00, data load time: 0.00302, step time: 0.12757
# epoch: [16], step: [85/189], batch loss: 0.52550, batch accuracy: 68.75, data load time: 0.00317, step time: 0.12588
# epoch: [16], step: [95/189], batch loss: 0.53534, batch accuracy: 69.14, data load time: 0.00319, step time: 0.12628
# epoch: [16], step: [105/189], batch loss: 0.49548, batch accuracy: 69.92, data load time: 0.00322, step time: 0.12591
# epoch: [16], step: [115/189], batch loss: 0.51157, batch accuracy: 70.70, data load time: 0.00298, step time: 0.12586
# epoch: [16], step: [125/189], batch loss: 0.51347, batch accuracy: 71.09, data load time: 0.00303, step time: 0.12656
# epoch: [16], step: [135/189], batch loss: 0.49704, batch accuracy: 69.53, data load time: 0.00315, step time: 0.12628
# epoch: [16], step: [145/189], batch loss: 0.53566, batch accuracy: 69.53, data load time: 0.00310, step time: 0.12613
# epoch: [16], step: [155/189], batch loss: 0.50200, batch accuracy: 72.66, data load time: 0.00308, step time: 0.12621
# epoch: [16], step: [165/189], batch loss: 0.50605, batch accuracy: 69.53, data load time: 0.00302, step time: 0.12674
# epoch: [16], step: [175/189], batch loss: 0.55304, batch accuracy: 65.23, data load time: 0.00316, step time: 0.12691
# epoch: [16], step: [185/189], batch loss: 0.50209, batch accuracy: 71.48, data load time: 0.00300, step time: 0.12666
# epoch: [17], step: [6/189], batch loss: 0.55403, batch accuracy: 66.02, data load time: 0.00308, step time: 0.12620
# epoch: [17], step: [16/189], batch loss: 0.53331, batch accuracy: 67.19, data load time: 0.00304, step time: 0.12625
# epoch: [17], step: [26/189], batch loss: 0.46527, batch accuracy: 78.91, data load time: 0.00309, step time: 0.12631
# epoch: [17], step: [36/189], batch loss: 0.48302, batch accuracy: 71.09, data load time: 0.00313, step time: 0.12627
# epoch: [17], step: [46/189], batch loss: 0.49527, batch accuracy: 74.22, data load time: 0.00298, step time: 0.12644
# epoch: [17], step: [56/189], batch loss: 0.49096, batch accuracy: 69.14, data load time: 0.00290, step time: 0.12747
# epoch: [17], step: [66/189], batch loss: 0.49819, batch accuracy: 73.83, data load time: 0.00311, step time: 0.12602
# epoch: [17], step: [76/189], batch loss: 0.53671, batch accuracy: 69.53, data load time: 0.00299, step time: 0.12678
# epoch: [17], step: [86/189], batch loss: 0.46817, batch accuracy: 73.05, data load time: 0.00312, step time: 0.12631
# epoch: [17], step: [96/189], batch loss: 0.51395, batch accuracy: 67.97, data load time: 0.00304, step time: 0.12591
# epoch: [17], step: [106/189], batch loss: 0.54066, batch accuracy: 64.45, data load time: 0.00320, step time: 0.12666
# epoch: [17], step: [116/189], batch loss: 0.51302, batch accuracy: 71.09, data load time: 0.00311, step time: 0.12668
# epoch: [17], step: [126/189], batch loss: 0.50250, batch accuracy: 68.75, data load time: 0.00300, step time: 0.12756
# epoch: [17], step: [136/189], batch loss: 0.54598, batch accuracy: 70.70, data load time: 0.00312, step time: 0.12678
# epoch: [17], step: [146/189], batch loss: 0.49892, batch accuracy: 71.88, data load time: 0.00301, step time: 0.12647
# epoch: [17], step: [156/189], batch loss: 0.48256, batch accuracy: 76.17, data load time: 0.00296, step time: 0.12652
# epoch: [17], step: [166/189], batch loss: 0.54354, batch accuracy: 66.02, data load time: 0.00293, step time: 0.12599
# epoch: [17], step: [176/189], batch loss: 0.46979, batch accuracy: 78.52, data load time: 0.00288, step time: 0.12657
# epoch: [17], step: [186/189], batch loss: 0.52787, batch accuracy: 67.58, data load time: 0.00305, step time: 0.12672
# epoch: [18], step: [7/189], batch loss: 0.50459, batch accuracy: 67.97, data load time: 0.00300, step time: 0.12690
# epoch: [18], step: [17/189], batch loss: 0.54196, batch accuracy: 63.28, data load time: 0.00316, step time: 0.12655
# epoch: [18], step: [27/189], batch loss: 0.54176, batch accuracy: 66.02, data load time: 0.00278, step time: 0.12677
# epoch: [18], step: [37/189], batch loss: 0.47456, batch accuracy: 69.92, data load time: 0.00311, step time: 0.12661
# epoch: [18], step: [47/189], batch loss: 0.51317, batch accuracy: 73.83, data load time: 0.00298, step time: 0.12679
# epoch: [18], step: [57/189], batch loss: 0.50463, batch accuracy: 71.88, data load time: 0.00301, step time: 0.12665
# epoch: [18], step: [67/189], batch loss: 0.52656, batch accuracy: 69.53, data load time: 0.00305, step time: 0.12694
# epoch: [18], step: [77/189], batch loss: 0.52558, batch accuracy: 70.31, data load time: 0.00307, step time: 0.12664
# epoch: [18], step: [87/189], batch loss: 0.50250, batch accuracy: 70.31, data load time: 0.00314, step time: 0.12624
# epoch: [18], step: [97/189], batch loss: 0.50020, batch accuracy: 71.09, data load time: 0.00292, step time: 0.12653
# epoch: [18], step: [107/189], batch loss: 0.51582, batch accuracy: 67.58, data load time: 0.00304, step time: 0.12780
# epoch: [18], step: [117/189], batch loss: 0.48423, batch accuracy: 73.44, data load time: 0.00303, step time: 0.12681
# epoch: [18], step: [127/189], batch loss: 0.52208, batch accuracy: 69.53, data load time: 0.00298, step time: 0.12681
# epoch: [18], step: [137/189], batch loss: 0.50236, batch accuracy: 74.22, data load time: 0.00308, step time: 0.12710
# epoch: [18], step: [147/189], batch loss: 0.54001, batch accuracy: 68.36, data load time: 0.00301, step time: 0.12673
# epoch: [18], step: [157/189], batch loss: 0.51131, batch accuracy: 71.48, data load time: 0.00305, step time: 0.12583
# epoch: [18], step: [167/189], batch loss: 0.49506, batch accuracy: 74.22, data load time: 0.00302, step time: 0.12695
# epoch: [18], step: [177/189], batch loss: 0.51274, batch accuracy: 71.09, data load time: 0.00309, step time: 0.12583
# epoch: [18], step: [187/189], batch loss: 0.51022, batch accuracy: 70.70, data load time: 0.00306, step time: 0.12642
# epoch: [19], step: [8/189], batch loss: 0.47454, batch accuracy: 75.78, data load time: 0.00306, step time: 0.12644
# epoch: [19], step: [18/189], batch loss: 0.54182, batch accuracy: 67.58, data load time: 0.00310, step time: 0.12737
# epoch: [19], step: [28/189], batch loss: 0.48345, batch accuracy: 69.92, data load time: 0.00305, step time: 0.12651
# epoch: [19], step: [38/189], batch loss: 0.48877, batch accuracy: 71.09, data load time: 0.00300, step time: 0.12665
# epoch: [19], step: [48/189], batch loss: 0.49860, batch accuracy: 71.88, data load time: 0.00307, step time: 0.12698
# epoch: [19], step: [58/189], batch loss: 0.47597, batch accuracy: 73.83, data load time: 0.00313, step time: 0.12585
# epoch: [19], step: [68/189], batch loss: 0.52857, batch accuracy: 69.14, data load time: 0.00316, step time: 0.12665
# epoch: [19], step: [78/189], batch loss: 0.49756, batch accuracy: 68.75, data load time: 0.00310, step time: 0.12731
# epoch: [19], step: [88/189], batch loss: 0.51072, batch accuracy: 69.53, data load time: 0.00301, step time: 0.12731
# epoch: [19], step: [98/189], batch loss: 0.54727, batch accuracy: 68.36, data load time: 0.00307, step time: 0.12658
# epoch: [19], step: [108/189], batch loss: 0.51234, batch accuracy: 70.70, data load time: 0.00294, step time: 0.12678
# epoch: [19], step: [118/189], batch loss: 0.48003, batch accuracy: 75.39, data load time: 0.00319, step time: 0.12664
# epoch: [19], step: [128/189], batch loss: 0.50710, batch accuracy: 66.80, data load time: 0.00292, step time: 0.12648
# epoch: [19], step: [138/189], batch loss: 0.52149, batch accuracy: 70.70, data load time: 0.00304, step time: 0.12634
# epoch: [19], step: [148/189], batch loss: 0.50696, batch accuracy: 66.80, data load time: 0.00305, step time: 0.12651
# epoch: [19], step: [158/189], batch loss: 0.50297, batch accuracy: 71.88, data load time: 0.00313, step time: 0.12600
# epoch: [19], step: [168/189], batch loss: 0.48838, batch accuracy: 74.22, data load time: 0.00316, step time: 0.12611
# epoch: [19], step: [178/189], batch loss: 0.52252, batch accuracy: 71.88, data load time: 0.00295, step time: 0.12660
# epoch: [19], step: [188/189], batch loss: 0.64189, batch accuracy: 59.62, data load time: 0.00193, step time: 0.02714
#
# Validating model...
# AUC: 0.6945851642113245 on validation dataset
#
# epoch: [20], step: [9/189], batch loss: 0.51043, batch accuracy: 71.88, data load time: 0.00333, step time: 0.12550
# epoch: [20], step: [19/189], batch loss: 0.53473, batch accuracy: 67.19, data load time: 0.00330, step time: 0.12509
# epoch: [20], step: [29/189], batch loss: 0.50265, batch accuracy: 72.27, data load time: 0.00318, step time: 0.12509
# epoch: [20], step: [39/189], batch loss: 0.49746, batch accuracy: 71.09, data load time: 0.00303, step time: 0.12540
# epoch: [20], step: [49/189], batch loss: 0.49836, batch accuracy: 71.48, data load time: 0.00309, step time: 0.12583
# epoch: [20], step: [59/189], batch loss: 0.45885, batch accuracy: 77.73, data load time: 0.00305, step time: 0.12557
# epoch: [20], step: [69/189], batch loss: 0.50585, batch accuracy: 73.83, data load time: 0.00331, step time: 0.12557
# epoch: [20], step: [79/189], batch loss: 0.50920, batch accuracy: 67.97, data load time: 0.00307, step time: 0.12589
# epoch: [20], step: [89/189], batch loss: 0.48780, batch accuracy: 67.97, data load time: 0.00297, step time: 0.12634
# epoch: [20], step: [99/189], batch loss: 0.50332, batch accuracy: 68.36, data load time: 0.00295, step time: 0.12595
# epoch: [20], step: [109/189], batch loss: 0.50151, batch accuracy: 69.92, data load time: 0.00298, step time: 0.12587
# epoch: [20], step: [119/189], batch loss: 0.50178, batch accuracy: 70.31, data load time: 0.00302, step time: 0.12555
# epoch: [20], step: [129/189], batch loss: 0.48528, batch accuracy: 73.83, data load time: 0.00299, step time: 0.12589
# epoch: [20], step: [139/189], batch loss: 0.48480, batch accuracy: 76.17, data load time: 0.00322, step time: 0.12596
# epoch: [20], step: [149/189], batch loss: 0.54193, batch accuracy: 68.75, data load time: 0.00292, step time: 0.12619
# epoch: [20], step: [159/189], batch loss: 0.47935, batch accuracy: 74.61, data load time: 0.00294, step time: 0.12600
# epoch: [20], step: [169/189], batch loss: 0.47622, batch accuracy: 75.78, data load time: 0.00300, step time: 0.12539
# epoch: [20], step: [179/189], batch loss: 0.51748, batch accuracy: 69.14, data load time: 0.00327, step time: 0.12542
# epoch: [21], step: [0/189], batch loss: 0.50386, batch accuracy: 70.70, data load time: 0.00947, step time: 0.12463
# epoch: [21], step: [10/189], batch loss: 0.56727, batch accuracy: 66.02, data load time: 0.00292, step time: 0.12756
# epoch: [21], step: [20/189], batch loss: 0.51866, batch accuracy: 70.31, data load time: 0.00313, step time: 0.12642
# epoch: [21], step: [30/189], batch loss: 0.54297, batch accuracy: 65.23, data load time: 0.00287, step time: 0.12616
# epoch: [21], step: [40/189], batch loss: 0.50562, batch accuracy: 71.88, data load time: 0.00298, step time: 0.12592
# epoch: [21], step: [50/189], batch loss: 0.47849, batch accuracy: 75.00, data load time: 0.00305, step time: 0.12582
# epoch: [21], step: [60/189], batch loss: 0.52123, batch accuracy: 72.27, data load time: 0.00298, step time: 0.12595
# epoch: [21], step: [70/189], batch loss: 0.47789, batch accuracy: 73.44, data load time: 0.00305, step time: 0.12624
# ...
# epoch: [45], step: [134/189], batch loss: 0.46777, batch accuracy: 74.61, data load time: 0.00311, step time: 0.12546
# epoch: [45], step: [144/189], batch loss: 0.49159, batch accuracy: 74.61, data load time: 0.00295, step time: 0.12717
# epoch: [45], step: [154/189], batch loss: 0.48951, batch accuracy: 76.56, data load time: 0.00305, step time: 0.12598
# epoch: [45], step: [164/189], batch loss: 0.44791, batch accuracy: 74.61, data load time: 0.00295, step time: 0.12621
# epoch: [45], step: [174/189], batch loss: 0.52015, batch accuracy: 69.53, data load time: 0.00291, step time: 0.12668
# epoch: [45], step: [184/189], batch loss: 0.44267, batch accuracy: 76.95, data load time: 0.00304, step time: 0.12642
#
# Validating model...
# AUC: 0.6516925922483184 on validation dataset
#
# epoch: [46], step: [5/189], batch loss: 0.50545, batch accuracy: 71.09, data load time: 0.00319, step time: 0.13098
# epoch: [46], step: [15/189], batch loss: 0.45835, batch accuracy: 77.34, data load time: 0.00293, step time: 0.12459
# epoch: [46], step: [25/189], batch loss: 0.47138, batch accuracy: 75.78, data load time: 0.00298, step time: 0.12566
# epoch: [46], step: [35/189], batch loss: 0.45997, batch accuracy: 73.83, data load time: 0.00291, step time: 0.12682
# epoch: [46], step: [45/189], batch loss: 0.46441, batch accuracy: 73.44, data load time: 0.00306, step time: 0.12542
# epoch: [46], step: [55/189], batch loss: 0.41013, batch accuracy: 81.25, data load time: 0.00305, step time: 0.12498
# epoch: [46], step: [65/189], batch loss: 0.45680, batch accuracy: 78.12, data load time: 0.00299, step time: 0.12506
# epoch: [46], step: [75/189], batch loss: 0.44413, batch accuracy: 76.95, data load time: 0.00306, step time: 0.12615
# epoch: [46], step: [85/189], batch loss: 0.47683, batch accuracy: 75.78, data load time: 0.00299, step time: 0.12558
# epoch: [46], step: [95/189], batch loss: 0.43933, batch accuracy: 75.78, data load time: 0.00282, step time: 0.12560
# epoch: [46], step: [105/189], batch loss: 0.49275, batch accuracy: 70.70, data load time: 0.00301, step time: 0.12682
# epoch: [46], step: [115/189], batch loss: 0.49834, batch accuracy: 73.05, data load time: 0.00302, step time: 0.12537
# epoch: [46], step: [125/189], batch loss: 0.49221, batch accuracy: 76.56, data load time: 0.00298, step time: 0.12587
# epoch: [46], step: [135/189], batch loss: 0.47741, batch accuracy: 73.83, data load time: 0.00306, step time: 0.12568
# epoch: [46], step: [145/189], batch loss: 0.47210, batch accuracy: 74.22, data load time: 0.00308, step time: 0.12571
# epoch: [46], step: [155/189], batch loss: 0.46358, batch accuracy: 76.17, data load time: 0.00310, step time: 0.12524
# epoch: [46], step: [165/189], batch loss: 0.45827, batch accuracy: 77.73, data load time: 0.00303, step time: 0.12580
# epoch: [46], step: [175/189], batch loss: 0.46625, batch accuracy: 75.78, data load time: 0.00305, step time: 0.12665
# epoch: [46], step: [185/189], batch loss: 0.47340, batch accuracy: 73.44, data load time: 0.00298, step time: 0.12554
# epoch: [47], step: [6/189], batch loss: 0.50447, batch accuracy: 71.48, data load time: 0.00295, step time: 0.12586
# epoch: [47], step: [16/189], batch loss: 0.46053, batch accuracy: 73.83, data load time: 0.00300, step time: 0.12613
# epoch: [47], step: [26/189], batch loss: 0.43190, batch accuracy: 77.34, data load time: 0.00321, step time: 0.12582
# epoch: [47], step: [36/189], batch loss: 0.51169, batch accuracy: 69.14, data load time: 0.00296, step time: 0.12564
# epoch: [47], step: [46/189], batch loss: 0.42949, batch accuracy: 75.39, data load time: 0.00298, step time: 0.12548
# epoch: [47], step: [56/189], batch loss: 0.44797, batch accuracy: 71.88, data load time: 0.00316, step time: 0.12630
# epoch: [47], step: [66/189], batch loss: 0.46403, batch accuracy: 72.66, data load time: 0.00296, step time: 0.12625
# epoch: [47], step: [76/189], batch loss: 0.46719, batch accuracy: 75.00, data load time: 0.00296, step time: 0.12662
# epoch: [47], step: [86/189], batch loss: 0.45679, batch accuracy: 73.05, data load time: 0.00297, step time: 0.12558
# epoch: [47], step: [96/189], batch loss: 0.44017, batch accuracy: 77.34, data load time: 0.00317, step time: 0.12636
# epoch: [47], step: [106/189], batch loss: 0.44875, batch accuracy: 76.17, data load time: 0.00315, step time: 0.12664
# epoch: [47], step: [116/189], batch loss: 0.50182, batch accuracy: 70.70, data load time: 0.00295, step time: 0.12642
# epoch: [47], step: [126/189], batch loss: 0.46452, batch accuracy: 74.61, data load time: 0.00302, step time: 0.12757
# epoch: [47], step: [136/189], batch loss: 0.41073, batch accuracy: 82.42, data load time: 0.00313, step time: 0.12656
# epoch: [47], step: [146/189], batch loss: 0.45816, batch accuracy: 75.39, data load time: 0.00298, step time: 0.12642
# epoch: [47], step: [156/189], batch loss: 0.45649, batch accuracy: 74.61, data load time: 0.00299, step time: 0.12599
# epoch: [47], step: [166/189], batch loss: 0.41951, batch accuracy: 75.78, data load time: 0.00305, step time: 0.12616
# epoch: [47], step: [176/189], batch loss: 0.45718, batch accuracy: 75.00, data load time: 0.00312, step time: 0.12613
# epoch: [47], step: [186/189], batch loss: 0.48478, batch accuracy: 71.09, data load time: 0.00295, step time: 0.12633
#
# Validating model...
# AUC: 0.6491590088062061 on validation dataset
#
# epoch: [48], step: [7/189], batch loss: 0.46720, batch accuracy: 76.17, data load time: 0.00297, step time: 0.12738
# epoch: [48], step: [17/189], batch loss: 0.43534, batch accuracy: 76.95, data load time: 0.00302, step time: 0.12515
# epoch: [48], step: [27/189], batch loss: 0.49554, batch accuracy: 73.05, data load time: 0.00300, step time: 0.12517
# epoch: [48], step: [37/189], batch loss: 0.45576, batch accuracy: 77.34, data load time: 0.00296, step time: 0.12581
# epoch: [48], step: [47/189], batch loss: 0.38673, batch accuracy: 82.42, data load time: 0.00329, step time: 0.12590
# epoch: [48], step: [57/189], batch loss: 0.48254, batch accuracy: 69.92, data load time: 0.00284, step time: 0.12636
# epoch: [48], step: [67/189], batch loss: 0.46252, batch accuracy: 75.39, data load time: 0.00294, step time: 0.12545
# epoch: [48], step: [77/189], batch loss: 0.46312, batch accuracy: 74.22, data load time: 0.00297, step time: 0.12527
# epoch: [48], step: [87/189], batch loss: 0.45670, batch accuracy: 73.44, data load time: 0.00295, step time: 0.12533
# epoch: [48], step: [97/189], batch loss: 0.44026, batch accuracy: 75.39, data load time: 0.00314, step time: 0.12577
# epoch: [48], step: [107/189], batch loss: 0.46406, batch accuracy: 74.22, data load time: 0.00300, step time: 0.12635
# epoch: [48], step: [117/189], batch loss: 0.47577, batch accuracy: 73.05, data load time: 0.00301, step time: 0.12561
# epoch: [48], step: [127/189], batch loss: 0.44884, batch accuracy: 75.78, data load time: 0.00301, step time: 0.12627
# epoch: [48], step: [137/189], batch loss: 0.45760, batch accuracy: 75.78, data load time: 0.00297, step time: 0.12577
# epoch: [48], step: [147/189], batch loss: 0.46145, batch accuracy: 74.61, data load time: 0.00295, step time: 0.12611
# epoch: [48], step: [157/189], batch loss: 0.42313, batch accuracy: 79.69, data load time: 0.00321, step time: 0.12582
# epoch: [48], step: [167/189], batch loss: 0.49957, batch accuracy: 71.48, data load time: 0.00300, step time: 0.12636
# epoch: [48], step: [177/189], batch loss: 0.43320, batch accuracy: 77.34, data load time: 0.00302, step time: 0.12618
# epoch: [48], step: [187/189], batch loss: 0.42555, batch accuracy: 78.91, data load time: 0.00287, step time: 0.12516
# epoch: [49], step: [8/189], batch loss: 0.47502, batch accuracy: 73.05, data load time: 0.00282, step time: 0.12628
# epoch: [49], step: [18/189], batch loss: 0.41214, batch accuracy: 78.12, data load time: 0.00308, step time: 0.12561
# epoch: [49], step: [28/189], batch loss: 0.45229, batch accuracy: 74.61, data load time: 0.00311, step time: 0.12586
# epoch: [49], step: [38/189], batch loss: 0.53317, batch accuracy: 69.14, data load time: 0.00302, step time: 0.12704
# epoch: [49], step: [48/189], batch loss: 0.44009, batch accuracy: 76.95, data load time: 0.00312, step time: 0.12545
# epoch: [49], step: [58/189], batch loss: 0.47370, batch accuracy: 77.34, data load time: 0.00293, step time: 0.12587
# epoch: [49], step: [68/189], batch loss: 0.45222, batch accuracy: 75.39, data load time: 0.00296, step time: 0.12602
# epoch: [49], step: [78/189], batch loss: 0.43998, batch accuracy: 77.34, data load time: 0.00290, step time: 0.12673
# epoch: [49], step: [88/189], batch loss: 0.43910, batch accuracy: 76.17, data load time: 0.00297, step time: 0.12586
# epoch: [49], step: [98/189], batch loss: 0.47676, batch accuracy: 73.83, data load time: 0.00303, step time: 0.12523
# epoch: [49], step: [108/189], batch loss: 0.42420, batch accuracy: 76.17, data load time: 0.00296, step time: 0.12597
# epoch: [49], step: [118/189], batch loss: 0.41632, batch accuracy: 76.56, data load time: 0.00298, step time: 0.12590
# epoch: [49], step: [128/189], batch loss: 0.52167, batch accuracy: 73.83, data load time: 0.00307, step time: 0.12616
# epoch: [49], step: [138/189], batch loss: 0.44214, batch accuracy: 74.22, data load time: 0.00295, step time: 0.12626
# epoch: [49], step: [148/189], batch loss: 0.44473, batch accuracy: 76.17, data load time: 0.00319, step time: 0.12603
# epoch: [49], step: [158/189], batch loss: 0.46918, batch accuracy: 76.95, data load time: 0.00297, step time: 0.12624
# epoch: [49], step: [168/189], batch loss: 0.42126, batch accuracy: 80.08, data load time: 0.00295, step time: 0.12649
# epoch: [49], step: [178/189], batch loss: 0.47504, batch accuracy: 73.05, data load time: 0.00311, step time: 0.12801
# epoch: [49], step: [188/189], batch loss: 0.49239, batch accuracy: 78.85, data load time: 0.00187, step time: 0.02686
#
# Validating model...
# AUC: 0.6603501875245412 on validation dataset
#
# epoch: [50], step: [9/189], batch loss: 0.46754, batch accuracy: 70.31, data load time: 0.00322, step time: 0.12556
# epoch: [50], step: [19/189], batch loss: 0.49138, batch accuracy: 72.66, data load time: 0.00295, step time: 0.12519
# epoch: [50], step: [29/189], batch loss: 0.42221, batch accuracy: 78.52, data load time: 0.00295, step time: 0.12600
# epoch: [50], step: [39/189], batch loss: 0.43119, batch accuracy: 75.78, data load time: 0.00328, step time: 0.12571
# epoch: [50], step: [49/189], batch loss: 0.46161, batch accuracy: 77.34, data load time: 0.00293, step time: 0.12548
# epoch: [50], step: [59/189], batch loss: 0.46712, batch accuracy: 76.17, data load time: 0.00299, step time: 0.12499
# epoch: [50], step: [69/189], batch loss: 0.44615, batch accuracy: 79.30, data load time: 0.00302, step time: 0.12588
# epoch: [50], step: [79/189], batch loss: 0.43047, batch accuracy: 78.91, data load time: 0.00305, step time: 0.12582
# epoch: [50], step: [89/189], batch loss: 0.41005, batch accuracy: 83.59, data load time: 0.00300, step time: 0.12590
# epoch: [50], step: [99/189], batch loss: 0.45668, batch accuracy: 75.78, data load time: 0.00299, step time: 0.12561
# epoch: [50], step: [109/189], batch loss: 0.47024, batch accuracy: 74.22, data load time: 0.00317, step time: 0.12534
# epoch: [50], step: [119/189], batch loss: 0.45982, batch accuracy: 74.61, data load time: 0.00300, step time: 0.12550
# epoch: [50], step: [129/189], batch loss: 0.45573, batch accuracy: 71.09, data load time: 0.00300, step time: 0.12543
# epoch: [50], step: [139/189], batch loss: 0.48030, batch accuracy: 74.22, data load time: 0.00302, step time: 0.12641
# epoch: [50], step: [149/189], batch loss: 0.49172, batch accuracy: 73.83, data load time: 0.00308, step time: 0.12622
# epoch: [50], step: [159/189], batch loss: 0.45839, batch accuracy: 76.17, data load time: 0.00300, step time: 0.12671
# epoch: [50], step: [169/189], batch loss: 0.40973, batch accuracy: 78.12, data load time: 0.00299, step time: 0.12594
# epoch: [50], step: [179/189], batch loss: 0.40121, batch accuracy: 78.52, data load time: 0.00323, step time: 0.12583
# epoch: [51], step: [0/189], batch loss: 0.47095, batch accuracy: 77.34, data load time: 0.00941, step time: 0.12518
# epoch: [51], step: [10/189], batch loss: 0.48656, batch accuracy: 72.27, data load time: 0.00299, step time: 0.13149
# epoch: [51], step: [20/189], batch loss: 0.56437, batch accuracy: 68.75, data load time: 0.00351, step time: 0.13133
# epoch: [51], step: [30/189], batch loss: 0.38965, batch accuracy: 79.69, data load time: 0.00325, step time: 0.13166
# epoch: [51], step: [40/189], batch loss: 0.41485, batch accuracy: 78.52, data load time: 0.00324, step time: 0.13270
# epoch: [51], step: [50/189], batch loss: 0.49192, batch accuracy: 71.48, data load time: 0.00346, step time: 0.13185
# epoch: [51], step: [60/189], batch loss: 0.46553, batch accuracy: 75.78, data load time: 0.00359, step time: 0.13405
# epoch: [51], step: [70/189], batch loss: 0.42879, batch accuracy: 75.00, data load time: 0.00424, step time: 0.13288
# epoch: [51], step: [80/189], batch loss: 0.46188, batch accuracy: 73.05, data load time: 0.00374, step time: 0.14031
# epoch: [51], step: [90/189], batch loss: 0.48988, batch accuracy: 73.44, data load time: 0.00338, step time: 0.13689
# epoch: [51], step: [100/189], batch loss: 0.44881, batch accuracy: 76.17, data load time: 0.00370, step time: 0.12665
# epoch: [51], step: [110/189], batch loss: 0.49217, batch accuracy: 70.70, data load time: 0.00307, step time: 0.12639
# epoch: [51], step: [120/189], batch loss: 0.47159, batch accuracy: 76.56, data load time: 0.00311, step time: 0.12589
# epoch: [51], step: [130/189], batch loss: 0.44386, batch accuracy: 77.73, data load time: 0.00336, step time: 0.12788
# epoch: [51], step: [140/189], batch loss: 0.41941, batch accuracy: 77.34, data load time: 0.00354, step time: 0.13273
# epoch: [51], step: [150/189], batch loss: 0.47724, batch accuracy: 75.39, data load time: 0.00330, step time: 0.12697
# epoch: [51], step: [160/189], batch loss: 0.45360, batch accuracy: 75.00, data load time: 0.00322, step time: 0.12573
# epoch: [51], step: [170/189], batch loss: 0.46906, batch accuracy: 74.22, data load time: 0.00312, step time: 0.13476
# epoch: [51], step: [180/189], batch loss: 0.46038, batch accuracy: 76.17, data load time: 0.00323, step time: 0.13972
#
# Validating model...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 404
#     402 if __name__ == "__main__":
#     403     args, _ = parser.parse_known_args()
# --> 404     main(args)
#
# Cell In[25], line 126, in main(args)
#     121 trainer = Trainer(
#     122     model, train_loader, test_loader, criterion, optimizer, summary_writer, DEVICE
#     123 )
#     125 print("About to train...")
# --> 126 trainer.train(
#     127     args.epochs,
#     128     args.val_frequency,
#     129     print_frequency=args.print_frequency,
#     130     log_frequency=args.log_frequency,
#     131 )
#     132 print("Finished training.")
#     133 summary_writer.close()
#
# Cell In[25], line 238, in Trainer.train(self, epochs, val_frequency, print_frequency, log_frequency, start_epoch)
#     236 if epoch > 23:
#     237     if ((epoch + 1) % val_frequency) == 0:
# --> 238         val_auc = self.validate()
#     239         checkpoint_model(self.model, float(val_auc), False)
#     240         # log val auc
#
# Cell In[25], line 292, in Trainer.validate(self)
#     288 def validate(self):
#     290     print("\nValidating model...")
# --> 292     auc = test_model(self.model, valdata, val_ground_truth_dict, self.device)
#     294     print("AUC:", auc, "on validation dataset\n")
#     296     return auc
#
# Cell In[25], line 341, in test_model(model, dataMIT, ground_truth_dict, device)
#     337 for j in range(num_batches):
#     339     batch = img_crops[j * batch_size:(j * batch_size) + batch_size,:,:,:,:]
# --> 341     batch = batch.to(device)
#     343     preds = sigmoid(model(batch).detach().cpu().reshape(1, 50))
#     344     # preds = (preds > 0.5).float()
#
# KeyboardInterrupt:

# %%
# code for CBAM parts inspired (taken from and modified accordingly) by code at https://github.com/w6688j/CBAM/blob/master/model/resnet_cbam.py
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        # self.fc1   = nn.Conv2d(in_planes, in_planes // ratio, 1, bias=False)
        self.fc1 = nn.Linear(in_planes, in_planes // ratio, bias=False)
        # self.fc2 = nn.Conv2d(in_planes // ratio, in_planes, 1, bias=False)
        self.fc2 = nn.Linear(in_planes // ratio, in_planes, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):

        # print("shapeee", x.shape)
        # import sys ; sys.exit(0)

        avg_out = self.avg_pool(x).squeeze().squeeze()
        avg_out = self.fc1(avg_out)
        avg_out = F.relu(avg_out)
        avg_out = self.fc2(avg_out)

        max_out = self.max_pool(x).squeeze().squeeze()
        max_out = self.fc1(max_out)
        max_out = F.relu(max_out)
        max_out = self.fc2(max_out)

        # avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        # max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))

        out = (avg_out + max_out).unsqueeze(2).unsqueeze(3)
        return self.sigmoid(out)

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super().__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return self.sigmoid(x)




class CNN(nn.Module):
    def __init__(self, height: int, width: int, channels: int, class_count: int, dropout:float):
        super().__init__()
        self.input_shape = ImageShape(height=height, width=width, channels=channels)
        self.class_count = class_count

        self.dropout = nn.Dropout(p=dropout)
        self.dropout2d = nn.Dropout2d(p=dropout)

        # Define 1st Conv, Pool, and BatchNorm
    
        # Conv 1
        self.conv1 = nn.Conv2d(
            in_channels=self.input_shape.channels,
            out_channels=96,
            kernel_size=(7, 7),
            padding= (0,0), #(2, 2),
        )
        self.initialise_layer(self.conv1)
        
        # Pool 1
        self.pool1 = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))

        # BatchNorm 1
        self.batchnorm1 = nn.BatchNorm2d(self.conv1.out_channels)

        # attention 1
        self.ca1 = ChannelAttention(96)
        self.sa1 = SpatialAttention()

        # Define 2nd Conv, Pool, and BatchNorm
        
        # Conv 2
        self.conv2 = nn.Conv2d(
            in_channels=96,
            out_channels=160,
            kernel_size=(3, 3),
            padding= (0,0) #(2, 2)
        )

        self.initialise_layer(self.conv2)
        
        # Pool 2
        self.pool2 = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))

        # BatchNorm 2
        self.batchnorm2 = nn.BatchNorm2d(num_features=self.conv2.out_channels)

        # attention 2
        self.ca2 = ChannelAttention(160)
        self.sa2 = SpatialAttention()
        
        # Define 3rd Conv, Pool, and BatchNorm
        
        # Conv 3
        self.conv3 = nn.Conv2d(
            in_channels=160,
            out_channels=288,
            kernel_size=(3, 3),
            padding= (0,0) #(2, 2)
        )

        self.initialise_layer(self.conv3)
        
        # Pool 3
        self.pool3 = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))

        # BatchNorm 3
        self.batchnorm3 = nn.BatchNorm2d(num_features=self.conv3.out_channels)

        # attention 3
        self.ca3 = ChannelAttention(288)
        self.sa3 = SpatialAttention()


        # Define FC 1

        self.fc1 = nn.Linear(2592, 512)
        self.initialise_layer(self.fc1)

        # BatchNorm layer after first FC layer
        # import pdb; pdb.set_trace()
        self.batchnorm4 = nn.BatchNorm1d(num_features=self.fc1.out_features)

        
        # Define FC 2

        # self.fc2 = nn.Linear(1536, 512)
        self.fc2 = nn.Linear(1536, 512)

        self.initialise_layer(self.fc2)

        # BatchNorm layer after second FC layer

        self.batchnorm5 = nn.BatchNorm1d(num_features=self.fc2.out_features)
        
        # Define FC 3

        self.fc3 = nn.Linear(512, 1)
        self.initialise_layer(self.fc3)

        # BatchNorm layer after third FC layer
        self.batchnorm6 = nn.BatchNorm1d(num_features=self.fc3.out_features)
    
    # FORWARD METHOD
    def forward(self, images: torch.Tensor) -> torch.Tensor:

        batch_size = images.shape[0]

        images = images.reshape(-1, 3, 42, 42)
        
        x = F.relu(self.conv1(images))
        x = self.pool1(x)
        x = self.batchnorm1(x)

        x = self.ca1(x) * x
        x = self.sa1(x) * x

        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = self.batchnorm2(x)


        x = self.ca2(x) * x
        x = self.sa2(x) * x

        
        x = F.relu(self.conv3(x))
        x = self.pool3(x)
        x = self.dropout2d(x)
        x = self.batchnorm3(x)

        # x = x.reshape(-1, 3, 42, 42)

        # print(x.shape)
        # print(x_ca.shape)

        # import sys ; sys.exit(0)

        x = self.ca3(x) * x
        x = self.sa3(x) * x


        # Flatten the output of the pooling layer so it is of shape (batch_size, 4096)
        x = torch.flatten(x, start_dim=1)

        # print(x.shape)
        
        # Pass x through the first fully connected layer
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.batchnorm4(x)


        x = x.reshape(batch_size, -1)


        # x = self.fc2(xCat)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)

        x = self.batchnorm5(x)
        
        x = self.fc3(x)
        #x = self.batchnorm6(x)

        return x

    @staticmethod
    def initialise_layer(layer):
        if hasattr(layer, "bias"):
            nn.init.zeros_(layer.bias)
        if hasattr(layer, "weight"):
            nn.init.kaiming_normal_(layer.weight)

# %% [markdown]
# # Qualitative Analysis

# %%
# load model

model_file_path = test_model_path

trained_model = torch.load(model_file_path)
trained_model.eval()
# Out:
# /tmp/ipykernel_1752378/2219644706.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trained_model = torch.load(model_file_path)
# CNN(
#   (dropout): Dropout(p=0.25, inplace=False)
#   (dropout2d): Dropout2d(p=0.25, inplace=False)
#   (conv1): Conv2d(3, 96, kernel_size=(7, 7), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca1): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=96, out_features=6, bias=False)
#     (fc2): Linear(in_features=6, out_features=96, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa1): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (conv2): Conv2d(96, 160, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca2): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=160, out_features=10, bias=False)
#     (fc2): Linear(in_features=10, out_features=160, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa2): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (conv3): Conv2d(160, 288, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm3): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca3): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=288, out_features=18, bias=False)
#     (fc2): Linear(in_features=18, out_features=288, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa3): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (fc1): Linear(in_features=2592, out_features=512, bias=True)
#   (batchnorm4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1536, out_features=512, bias=True)
#   (batchnorm5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=512, out_features=1, bias=True)
#   (batchnorm6): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def visualise_sal_map(sal_map):

    # Convert the tensor to a numpy array (matplotlib works well with numpy arrays)
    map_np = sal_map.numpy()

    # Plot the tensor as an image
    plt.imshow(map_np, cmap='gray', interpolation='nearest')
    # plt.colorbar()  # Optional: add a colorbar to visualize the range of values
    plt.title('Saliency Map')
    plt.axis('off')  # Turn off axis ticks
    plt.show()

def visualise_triple(pred_sal_map, gt_sal_map, img):
    pred_map_np = pred_sal_map.numpy()
    gt_map_np = gt_sal_map.numpy()

    fig, axes = plt.subplots(1, 3, figsize=(18, 6))

    # Plot the tensor as an image
    axes[0].imshow(pred_map_np, cmap='gray', interpolation='nearest')
    axes[1].imshow(gt_map_np, cmap='gray', interpolation='nearest')
    axes[2].imshow(img)
    # plt.colorbar()  # Optional: add a colorbar to visualize the range of values
    axes[0].set_title('Prediction')
    axes[1].set_title('GT')
    axes[2].set_title('Image')
    axes[0].axis('off')  # Turn off axis ticks
    axes[1].axis('off')  # Turn off axis ticks
    axes[2].axis('off')  # Turn off axis ticks
    plt.tight_layout()  # Adjust layout for better spacing
    plt.show()

# %%
def get_preds_dict(model, dataMIT, device):
    
    model.eval()

    dataset_size = len(dataMIT.dataset)

    batch_size = 50
    num_batches = int(2500 / batch_size)

    preds_dict = {}

    sigmoid = nn.Sigmoid()

    for i in range (dataset_size):

        # potential bug: getting height and width mixed up, so if results look bad, make sure to check this is right

        formatted_filename = format_file_name_fixMap_jpg(dataMIT.dataset[i]['file'])
        height = dataMIT.dataset[i]['X'].shape[1]
        width = dataMIT.dataset[i]['X'].shape[2]

        rescale_to_img = transforms.Resize((height, width))

        img_crops = torch.stack([dataMIT.__getitem__(i * 2500 + j)[0] for j in range(2500)])

        preds_rows = []

        for j in range(num_batches):
            
            batch = img_crops[j * batch_size:(j * batch_size) + batch_size,:,:,:,:]

            batch = batch.to(device)

            preds = sigmoid(model(batch).detach().cpu().reshape(1, 50))
            preds_rows.append(preds)


        sal_map = torch.cat(preds_rows, 0) * 255

        sal_map = rescale_to_img(sal_map.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)    # unsqueezing and squeezing done because transforms.Resize requires (., ., H, W) shape tensor

        preds_dict[formatted_filename] = sal_map

    return preds_dict

# %%
val_preds_dict = get_preds_dict(trained_model, valdata, DEVICE)
test_preds_dict = get_preds_dict(trained_model, testingdata, DEVICE)

# %%
model_test_auc = calculate_auc(test_preds_dict, test_ground_truth_dict)
print(model_test_auc)
# Out:
# 0.8589296779712693

# %%
def get_sal_maps(i, preds_dict, ground_truth_dict):
    file_name = list(preds_dict.keys())[i]

    for img_dict in testingdata.dataset:
        if img_dict['file'] == f"{file_name[:-11]}.jpeg":
            return preds_dict[file_name], ground_truth_dict[file_name], img_dict['X']

    # return preds_dict[file_name], ground_truth_dict[file_name], img

# %%
testingdata.dataset[0]['file']
# Out:
# 'i1182505554.jpeg'

# %%
test_preds_dict.keys()
# Out:
# dict_keys(['i1182505554_fixMap.jpg', 'i110996888_fixMap.jpg', 'i2168982172_fixMap.jpg', 'i10feb04_static_techsquare_img_0873_fixMap.jpg', 'i1560309298_fixMap.jpg', 'i2133522539_fixMap.jpg', 'i1425519942_fixMap.jpg', 'istatic_outdoor_road_mallorca_spain_IMG_0540_fixMap.jpg', 'i1163341362_fixMap.jpg', 'i2125430605_fixMap.jpg', 'i1064228254_fixMap.jpg', 'i1247865242_fixMap.jpg', 'i2197089389_fixMap.jpg', 'i1022085609_fixMap.jpg', 'i2289350187_fixMap.jpg', 'i19023164_fixMap.jpg', 'i111369435_fixMap.jpg', 'i2244445589_fixMap.jpg', 'i2260404605_fixMap.jpg', 'i2051249439_fixMap.jpg', 'i2078195666_fixMap.jpg', 'i1799873859_fixMap.jpg', 'i1394080896_fixMap.jpg', 'i206881209_fixMap.jpg', 'i1486171792_fixMap.jpg', 'imadrid_static_street_p9110480_fixMap.jpg', 'i1425518494_fixMap.jpg', 'i2285904669_fixMap.jpg', 'i201161868_fixMap.jpg', 'i1526935589_fixMap.jpg', 'i182708511_fixMap.jpg', 'i2117655611_fixMap.jpg', 'istatic_houses_boston_2005_IMG_3629_fixMap.jpg', 'i2291139547_fixMap.jpg', 'istatic_barcelona_street_city_outdoor_2_2005_dsc04417_fixMap.jpg', 'i1343103601_fixMap.jpg', 'syntheticData1_fixMap.jpg', 'i2271918453_fixMap.jpg', 'i1818663426_fixMap.jpg', 'i2205555719_fixMap.jpg', 'i2145575787_fixMap.jpg', 'istatic_barcelona_street_city_outdoor_2_2005_img_0625_fixMap.jpg', 'i1583042749_fixMap.jpg', 'i111366726_fixMap.jpg', 'i2285475491_fixMap.jpg', 'i2158540867_fixMap.jpg', 'istatic_submitted_saxena_chung_ng_nips2005_learningdepth_img_gatesback2_p_15t0_fixMap.jpg', 'i114124777_fixMap.jpg', 'i2305300253_fixMap.jpg', 'i2130718051_fixMap.jpg', 'i1166229983_fixMap.jpg', 'istatic_houses_boston_2005_IMG_4024_fixMap.jpg', 'i2285970199_fixMap.jpg', 'i2279208009_fixMap.jpg', 'i1164346942_fixMap.jpg', 'i2275159166_fixMap.jpg', 'i2274292178_fixMap.jpg', 'i2312211495_fixMap.jpg', 'i1061875704_fixMap.jpg', 'i1131124824_fixMap.jpg', 'i1246347137_fixMap.jpg', 'i1918259724_fixMap.jpg', 'i2214763761_fixMap.jpg', 'i111373642_fixMap.jpg', 'i1040585936_fixMap.jpg', 'i436895919_fixMap.jpg', 'i2190576311_fixMap.jpg', 'i1065019259_fixMap.jpg', 'i245864757_fixMap.jpg', 'i2197862712_fixMap.jpg', 'i2141160962_fixMap.jpg', 'i30may05_static_street_cambridge_p1010735_fixMap.jpg', 'i2067603576_fixMap.jpg', 'i2274770415_fixMap.jpg', 'i1865602483_fixMap.jpg', 'i1492679408_fixMap.jpg', 'i207806307_fixMap.jpg', 'istatic_street_outdoor_palma_mallorca_spain_IMG_0459_fixMap.jpg', 'i1843338577_fixMap.jpg', 'i1158903665_fixMap.jpg', 'i2294701937_fixMap.jpg', 'i1426163477_fixMap.jpg', 'i2286258230_fixMap.jpg', 'i1143924367_fixMap.jpg', 'i2206349266_fixMap.jpg', 'i2265201355_fixMap.jpg', 'i1276571229_fixMap.jpg', 'i2238758189_fixMap.jpg', 'istatic_barcelona_street_city_outdoor_2_2005_dsc04121_fixMap.jpg', 'i2238477160_fixMap.jpg', 'i2257330951_fixMap.jpg', 'i126605331_fixMap.jpg', 'i2069913521_fixMap.jpg', 'i2294898365_fixMap.jpg', 'i2309997405_fixMap.jpg', 'i1473135008_fixMap.jpg', 'i2171576731_fixMap.jpg', 'i2172660077_fixMap.jpg', 'i2300299195_fixMap.jpg', 'i2301233235_fixMap.jpg'])

# %%
j = 0

# %%
j += 1

# %%
pred_sal_map, gt_sal_map, img = get_sal_maps(j, test_preds_dict, test_ground_truth_dict)

# visualise_sal_map(pred_sal_map)
# visualise_sal_map(gt_sal_map)

img = img.permute(1, 2, 0).numpy()
visualise_triple(pred_sal_map, gt_sal_map, img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
