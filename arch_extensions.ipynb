# %% [markdown]
# # Data Processing

# %%
#!/usr/bin/env python3
import time
from multiprocessing import cpu_count
from typing import Union, NamedTuple

from torch.utils import data
from torch import Tensor
from typing import Tuple
import torch
import torch.backends.cudnn
import numpy as np
from torch import nn, optim
from torch.nn import functional as F
import torchvision.datasets
from torch.optim.optimizer import Optimizer
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms
from torch.utils.data import Dataset

import argparse
from pathlib import Path

from PIL import Image
from torchvision import transforms

import matplotlib.pyplot as plt

torch.backends.cudnn.benchmark = True


def crop_to_region(coords: Tuple[int], img: Tensor, crop_size: int=42) -> Tensor:
    """ 
    Given coordinates in the form Tuple[int](y, x), return a cropped
    sample of the input imaged centred at (y, x), matching the input size.
    Args:
        coords (Tuple[int]): The input coordinates (y, x) where the crop will be
        centred.
        img (Tensor): The input image, either 3x400x400, 3x250x250, 3x150x150
        crop_size (int, optional): The size of the returned crop. Defaults to 42.

    Returns:
        Tensor: The image cropped with central coordinates at (y, x) of size 
        (3 x size x size) # is size here referring to 42?
    """
    _, H, W = img.shape
    y, x = coords
    y_min, x_min = max(0, y-crop_size//2), max(0, x-crop_size//2)
    y_max, x_max = min(H, y+crop_size//2), min(W, x+crop_size//2)
    region = img[:, y_min:y_max, x_min:x_max]
    if region.shape[1] < crop_size:
        to_pad = crop_size - region.shape[1]
        padding = (0, 0, to_pad, 0) if (y-crop_size//2) < 0 else (0, 0, 0, to_pad)
        region = F.pad(region, padding, mode='replicate')

    if region.shape[2] < crop_size:
        to_pad = crop_size - region.shape[2]
        padding = (to_pad, 0, 0, 0) if (x-crop_size//2) < 0 else (0, to_pad, 0, 0)
        region = F.pad(region, padding, mode='replicate')
    return region

class MIT(data.Dataset):
    def __init__(self, dataset_path: str):
        """
        Given the dataset path, create the MIT dataset. Creates the
        variable self.dataset which is a list of dictionaries with three keys:
            1) X: For train the crop of image. This is of shape [3, 3, 42, 42]. The 
                first dim represents the crop across each different scale
                (400x400, 250x250, 150x150), the second dim is the colour
                channels C, followed by H and W (42x42). For inference, this is 
                the full size image of shape [3, H, W].
            2) y: The label for the crop. 1 = a fixation point, 0 = a
                non-fixation point. -1 = Unlabelled i.e. val and test
            3) file: The file name the crops were extracted from.
            
        If the dataset belongs to val or test, there are 4 additional keys:
            1) X_400: The image resized to 400x400
            2) X_250: The image resized to 250x250
            3) X_150: The image resized to 150x150
            4) spatial_coords: The centre coordinates of all 50x50 (2500) crops
            
        These additional keys help to load the different scales within the
        dataloader itself in a timely manner. Precomputing all crops requires too
        much storage for the lab machines, and resizing/cropping on the fly
        slows down the dataloader, so this is a happy balance.
        Args:
            dataset_path (str): Path to train/val/test.pth.tar
        """
        self.dataset = torch.load(dataset_path, weights_only=True)
        self.mode = 'train' if 'train' in dataset_path else 'inference'
        self.num_crops = 2500 if self.mode == 'inference' else 1

    def __getitem__(self, index) -> Tuple[Tensor, int]:
        """
        Given the index from the DataLoader, return the image crop(s) and label
        Args:
            index (int): the dataset index provided by the PyTorch DataLoader.
        Returns:
            Tuple[Tensor, int]: A two-element tuple consisting of: 
                1) img (Tensor): The image crop of shape [3, 3, 42, 42]. The 
                first dim represents the crop across each different scale
                (400x400, 250x250, 150x150), the second dim is the colour
                channels C, followed by H and W (42x42).
                2) label (int): The label for this crop. 1 = a fixation point, 
                0 = a non-fixation point. -1 = Unlabelled i.e. val and test.
        """
        sample_index = index // self.num_crops
        # print(sample_index)
        
        img = self.dataset[sample_index]['X']
        
        # Inference crops are not precomputed due to file size, do here instead
        if self.mode == 'inference': 
            _, H, W = img.shape
            crop_index = index % self.num_crops
            crop_y, crop_x = self.dataset[sample_index]['spatial_coords'][crop_index]
            scales = []
            for size in ['X_400', 'X_250', 'X_150']:
                scaled_img = self.dataset[sample_index][size]
                y_ratio, x_ratio = scaled_img.shape[1] / H, scaled_img.shape[2] / W
                
                # Need to rescale the crops central coordinate.
                scaled_coords = (int(y_ratio * crop_y), int(x_ratio * crop_x))
                crops = crop_to_region(scaled_coords, scaled_img)
                scales.append(crops)
            img = torch.stack(scales, axis=1)
            
        label = self.dataset[sample_index]['y']

        return img, label

    def __len__(self):
        """
        Returns the length of the dataset (length of the list of dictionaries * number
        of crops). 
        __len()__ always needs to be defined so that the DataLoader
            can create the batches
        Returns:
            len(self.dataset) (int): the length of the list of dictionaries * number of
            crops.
        """
        return len(self.dataset) * self.num_crops


trainingdata = MIT("data/train_data.pth.tar")
valdata = MIT("data/val_data.pth.tar")
testingdata = MIT("data/test_data.pth.tar")


class NormalisedDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


# each element in self.dataset dictionary which has three components so just get X and y component (so X component 3x3x42x42 and y is label) -> inputs to the CNN


# print(trainingdata.dataset[0]['y'])
# print(trainingdata.dataset[0]['X'])
# Out:
# 2024-11-27 15:29:16.826533: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-27 15:29:16.833494: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 15:29:16.841924: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 15:29:16.844619: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-27 15:29:16.850986: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-27 15:29:18.370878: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data Augmentation

# %%
import numpy as np
import statistics

training_data_augmented = trainingdata.dataset * 2
for i in range(len(trainingdata.dataset), len(training_data_augmented)):
    training_data_augmented[i]['X'] = torch.flip(training_data_augmented[i]['X'], dims=[3])
    
print('done')

red_channel = ([sample['X'][:, 0, :, :] for sample in training_data_augmented])
blue_channel = ([sample['X'][:, 1, :, :] for sample in training_data_augmented])
green_channel = ([sample['X'][:, 2, :, :] for sample in training_data_augmented])

normalised_training_data = training_data_augmented

# red channel is a list of 3x42x42 i.e each resolution 42x42 image only the red channel, likewise with the blue and green channel
# so want the mean of the red channels, blue and green channel

def channel_mean(x):
    return (torch.stack(x).mean().item())

def channel_std(x):
    return (torch.stack(x).std().item())

# def channel_mean(x):
#     channel_sum = 0 # sum is 0 to begin with
#     for i in range(0, len(x)): # go through each item in the list
#         item = x[i] # extract 3x42x42 list
#         for j in range(0, 3): # find the sum of each element of the 3x42x42 list and increment to the running sum
#             for k in range(0, 42):
#                 for l in range(0,42):
#                     channel_sum += item[j][k][l].item()
                    
#     return (channel_sum / (len(x)*3*42*42)) # mean of x i.e. total of all values / number of values 

red_mean = channel_mean(red_channel)
blue_mean = channel_mean(blue_channel)
green_mean = channel_mean(green_channel)

red_std = channel_std(red_channel)
blue_std = channel_std(blue_channel)
green_std = channel_std(green_channel)

print(red_mean, blue_mean, green_mean, red_std, blue_std, green_std)

for i in range(0, len(normalised_training_data)): # goes through the current list
    training_data_X = normalised_training_data[i]['X'] # gets the 3x3x42x42 X
    training_data_X[:,0,:,:] = (training_data_X[:,0,:,:] - red_mean) / red_std # gets red channel values and normalises them
    training_data_X[:, 1, :,:] = (training_data_X[:,1,:,:] - blue_mean) / blue_std
    training_data_X[:, 2, :,:] = (training_data_X[:,2,:,:] - green_mean) / green_std
    
    normalised_training_data[i]['X'] = training_data_X
    #print('in loop')

final_data = trainingdata
final_data.dataset = normalised_training_data

print('hello')
# Out:
# done
# 0.01992413029074669 -0.003527479013428092 -0.011873003095388412 0.9579979777336121 0.948402464389801 0.9503791928291321
# hello

# %%
k = 0

# %%
k += 1

# %%
# visualise training data for sanity check

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

X = trainingdata.dataset[k]['X'][1].permute(1, 2, 0).numpy() * 255
y = trainingdata.dataset[k]['y']

print(y)

axes[0].imshow(X)
axes[0].set_title('X')
axes[0].axis('off')  # Turn off axis ticks

# axes[0].imshow(y)
# axes[0].set_title('y')
# axes[0].axis('off')  # Turn off axis ticks
plt.show()

# %% [markdown]
# # Format Files and Generate Ground Truth

# %%
# this code generates the ground truth dictionary for inference datasets indexed by file name (formatted so they end with _fixMap.jpg)
# ensure the predictions dictionary matches this format for file name

def format_file_name_fixMap_jpg(filename):
    return f"{filename[:-5]}_fixMap.jpg"

def get_filenames_fixMap_jpg(dataset: Dataset):
    filenames = [format_file_name_fixMap_jpg(sample['file']) for sample in dataset]

    return filenames

def get_ground_truth_dict(dataset: Dataset):

    filenames = get_filenames_fixMap_jpg(dataset)

    ground_truth_dict = {}
    transform = transforms.ToTensor()

    for filename in filenames:
        ground_truth_dict[filename] = transform(Image.open(f"data/ALLFIXATIONMAPS/ALLFIXATIONMAPS/{filename}")).squeeze() * 255
    
    return ground_truth_dict

# to show usage
# print(list(get_ground_truth_dict(get_filenames_fixMap_jpg(valdata.dataset)).values())[7].shape)

val_ground_truth_dict = get_ground_truth_dict(valdata.dataset)
test_ground_truth_dict = get_ground_truth_dict(testingdata.dataset)

print(list(get_ground_truth_dict(valdata.dataset).values())[0].shape)
print(valdata.dataset[0]['X'].shape)
# Out:
# torch.Size([768, 1024])
# torch.Size([3, 768, 1024])

# %% [markdown]
# # Define ROC-AUC Evaluation

# %%
# metrics code


import numpy as np
from scipy.integrate import simpson


def roc_auc(pred, target, n_points=20, include_prior=False):
        """
        Calculates the Reciever-Operating-Characteristic (ROC) area under
        the curve (AUC) by numerical integration.
        """

        target = np.array(target)/255
                
        # generated = pred
        # changed above comment line to below one as above was throwing error
        generated = np.array(pred)
        # min max normalisation
        generated = (generated - generated.min())/(generated.max() - generated.min())

        def roc(p=0.1):
            x = generated.reshape(-1) > p
            t = target.reshape(-1) > p

            return np.sum(x==t)/len(t)

        calculate_roc = np.vectorize(roc)

        x = np.linspace(0, 1, n_points)
        auc = simpson(calculate_roc(x))/n_points

        return auc

def calculate_auc(preds, targets):
	"""
	inputs -- 2 dictionary with prediction and target images. The 2 dictionaries have the  same number of keys, where each key identifies a unique image. 
	The predictions have the predicted fixation maps while the targets have the ground truth fixation maps which are available from "https://people.csail.mit.edu/tjudd/WherePeopleLook/" 
	"""
	assert preds.keys() == targets.keys()
	mean_auc = 0
	for key in preds.keys():
		mean_auc += roc_auc(preds[key], targets[key])
	mean_auc /= len(preds.keys())
	return mean_auc

# %%
import random

# take the ground truth dictionary of 2d maps and build the set of fixation points
def get_fixation_set(gt_dict, threshold):
    fixation_set = []
    for saliency_map in gt_dict.values():
        #print("hello")
        np_map = saliency_map.numpy()
        coords = np.argwhere(np_map >= threshold).astype(float)
        coords[:, 0] /= saliency_map.shape[0]
        coords[:, 1] /= saliency_map.shape[1]
        fixation_set.extend(map(tuple, coords))
    return np.array(fixation_set)

# get the positive set from a single gt map
def get_positive_set(gt_map, threshold):
    positive_set = []
    np_map = gt_map.numpy()
    coords = np.argwhere(np_map >= threshold).astype(float)
    #print(coords)
    positive_set.extend(map(tuple, coords))
    return np.array(positive_set, dtype=int)

# continuously sample the negative set until we get a sufficient amount.
# IMPORTANT: ensure that no samples from the negative set belong to the positive set.
def sample_negative_set(pos, neg):
    pos_set = pos.astype(set)
    pos_len = len(pos)
    neg_len = len(neg)

    samples = []
    #print(pos_len)
    while len(samples) < pos_len:
        sample_index = np.random.choice(neg_len)
        sample_point = neg[sample_index]
        
        if sample_point not in pos_set:
            samples.append(sample_point)

    return np.array(samples)
    #print([228,458] in pos_set)

#return the saliency values given a set of coords
def get_saliency_values(coords, saliency_map):
    return saliency_map[coords[:, 0], coords[:, 1]]

# Shuffled AUC metric: accounts for center bias by sampling the negative set from all other ground truth images
def calculate_shuffled_auc(preds, targets):
    # get GT map and create binary fixation point set
    fixation_set = get_fixation_set(targets, 200)

    s_auc = 0

    for image_name, map in targets.items():

        #rescale normalised fixation points and convert to int to get negative set
        negative_set = np.copy(fixation_set)
        negative_set[:, 0] *= map.shape[0]
        negative_set[:, 1] *= map.shape[1]
        negative_set = negative_set.astype(int)
        
        #get fixation points for positive set
        positive_set = get_positive_set(map, 200)
        #print(positive_set)

        # get the associated prediction map
        s_map = preds[image_name].numpy()
        # s_map = np.random.rand(x.shape[0], x.shape[1])

        #sample the size of positive set from the negative set, as the negative set very large so this reduces computation
        samples = sample_negative_set(positive_set, negative_set)

        # return the saliency values from the coords defined by the pos and neg set
        pos_saliencies = get_saliency_values(positive_set, s_map)
        neg_saliencies = get_saliency_values(samples, s_map)

        # print(pos_saliencies)
        #plot the predicted saliencies
        y_true = np.concatenate([np.ones(len(pos_saliencies)), np.zeros(len(neg_saliencies))])
        y_scores = np.concatenate([pos_saliencies, neg_saliencies])

        # Sort by the predicted scores
        sorted_indices = np.argsort(y_scores)[::-1]  # Sorting in descending order
        sorted_scores = y_scores[sorted_indices]
        sorted_labels = y_true[sorted_indices]
        
        # Compute TPR and FPR based on sorted scores
        tp_cumsum = np.cumsum(sorted_labels)  
        fp_cumsum = np.cumsum(1 - sorted_labels)  
        
        # Calculate TPR and FPR
        tpr_values = tp_cumsum / tp_cumsum[-1]  
        fpr_values = fp_cumsum / fp_cumsum[-1]  
        
        # Compute the AUC using the trapezoidal rule
        auc_score = np.trapz(tpr_values, fpr_values)  # Trapezoidal rule

        s_auc += auc_score

        #import sys; sys.exit(1)

    s_auc /= len(targets)
        
    return s_auc

# %% [markdown]
# # Model checkpointing

# %%
# val_hp_model_path = "./model/hp_ext/val/model.pth"
# val_hp_auc_path = "./model/hp_ext/val/auc_score"
# test_hp_model_path = "./model/test/model.pth"
# test_hp_auc_path = "./model/test/auc_score"

hp_ext_path = "./model/hp_ext/"

# all_models_path = "./data/models/"

def hp_checkpoint_model(model, auc, is_test, lr, bs, d):

    model_path = ""
    auc_path = ""

    if is_test:
        model_path = f"{hp_ext_path}model_test_{str(lr)}_{str(bs)}_{str(d)}"
        auc_path = f"{hp_ext_path}AUC_test_{str(lr)}_{str(bs)}_{str(d)}"

        # if auc > 0.65:
        #     torch.save(model, f"{all_models_path}model_test_{str(auc)[:5]}.pth")
    else:
        model_path = f"{hp_ext_path}model_val_{str(lr)}_{str(bs)}_{str(d)}"
        auc_path = f"{hp_ext_path}AUC_val_{str(lr)}_{str(bs)}_{str(d)}"

        # if auc > 0.65:
        #     torch.save(model, f"{all_models_path}model_val_{str(auc)[:5]}.pth")

    # scoreboard type checkpointing
    path = Path(auc_path)  # Path to the file you want to check

    if path.exists():
        with open(auc_path, 'r+', encoding='utf-8') as file:
            
            old_auc = float(file.read().strip())

            if auc > old_auc:
                torch.save(model, model_path)
                
                file.truncate(0)
                file.seek(0)
                file.write(str(auc))
    else:
        torch.save(model, model_path)
    
        with open(auc_path, 'w', encoding='utf-8') as file:
            file.write(str(auc))

# %%
val_model_path = "./model/val/model.pth"
val_auc_path = "./model/val/auc_score"
test_model_path = "./model/test/model.pth"
test_auc_path = "./model/test/auc_score"

all_models_path = "./data/models/"

def checkpoint_model(model, auc, is_test):
    model_path = ""
    auc_path = ""

    if is_test:
        model_path = test_model_path
        auc_path = test_auc_path

        if auc > 0.65:
            torch.save(model, f"{all_models_path}model_test_{str(auc)[:5]}.pth")
    else:
        model_path = val_model_path
        auc_path = val_auc_path

        if auc > 0.65:
            torch.save(model, f"{all_models_path}model_val_{str(auc)[:5]}.pth")

    # scoreboard type checkpointing
    path = Path(auc_path)  # Path to the file you want to check

    if path.exists():
        with open(auc_path, 'r+', encoding='utf-8') as file:
            
            old_auc = float(file.read().strip())

            if auc > old_auc:
                torch.save(model, model_path)
                
                file.truncate(0)
                file.seek(0)
                file.write(str(auc))
    else:
        torch.save(model, model_path)
    
        with open(auc_path, 'w', encoding='utf-8') as file:
            file.write(str(auc))

# %% [markdown]
# # Initialise and Train Mr-CNN
#
# ### To see logs:
# module load anaconda \
# pip install tensorboard \
# python3 -m tensorboard.main --logdir=./logs \

# %%
from torchviz import make_dot

parser = argparse.ArgumentParser(
    description="Train a simple CNN on CIFAR-10",
    formatter_class=argparse.ArgumentDefaultsHelpFormatter,
)
default_dataset_dir = Path.home() / ".cache" / "torch" / "datasets"
parser.add_argument("--dataset-root", default=default_dataset_dir)
parser.add_argument("--log-dir", default=Path("logs"), type=Path)
parser.add_argument("--learning-rate", default=2e-4, type=float, help="Learning rate")
parser.add_argument(
    "--batch-size",
    default=256,
    type=int,
    help="Number of images within each mini-batch",
)
parser.add_argument(
    "--epochs",
    default=30,
    type=int,
    help="Number of epochs (passes through the entire dataset) to train for",
)
parser.add_argument(
    "--val-frequency",
    default=10,
    type=int,
    help="How frequently to test the model on the validation set in number of epochs",
)
parser.add_argument(
    "--log-frequency",
    default=10,
    type=int,
    help="How frequently to save logs to tensorboard in number of steps",
)
parser.add_argument(
    "--print-frequency",
    default=10,
    type=int,
    help="How frequently to print progress to the command line in number of steps",
)
parser.add_argument(
    "-j",
    "--worker-count",
    default=0, #cpu_count(), #note make this 0 if not using lab machine
    type=int,
    help="Number of worker processes used to load data.",
)
parser.add_argument("--sgd-momentum", default=0.9, type=float)
parser.add_argument("--data-aug-hflip", action="store_true")
parser.add_argument("--dropout", default=0.5, type=float)
parser.add_argument("--max_norm", default=0.1, type=float)



class ImageShape(NamedTuple):
    height: int
    width: int
    channels: int


if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
else:
    DEVICE = torch.device("cpu")



def main(args):

    # hp tuning

    lr_vals = [2e-3]
    batch_size_vals = [256]
    dropout_vals = [0.2, 0.3, 0.4, 0.5]

    for lr in lr_vals:

        for bs in batch_size_vals:

            for d in dropout_vals:

                args.learning_rate = lr
                args.batch_size = bs
                args.dropout = d

                print(f"\nNEW RUN WITH lr={args.learning_rate}, batch_size={args.batch_size}, dropout={args.dropout}\n")

                train_loader = torch.utils.data.DataLoader(
                    final_data,
                    shuffle=True,
                    batch_size=args.batch_size,
                    pin_memory=True,
                    num_workers=args.worker_count,
                )
                
                print(args)
                
                args.dataset_root.mkdir(parents=True, exist_ok=True)
                
                test_dataset = testingdata.dataset
                
                
                test_loader = torch.utils.data.DataLoader(
                    test_dataset,
                    shuffle=False,
                    batch_size=args.batch_size,
                    num_workers=args.worker_count,
                    pin_memory=True,
                )

                model = CNN(height=42, width=42, channels=3, class_count=2, dropout=args.dropout)

                # for torchviz visualisation of architecture
                # dummy_input = torch.randn(1, 3, 3, 42, 42)

                # output = model(dummy_input)

                # graph = make_dot(output, params=dict(model.named_parameters()))

                # # Save or render the graph
                # graph.render("cnn_graph_merged", format="png")  # Save as PNG

                # define criterion as Binary Cross Entropy Loss - it does sigmoid as built in
                criterion = nn.BCEWithLogitsLoss()

                # define optimizer
                optimizer = torch.optim.SGD(model.parameters(), lr=args.learning_rate, momentum=args.sgd_momentum, weight_decay=2e-4)

                log_dir = get_summary_writer_log_dir(args)
                print(f"Writing logs to {log_dir}")
                summary_writer = SummaryWriter(
                        str(log_dir),
                        flush_secs=5
                )
                trainer = Trainer(
                    model, train_loader, test_loader, criterion, optimizer, summary_writer, DEVICE, args
                )

                print("About to train...")
                trainer.train(
                    args.epochs,
                    args.val_frequency,
                    print_frequency=args.print_frequency,
                    log_frequency=args.log_frequency,
                )
                print("Finished training.")
                summary_writer.close()

                print("\nTESTING MODEL")
                test_auc = test_model(model, testingdata, test_ground_truth_dict, DEVICE)
                print("AUC:", test_auc, "on test dataset\n")

                # save model locally in notebook for manual evaluation
                # checkpoint_model(model, float(test_auc), True)
                hp_checkpoint_model(model, test_auc, True, args.learning_rate, args.batch_size, args.dropout)



class Trainer:
    def __init__(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        val_loader: DataLoader,
        criterion: nn.Module,
        optimizer: Optimizer,
        summary_writer: SummaryWriter,
        device: torch.device,
        args
    ):
        self.model = model.to(device)
        self.device = device
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.criterion = criterion
        self.optimizer = optimizer
        self.summary_writer = summary_writer
        self.step = 0
        self.args = args


            
    def train(
        self,
        epochs: int,
        val_frequency: int,
        print_frequency: int = 20,
        log_frequency: int = 5,
        start_epoch: int = 0
    ):
        self.model.train()
        
        for epoch in range(start_epoch, epochs):

            self.model.train()
            
            data_load_start_time = time.time()

            epoch_accuracy = 0
            epoch_loss = 0

            for batch, labels in self.train_loader:
                
                batch = batch.to(self.device)
                labels = labels.to(self.device)
                data_load_end_time = time.time()

                # forward pass
                logits = self.model.forward(batch).squeeze()

                # compute loss using criterion
                loss = self.criterion(logits, labels.float())

                # backward pass
                loss.backward()

                # step optimizer and zero out gradient buffer
                self.optimizer.step()
                self.optimizer.zero_grad()


                
                with torch.no_grad():
                    preds = (logits > 0.5).float()
                    accuracy = compute_accuracy(labels, preds)

                data_load_time = data_load_end_time - data_load_start_time
                step_time = time.time() - data_load_end_time
                if ((self.step + 1) % log_frequency) == 0:
                    self.log_metrics(epoch, accuracy, loss, data_load_time, step_time)
                if ((self.step + 1) % print_frequency) == 0:
                    self.print_metrics(epoch, accuracy, loss, data_load_time, step_time)

                self.step += 1
                data_load_start_time = time.time()

                epoch_accuracy += accuracy
                epoch_loss += loss

            #update the momentum in the optimizer so that it linearly increases from 0.9 to 0.99
            update_momentum(self.model, self.optimizer, epoch, epochs, start_momentum=0.9, end_momentum=0.99)

            # apply weight constraints to limit the magnitude of all weights (should we apply per batch or per epoch?)
            apply_max_norm(self.model, 0.1)

            # log epoch accuracy and epoch loss
            epoch_accuracy /= self.train_loader.batch_size
            epoch_loss /= self.train_loader.batch_size
            self.summary_writer.add_scalar("epoch_accuracy", epoch_accuracy, self.step)
            self.summary_writer.add_scalar("epoch_loss", epoch_loss, self.step)

            self.summary_writer.add_scalar("epoch", epoch, self.step)
            if ((epoch + 1) % val_frequency) == 0:
                val_auc = self.validate()
                # checkpoint_model(self.model, float(val_auc), False)
                hp_checkpoint_model(self.model, val_auc, False, self.args.learning_rate, self.args.batch_size, self.args.dropout)
                # log val auc
                self.summary_writer.add_scalar("val_auc", val_auc, self.step)
                # self.validate() will put the model in validation mode,
                # so we have to switch back to train mode afterwards
                self.model.train()


    
    def print_metrics(self, epoch, accuracy, loss, data_load_time, step_time):
        epoch_step = self.step % len(self.train_loader)
        print(
                f"epoch: [{epoch}], "
                f"step: [{epoch_step}/{len(self.train_loader)}], "
                f"batch loss: {loss:.5f}, "
                f"batch accuracy: {accuracy * 100:2.2f}, "
                f"data load time: "
                f"{data_load_time:.5f}, "
                f"step time: {step_time:.5f}"
        )

    def log_metrics(self, epoch, accuracy, loss, data_load_time, step_time):
        self.summary_writer.add_scalar("epoch", epoch, self.step)
        self.summary_writer.add_scalars(
                "accuracy",
                {"train": accuracy},
                self.step
        )
        self.summary_writer.add_scalars(
                "loss",
                {"train": float(loss.item())},
                self.step
        )
        self.summary_writer.add_scalar(
                "time/data", data_load_time, self.step
        )
        self.summary_writer.add_scalar(
                "time/data", step_time, self.step
        )

    def validate(self):

        print("\nValidating model...")

        auc = test_model(self.model, valdata, val_ground_truth_dict, self.device)

        print("AUC:", auc, "on validation dataset\n")

        return auc

def update_momentum(self, optimizer, epoch, max_epochs, start_momentum=0.9, end_momentum=0.99):
    momentum = start_momentum + (end_momentum - start_momentum) * (epoch / max_epochs)
    for param_group in optimizer.param_groups:
        param_group['momentum'] = momentum

# Apply weight constraints
def apply_max_norm(model, max_norm):
    with torch.no_grad():
        for param in model.parameters():
            if param.requires_grad:
                param.clamp_(-max_norm, max_norm)

def test_model(model, dataMIT, ground_truth_dict, device):
    
    model.eval()

    dataset_size = len(dataMIT.dataset)

    batch_size = 50
    num_batches = int(2500 / batch_size)

    preds_dict = {}

    sigmoid = nn.Sigmoid()

    for i in range (dataset_size):

        # potential bug: getting height and width mixed up, so if results look bad, make sure to check this is right

        formatted_filename = format_file_name_fixMap_jpg(dataMIT.dataset[i]['file'])
        height = dataMIT.dataset[i]['X'].shape[1]
        width = dataMIT.dataset[i]['X'].shape[2]

        rescale_to_img = transforms.Resize((height, width))

        img_crops = torch.stack([dataMIT.__getitem__(i * 2500 + j)[0] for j in range(2500)])

        preds_rows = []

        for j in range(num_batches):
            
            batch = img_crops[j * batch_size:(j * batch_size) + batch_size,:,:,:,:]

            batch = batch.to(device)

            preds = sigmoid(model(batch).detach().cpu().reshape(1, 50))
            # preds = (preds > 0.5).float()
            preds_rows.append(preds)


        sal_map = torch.cat(preds_rows, 0)

        sal_map = rescale_to_img(sal_map.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)    # unsqueezing and squeezing done because transforms.Resize requires (., ., H, W) shape tensor
        sal_map = rescale_to_img(sal_map) * 255


        preds_dict[formatted_filename] = sal_map

    auc = calculate_auc(preds_dict, ground_truth_dict)

    return auc


def compute_accuracy(
    labels: Union[torch.Tensor, np.ndarray], preds: Union[torch.Tensor, np.ndarray]
) -> float:
    """
    Args:
        labels: ``(batch_size, class_count)`` tensor or array containing example labels
        preds: ``(batch_size, class_count)`` tensor or array containing model prediction
    """
    assert len(labels) == len(preds)
    return float((labels == preds).sum()) / len(labels)


def get_summary_writer_log_dir(args: argparse.Namespace) -> str:
    """Get a unique directory that hasn't been logged to before for use with a TB
    SummaryWriter.

    Args:
        args: CLI Arguments

    Returns:
        Subdirectory of log_dir with unique subdirectory name to prevent multiple runs
        from getting logged to the same TB log directory (which you can't easily
        untangle in TB).
    """
    tb_log_dir_prefix = (
    f"CNN_bn_"
    f"bs={args.batch_size}_"
    f"lr={args.learning_rate}_"
    f"momentum=0.9_" +
    ("hflip_" if args.data_aug_hflip else "") +
    f"run_"
)
    i = 0
    while i < 1000:
        tb_log_dir = args.log_dir / (tb_log_dir_prefix + str(i))
        if not tb_log_dir.exists():
            return str(tb_log_dir)
        i += 1
    return str(tb_log_dir)


if __name__ == "__main__":
    args, _ = parser.parse_known_args()
    main(args)
# Out:
# NEW RUN WITH lr=0.002, batch_size=256, dropout=0.2
#
# Namespace(dataset_root=PosixPath('/home/qz21635/.cache/torch/datasets'), log_dir=PosixPath('logs'), learning_rate=0.002, batch_size=256, epochs=30, val_frequency=10, log_frequency=10, print_frequency=10, worker_count=0, sgd_momentum=0.9, data_aug_hflip=False, dropout=0.2, max_norm=0.1)
# Writing logs to logs/CNN_bn_bs=256_lr=0.002_momentum=0.9_run_2
# About to train...
# epoch: [0], step: [9/189], batch loss: 0.68615, batch accuracy: 61.72, data load time: 0.00340, step time: 0.12720
# epoch: [0], step: [19/189], batch loss: 0.66372, batch accuracy: 68.75, data load time: 0.00310, step time: 0.12585
# epoch: [0], step: [29/189], batch loss: 0.65287, batch accuracy: 67.58, data load time: 0.00313, step time: 0.12494
# epoch: [0], step: [39/189], batch loss: 0.66529, batch accuracy: 63.67, data load time: 0.00297, step time: 0.12622
# epoch: [0], step: [49/189], batch loss: 0.63971, batch accuracy: 67.58, data load time: 0.00306, step time: 0.12694
# epoch: [0], step: [59/189], batch loss: 0.65105, batch accuracy: 64.06, data load time: 0.00302, step time: 0.12449
# epoch: [0], step: [69/189], batch loss: 0.66188, batch accuracy: 62.89, data load time: 0.00312, step time: 0.12552
# epoch: [0], step: [79/189], batch loss: 0.63270, batch accuracy: 67.19, data load time: 0.00322, step time: 0.12565
# epoch: [0], step: [89/189], batch loss: 0.64544, batch accuracy: 64.45, data load time: 0.00329, step time: 0.12544
# epoch: [0], step: [99/189], batch loss: 0.65733, batch accuracy: 63.28, data load time: 0.00293, step time: 0.12475
# epoch: [0], step: [109/189], batch loss: 0.63343, batch accuracy: 67.19, data load time: 0.00296, step time: 0.12490
# epoch: [0], step: [119/189], batch loss: 0.64591, batch accuracy: 63.28, data load time: 0.00324, step time: 0.12644
# epoch: [0], step: [129/189], batch loss: 0.62917, batch accuracy: 65.62, data load time: 0.00321, step time: 0.12634
# epoch: [0], step: [139/189], batch loss: 0.62564, batch accuracy: 67.19, data load time: 0.00322, step time: 0.12681
# epoch: [0], step: [149/189], batch loss: 0.58320, batch accuracy: 72.27, data load time: 0.00301, step time: 0.12631
# epoch: [0], step: [159/189], batch loss: 0.59976, batch accuracy: 69.92, data load time: 0.00303, step time: 0.12501
# epoch: [0], step: [169/189], batch loss: 0.58443, batch accuracy: 70.70, data load time: 0.00301, step time: 0.12466
# epoch: [0], step: [179/189], batch loss: 0.57313, batch accuracy: 70.31, data load time: 0.00312, step time: 0.12675
# epoch: [1], step: [0/189], batch loss: 0.61992, batch accuracy: 71.09, data load time: 0.00918, step time: 0.12353
# epoch: [1], step: [10/189], batch loss: 0.62017, batch accuracy: 69.14, data load time: 0.00310, step time: 0.12415
# epoch: [1], step: [20/189], batch loss: 0.63754, batch accuracy: 64.06, data load time: 0.00310, step time: 0.12571
# epoch: [1], step: [30/189], batch loss: 0.63160, batch accuracy: 65.23, data load time: 0.00305, step time: 0.12596
# epoch: [1], step: [40/189], batch loss: 0.64334, batch accuracy: 63.28, data load time: 0.00303, step time: 0.12418
# epoch: [1], step: [50/189], batch loss: 0.58873, batch accuracy: 69.53, data load time: 0.00303, step time: 0.12424
# epoch: [1], step: [60/189], batch loss: 0.61071, batch accuracy: 66.41, data load time: 0.00300, step time: 0.12455
# epoch: [1], step: [70/189], batch loss: 0.61281, batch accuracy: 68.36, data load time: 0.00298, step time: 0.12527
# epoch: [1], step: [80/189], batch loss: 0.61806, batch accuracy: 66.02, data load time: 0.00297, step time: 0.12493
# epoch: [1], step: [90/189], batch loss: 0.60468, batch accuracy: 64.84, data load time: 0.00296, step time: 0.12412
# epoch: [1], step: [100/189], batch loss: 0.57187, batch accuracy: 71.09, data load time: 0.00301, step time: 0.12587
# epoch: [1], step: [110/189], batch loss: 0.61125, batch accuracy: 63.67, data load time: 0.00297, step time: 0.12512
# epoch: [1], step: [120/189], batch loss: 0.57991, batch accuracy: 66.41, data load time: 0.00317, step time: 0.12582
# epoch: [1], step: [130/189], batch loss: 0.57812, batch accuracy: 67.97, data load time: 0.00303, step time: 0.12727
# epoch: [1], step: [140/189], batch loss: 0.54856, batch accuracy: 68.36, data load time: 0.00300, step time: 0.12533
# epoch: [1], step: [150/189], batch loss: 0.54623, batch accuracy: 71.88, data load time: 0.00291, step time: 0.12458
# epoch: [1], step: [160/189], batch loss: 0.54925, batch accuracy: 67.58, data load time: 0.00286, step time: 0.12721
# epoch: [1], step: [170/189], batch loss: 0.54840, batch accuracy: 72.27, data load time: 0.00329, step time: 0.12724
# epoch: [1], step: [180/189], batch loss: 0.52205, batch accuracy: 70.31, data load time: 0.00299, step time: 0.12579
# epoch: [2], step: [1/189], batch loss: 0.59580, batch accuracy: 66.02, data load time: 0.00297, step time: 0.12528
# epoch: [2], step: [11/189], batch loss: 0.59401, batch accuracy: 61.72, data load time: 0.00331, step time: 0.12474
# epoch: [2], step: [21/189], batch loss: 0.58143, batch accuracy: 65.62, data load time: 0.00297, step time: 0.12651
# epoch: [2], step: [31/189], batch loss: 0.52832, batch accuracy: 71.88, data load time: 0.00306, step time: 0.12610
# epoch: [2], step: [41/189], batch loss: 0.54766, batch accuracy: 67.58, data load time: 0.00298, step time: 0.12776
# epoch: [2], step: [51/189], batch loss: 0.53503, batch accuracy: 73.83, data load time: 0.00294, step time: 0.12606
# epoch: [2], step: [61/189], batch loss: 0.54558, batch accuracy: 66.02, data load time: 0.00291, step time: 0.12660
# epoch: [2], step: [71/189], batch loss: 0.53303, batch accuracy: 70.70, data load time: 0.00313, step time: 0.12574
# epoch: [2], step: [81/189], batch loss: 0.52762, batch accuracy: 73.44, data load time: 0.00306, step time: 0.12629
# epoch: [2], step: [91/189], batch loss: 0.53399, batch accuracy: 69.14, data load time: 0.00300, step time: 0.12607
# epoch: [2], step: [101/189], batch loss: 0.52661, batch accuracy: 75.00, data load time: 0.00317, step time: 0.12492
# epoch: [2], step: [111/189], batch loss: 0.54509, batch accuracy: 67.19, data load time: 0.00314, step time: 0.12676
# epoch: [2], step: [121/189], batch loss: 0.53475, batch accuracy: 69.14, data load time: 0.00298, step time: 0.12657
# epoch: [2], step: [131/189], batch loss: 0.55306, batch accuracy: 64.84, data load time: 0.00302, step time: 0.12568
# epoch: [2], step: [141/189], batch loss: 0.54303, batch accuracy: 71.48, data load time: 0.00294, step time: 0.12517
# epoch: [2], step: [151/189], batch loss: 0.54474, batch accuracy: 71.48, data load time: 0.00321, step time: 0.12524
# epoch: [2], step: [161/189], batch loss: 0.53706, batch accuracy: 68.36, data load time: 0.00295, step time: 0.12636
# epoch: [2], step: [171/189], batch loss: 0.50405, batch accuracy: 71.88, data load time: 0.00291, step time: 0.12583
# epoch: [2], step: [181/189], batch loss: 0.52468, batch accuracy: 72.27, data load time: 0.00291, step time: 0.12553
# epoch: [3], step: [2/189], batch loss: 0.53238, batch accuracy: 67.19, data load time: 0.00325, step time: 0.12566
# epoch: [3], step: [12/189], batch loss: 0.56455, batch accuracy: 68.75, data load time: 0.00328, step time: 0.12580
# epoch: [3], step: [22/189], batch loss: 0.48541, batch accuracy: 72.66, data load time: 0.00303, step time: 0.12654
# epoch: [3], step: [32/189], batch loss: 0.47949, batch accuracy: 76.56, data load time: 0.00294, step time: 0.12693
# epoch: [3], step: [42/189], batch loss: 0.53726, batch accuracy: 70.70, data load time: 0.00292, step time: 0.12754
# epoch: [3], step: [52/189], batch loss: 0.55625, batch accuracy: 70.31, data load time: 0.00292, step time: 0.12578
# epoch: [3], step: [62/189], batch loss: 0.52211, batch accuracy: 73.05, data load time: 0.00297, step time: 0.12798
# epoch: [3], step: [72/189], batch loss: 0.50751, batch accuracy: 73.05, data load time: 0.00293, step time: 0.12635
# epoch: [3], step: [82/189], batch loss: 0.52096, batch accuracy: 72.66, data load time: 0.00291, step time: 0.12789
# epoch: [3], step: [92/189], batch loss: 0.51449, batch accuracy: 71.48, data load time: 0.00318, step time: 0.12927
# epoch: [3], step: [102/189], batch loss: 0.55687, batch accuracy: 70.70, data load time: 0.00291, step time: 0.12755
# epoch: [3], step: [112/189], batch loss: 0.52776, batch accuracy: 69.92, data load time: 0.00312, step time: 0.12620
# epoch: [3], step: [122/189], batch loss: 0.47191, batch accuracy: 75.39, data load time: 0.00285, step time: 0.12851
# epoch: [3], step: [132/189], batch loss: 0.48786, batch accuracy: 73.05, data load time: 0.00291, step time: 0.13002
# epoch: [3], step: [142/189], batch loss: 0.52873, batch accuracy: 67.58, data load time: 0.00317, step time: 0.12772
# epoch: [3], step: [152/189], batch loss: 0.52556, batch accuracy: 67.97, data load time: 0.00302, step time: 0.12737
# epoch: [3], step: [162/189], batch loss: 0.52581, batch accuracy: 72.27, data load time: 0.00303, step time: 0.12848
# epoch: [3], step: [172/189], batch loss: 0.48124, batch accuracy: 71.48, data load time: 0.00287, step time: 0.12801
# epoch: [3], step: [182/189], batch loss: 0.51624, batch accuracy: 71.88, data load time: 0.00324, step time: 0.12874
# epoch: [4], step: [3/189], batch loss: 0.58653, batch accuracy: 63.67, data load time: 0.00293, step time: 0.12954
# epoch: [4], step: [13/189], batch loss: 0.53564, batch accuracy: 71.48, data load time: 0.00304, step time: 0.12722
# epoch: [4], step: [23/189], batch loss: 0.52931, batch accuracy: 71.48, data load time: 0.00304, step time: 0.12770
# epoch: [4], step: [33/189], batch loss: 0.53968, batch accuracy: 69.14, data load time: 0.00296, step time: 0.12815
# epoch: [4], step: [43/189], batch loss: 0.52173, batch accuracy: 70.31, data load time: 0.00304, step time: 0.12813
# epoch: [4], step: [53/189], batch loss: 0.50978, batch accuracy: 73.83, data load time: 0.00303, step time: 0.12738
# epoch: [4], step: [63/189], batch loss: 0.52187, batch accuracy: 72.66, data load time: 0.00302, step time: 0.12866
# epoch: [4], step: [73/189], batch loss: 0.48848, batch accuracy: 72.27, data load time: 0.00298, step time: 0.12718
# epoch: [4], step: [83/189], batch loss: 0.49689, batch accuracy: 73.05, data load time: 0.00300, step time: 0.12945
# epoch: [4], step: [93/189], batch loss: 0.48769, batch accuracy: 71.09, data load time: 0.00303, step time: 0.12935
# epoch: [4], step: [103/189], batch loss: 0.55341, batch accuracy: 68.36, data load time: 0.00333, step time: 0.12906
# epoch: [4], step: [113/189], batch loss: 0.48680, batch accuracy: 69.92, data load time: 0.00313, step time: 0.12884
# epoch: [4], step: [123/189], batch loss: 0.52472, batch accuracy: 69.14, data load time: 0.00315, step time: 0.12830
# epoch: [4], step: [133/189], batch loss: 0.51851, batch accuracy: 68.75, data load time: 0.00300, step time: 0.12805
# epoch: [4], step: [143/189], batch loss: 0.50828, batch accuracy: 73.05, data load time: 0.00303, step time: 0.12890
# epoch: [4], step: [153/189], batch loss: 0.54178, batch accuracy: 68.75, data load time: 0.00307, step time: 0.12925
# epoch: [4], step: [163/189], batch loss: 0.50409, batch accuracy: 67.97, data load time: 0.00310, step time: 0.12838
# epoch: [4], step: [173/189], batch loss: 0.51825, batch accuracy: 71.48, data load time: 0.00324, step time: 0.12846
# epoch: [4], step: [183/189], batch loss: 0.52950, batch accuracy: 71.09, data load time: 0.00305, step time: 0.12863
# epoch: [5], step: [4/189], batch loss: 0.49622, batch accuracy: 73.05, data load time: 0.00301, step time: 0.12911
# epoch: [5], step: [14/189], batch loss: 0.51644, batch accuracy: 71.88, data load time: 0.00305, step time: 0.12861
# epoch: [5], step: [24/189], batch loss: 0.49409, batch accuracy: 75.00, data load time: 0.00318, step time: 0.12950
# epoch: [5], step: [34/189], batch loss: 0.48689, batch accuracy: 71.88, data load time: 0.00333, step time: 0.12884
# epoch: [5], step: [44/189], batch loss: 0.50207, batch accuracy: 72.27, data load time: 0.00306, step time: 0.12875
# epoch: [5], step: [54/189], batch loss: 0.47764, batch accuracy: 71.09, data load time: 0.00305, step time: 0.12883
# epoch: [5], step: [64/189], batch loss: 0.50771, batch accuracy: 69.92, data load time: 0.00322, step time: 0.12898
# epoch: [5], step: [74/189], batch loss: 0.54201, batch accuracy: 69.53, data load time: 0.00296, step time: 0.12850
# epoch: [5], step: [84/189], batch loss: 0.50333, batch accuracy: 73.05, data load time: 0.00305, step time: 0.12797
# epoch: [5], step: [94/189], batch loss: 0.48564, batch accuracy: 69.92, data load time: 0.00301, step time: 0.12942
# epoch: [5], step: [104/189], batch loss: 0.53101, batch accuracy: 71.09, data load time: 0.00309, step time: 0.12945
# epoch: [5], step: [114/189], batch loss: 0.47163, batch accuracy: 76.17, data load time: 0.00303, step time: 0.12891
# epoch: [5], step: [124/189], batch loss: 0.53661, batch accuracy: 71.48, data load time: 0.00312, step time: 0.12849
# epoch: [5], step: [134/189], batch loss: 0.51895, batch accuracy: 72.66, data load time: 0.00314, step time: 0.12903
# epoch: [5], step: [144/189], batch loss: 0.50962, batch accuracy: 68.75, data load time: 0.00311, step time: 0.13013
# epoch: [5], step: [154/189], batch loss: 0.48781, batch accuracy: 72.27, data load time: 0.00304, step time: 0.13061
# epoch: [5], step: [164/189], batch loss: 0.43710, batch accuracy: 74.22, data load time: 0.00303, step time: 0.12903
# epoch: [5], step: [174/189], batch loss: 0.52798, batch accuracy: 70.70, data load time: 0.00338, step time: 0.12831
# epoch: [5], step: [184/189], batch loss: 0.52686, batch accuracy: 72.66, data load time: 0.00309, step time: 0.13002
# epoch: [6], step: [5/189], batch loss: 0.50044, batch accuracy: 71.09, data load time: 0.00303, step time: 0.12964
# epoch: [6], step: [15/189], batch loss: 0.50254, batch accuracy: 67.19, data load time: 0.00314, step time: 0.13042
# epoch: [6], step: [25/189], batch loss: 0.53446, batch accuracy: 65.62, data load time: 0.00319, step time: 0.13019
# epoch: [6], step: [35/189], batch loss: 0.50706, batch accuracy: 74.61, data load time: 0.00302, step time: 0.13009
# epoch: [6], step: [45/189], batch loss: 0.51783, batch accuracy: 71.88, data load time: 0.00307, step time: 0.13060
# epoch: [6], step: [55/189], batch loss: 0.52910, batch accuracy: 74.22, data load time: 0.00301, step time: 0.12934
# epoch: [6], step: [65/189], batch loss: 0.47877, batch accuracy: 72.27, data load time: 0.00321, step time: 0.12814
# epoch: [6], step: [75/189], batch loss: 0.48509, batch accuracy: 71.48, data load time: 0.00301, step time: 0.12903
# epoch: [6], step: [85/189], batch loss: 0.47882, batch accuracy: 76.17, data load time: 0.00311, step time: 0.12913
# epoch: [6], step: [95/189], batch loss: 0.49773, batch accuracy: 73.83, data load time: 0.00309, step time: 0.12936
# epoch: [6], step: [105/189], batch loss: 0.48820, batch accuracy: 72.27, data load time: 0.00341, step time: 0.12959
# epoch: [6], step: [115/189], batch loss: 0.46084, batch accuracy: 73.05, data load time: 0.00335, step time: 0.12970
# epoch: [6], step: [125/189], batch loss: 0.51190, batch accuracy: 71.48, data load time: 0.00314, step time: 0.12853
# epoch: [6], step: [135/189], batch loss: 0.48201, batch accuracy: 79.30, data load time: 0.00299, step time: 0.12994
# epoch: [6], step: [145/189], batch loss: 0.47206, batch accuracy: 72.66, data load time: 0.00330, step time: 0.12913
# epoch: [6], step: [155/189], batch loss: 0.49515, batch accuracy: 71.48, data load time: 0.00310, step time: 0.12865
# epoch: [6], step: [165/189], batch loss: 0.47336, batch accuracy: 73.83, data load time: 0.00293, step time: 0.12907
# epoch: [6], step: [175/189], batch loss: 0.46157, batch accuracy: 74.22, data load time: 0.00339, step time: 0.12857
# epoch: [6], step: [185/189], batch loss: 0.54556, batch accuracy: 63.67, data load time: 0.00307, step time: 0.12926
# epoch: [7], step: [6/189], batch loss: 0.47133, batch accuracy: 71.48, data load time: 0.00307, step time: 0.12981
# epoch: [7], step: [16/189], batch loss: 0.51019, batch accuracy: 70.70, data load time: 0.00303, step time: 0.12943
# epoch: [7], step: [26/189], batch loss: 0.44743, batch accuracy: 73.05, data load time: 0.00348, step time: 0.13033
# epoch: [7], step: [36/189], batch loss: 0.48224, batch accuracy: 75.39, data load time: 0.00320, step time: 0.13125
# epoch: [7], step: [46/189], batch loss: 0.47363, batch accuracy: 71.48, data load time: 0.00298, step time: 0.12786
# epoch: [7], step: [56/189], batch loss: 0.47460, batch accuracy: 72.66, data load time: 0.00314, step time: 0.13045
# epoch: [7], step: [66/189], batch loss: 0.41262, batch accuracy: 80.86, data load time: 0.00296, step time: 0.12953
# epoch: [7], step: [76/189], batch loss: 0.50193, batch accuracy: 69.92, data load time: 0.00326, step time: 0.13047
# epoch: [7], step: [86/189], batch loss: 0.47646, batch accuracy: 73.05, data load time: 0.00297, step time: 0.13023
# epoch: [7], step: [96/189], batch loss: 0.43526, batch accuracy: 74.22, data load time: 0.00324, step time: 0.13001
# epoch: [7], step: [106/189], batch loss: 0.52444, batch accuracy: 73.05, data load time: 0.00300, step time: 0.12990
# epoch: [7], step: [116/189], batch loss: 0.48774, batch accuracy: 73.05, data load time: 0.00315, step time: 0.13087
# epoch: [7], step: [126/189], batch loss: 0.49003, batch accuracy: 70.70, data load time: 0.00304, step time: 0.12973
# epoch: [7], step: [136/189], batch loss: 0.54631, batch accuracy: 73.44, data load time: 0.00324, step time: 0.13011
# epoch: [7], step: [146/189], batch loss: 0.46048, batch accuracy: 74.22, data load time: 0.00306, step time: 0.12855
# epoch: [7], step: [156/189], batch loss: 0.44850, batch accuracy: 73.44, data load time: 0.00344, step time: 0.12880
# epoch: [7], step: [166/189], batch loss: 0.51009, batch accuracy: 74.22, data load time: 0.00296, step time: 0.13032
# epoch: [7], step: [176/189], batch loss: 0.45587, batch accuracy: 71.09, data load time: 0.00322, step time: 0.12862
# epoch: [7], step: [186/189], batch loss: 0.48230, batch accuracy: 72.27, data load time: 0.00309, step time: 0.13031
# epoch: [8], step: [7/189], batch loss: 0.50462, batch accuracy: 68.75, data load time: 0.00313, step time: 0.12895
# epoch: [8], step: [17/189], batch loss: 0.53350, batch accuracy: 72.66, data load time: 0.00301, step time: 0.13004
# epoch: [8], step: [27/189], batch loss: 0.45818, batch accuracy: 74.61, data load time: 0.00310, step time: 0.12963
# epoch: [8], step: [37/189], batch loss: 0.49759, batch accuracy: 76.17, data load time: 0.00329, step time: 0.12969
# epoch: [8], step: [47/189], batch loss: 0.50365, batch accuracy: 75.78, data load time: 0.00304, step time: 0.12953
# epoch: [8], step: [57/189], batch loss: 0.51865, batch accuracy: 73.05, data load time: 0.00310, step time: 0.12949
# epoch: [8], step: [67/189], batch loss: 0.44538, batch accuracy: 78.52, data load time: 0.00320, step time: 0.13000
# epoch: [8], step: [77/189], batch loss: 0.44494, batch accuracy: 74.61, data load time: 0.00301, step time: 0.12996
# epoch: [8], step: [87/189], batch loss: 0.56202, batch accuracy: 69.92, data load time: 0.00300, step time: 0.13023
# epoch: [8], step: [97/189], batch loss: 0.54430, batch accuracy: 69.14, data load time: 0.00299, step time: 0.13026
# epoch: [8], step: [107/189], batch loss: 0.49133, batch accuracy: 72.66, data load time: 0.00312, step time: 0.13040
# epoch: [8], step: [117/189], batch loss: 0.48134, batch accuracy: 71.48, data load time: 0.00333, step time: 0.12966
# epoch: [8], step: [127/189], batch loss: 0.51318, batch accuracy: 70.70, data load time: 0.00295, step time: 0.12935
# epoch: [8], step: [137/189], batch loss: 0.45105, batch accuracy: 72.66, data load time: 0.00305, step time: 0.12859
# epoch: [8], step: [147/189], batch loss: 0.42243, batch accuracy: 76.56, data load time: 0.00338, step time: 0.12897
# epoch: [8], step: [157/189], batch loss: 0.49754, batch accuracy: 71.48, data load time: 0.00311, step time: 0.12973
# epoch: [8], step: [167/189], batch loss: 0.44894, batch accuracy: 75.39, data load time: 0.00307, step time: 0.12937
# epoch: [8], step: [177/189], batch loss: 0.47112, batch accuracy: 75.39, data load time: 0.00290, step time: 0.13084
# epoch: [8], step: [187/189], batch loss: 0.45243, batch accuracy: 78.12, data load time: 0.00303, step time: 0.13009
# epoch: [9], step: [8/189], batch loss: 0.48514, batch accuracy: 70.31, data load time: 0.00334, step time: 0.12907
# epoch: [9], step: [18/189], batch loss: 0.49713, batch accuracy: 73.05, data load time: 0.00300, step time: 0.12931
# epoch: [9], step: [28/189], batch loss: 0.48121, batch accuracy: 76.56, data load time: 0.00297, step time: 0.13021
# epoch: [9], step: [38/189], batch loss: 0.52699, batch accuracy: 72.66, data load time: 0.00331, step time: 0.12928
# epoch: [9], step: [48/189], batch loss: 0.45071, batch accuracy: 75.78, data load time: 0.00306, step time: 0.12968
# epoch: [9], step: [58/189], batch loss: 0.43943, batch accuracy: 75.78, data load time: 0.00332, step time: 0.12999
# epoch: [9], step: [68/189], batch loss: 0.47145, batch accuracy: 73.44, data load time: 0.00298, step time: 0.12981
# epoch: [9], step: [78/189], batch loss: 0.50428, batch accuracy: 72.66, data load time: 0.00305, step time: 0.13024
# epoch: [9], step: [88/189], batch loss: 0.48732, batch accuracy: 71.48, data load time: 0.00328, step time: 0.13043
# epoch: [9], step: [98/189], batch loss: 0.47197, batch accuracy: 73.05, data load time: 0.00304, step time: 0.13126
# epoch: [9], step: [108/189], batch loss: 0.48329, batch accuracy: 75.00, data load time: 0.00299, step time: 0.12965
# epoch: [9], step: [118/189], batch loss: 0.52592, batch accuracy: 71.09, data load time: 0.00310, step time: 0.13080
# epoch: [9], step: [128/189], batch loss: 0.49790, batch accuracy: 76.95, data load time: 0.00328, step time: 0.12924
# epoch: [9], step: [138/189], batch loss: 0.45965, batch accuracy: 75.39, data load time: 0.00322, step time: 0.13051
# epoch: [9], step: [148/189], batch loss: 0.47357, batch accuracy: 78.12, data load time: 0.00297, step time: 0.12912
# epoch: [9], step: [158/189], batch loss: 0.43847, batch accuracy: 76.95, data load time: 0.00312, step time: 0.12897
# epoch: [9], step: [168/189], batch loss: 0.47276, batch accuracy: 74.22, data load time: 0.00319, step time: 0.13053
# epoch: [9], step: [178/189], batch loss: 0.41971, batch accuracy: 80.86, data load time: 0.00307, step time: 0.13030
# epoch: [9], step: [188/189], batch loss: 0.39928, batch accuracy: 84.62, data load time: 0.00188, step time: 0.02868
#
# Validating model...
# AUC: 0.7286835073847027 on validation dataset
#
# epoch: [10], step: [9/189], batch loss: 0.49078, batch accuracy: 70.31, data load time: 0.00339, step time: 0.13117
# epoch: [10], step: [19/189], batch loss: 0.46308, batch accuracy: 75.39, data load time: 0.00323, step time: 0.13033
# epoch: [10], step: [29/189], batch loss: 0.44261, batch accuracy: 76.17, data load time: 0.00317, step time: 0.12983
# epoch: [10], step: [39/189], batch loss: 0.45856, batch accuracy: 75.00, data load time: 0.00321, step time: 0.13124
# epoch: [10], step: [49/189], batch loss: 0.47634, batch accuracy: 76.17, data load time: 0.00323, step time: 0.12936
# epoch: [10], step: [59/189], batch loss: 0.39500, batch accuracy: 75.39, data load time: 0.00302, step time: 0.12951
# epoch: [10], step: [69/189], batch loss: 0.46116, batch accuracy: 78.12, data load time: 0.00303, step time: 0.13068
# epoch: [10], step: [79/189], batch loss: 0.46529, batch accuracy: 76.17, data load time: 0.00292, step time: 0.12005
# epoch: [10], step: [89/189], batch loss: 0.44295, batch accuracy: 83.59, data load time: 0.00278, step time: 0.12029
# epoch: [10], step: [99/189], batch loss: 0.47263, batch accuracy: 72.66, data load time: 0.00292, step time: 0.11975
# epoch: [10], step: [109/189], batch loss: 0.46657, batch accuracy: 77.73, data load time: 0.00301, step time: 0.11960
# epoch: [10], step: [119/189], batch loss: 0.39577, batch accuracy: 77.73, data load time: 0.00291, step time: 0.11931
# epoch: [10], step: [129/189], batch loss: 0.43010, batch accuracy: 78.12, data load time: 0.00296, step time: 0.11983
# epoch: [10], step: [139/189], batch loss: 0.46920, batch accuracy: 77.73, data load time: 0.00292, step time: 0.11936
# epoch: [10], step: [149/189], batch loss: 0.43786, batch accuracy: 78.52, data load time: 0.00296, step time: 0.11912
# epoch: [10], step: [159/189], batch loss: 0.39886, batch accuracy: 78.12, data load time: 0.00298, step time: 0.11953
# epoch: [10], step: [169/189], batch loss: 0.46139, batch accuracy: 73.05, data load time: 0.00291, step time: 0.11967
# epoch: [10], step: [179/189], batch loss: 0.48379, batch accuracy: 78.91, data load time: 0.00307, step time: 0.11947
# epoch: [11], step: [0/189], batch loss: 0.43368, batch accuracy: 73.05, data load time: 0.00838, step time: 0.11811
# epoch: [11], step: [10/189], batch loss: 0.48498, batch accuracy: 76.17, data load time: 0.00287, step time: 0.11956
# epoch: [11], step: [20/189], batch loss: 0.46880, batch accuracy: 76.17, data load time: 0.00294, step time: 0.11926
# epoch: [11], step: [30/189], batch loss: 0.41945, batch accuracy: 78.12, data load time: 0.00298, step time: 0.11991
# epoch: [11], step: [40/189], batch loss: 0.44951, batch accuracy: 80.47, data load time: 0.00307, step time: 0.11980
# epoch: [11], step: [50/189], batch loss: 0.41947, batch accuracy: 81.25, data load time: 0.00302, step time: 0.11934
# epoch: [11], step: [60/189], batch loss: 0.47440, batch accuracy: 72.27, data load time: 0.00297, step time: 0.11947
# epoch: [11], step: [70/189], batch loss: 0.46483, batch accuracy: 79.69, data load time: 0.00292, step time: 0.11947
# epoch: [11], step: [80/189], batch loss: 0.42573, batch accuracy: 78.12, data load time: 0.00296, step time: 0.12050
# epoch: [11], step: [90/189], batch loss: 0.55261, batch accuracy: 70.31, data load time: 0.00294, step time: 0.11940
# epoch: [11], step: [100/189], batch loss: 0.38967, batch accuracy: 80.08, data load time: 0.00290, step time: 0.11977
# epoch: [11], step: [110/189], batch loss: 0.43964, batch accuracy: 76.56, data load time: 0.00297, step time: 0.11966
# epoch: [11], step: [120/189], batch loss: 0.43576, batch accuracy: 76.17, data load time: 0.00295, step time: 0.11984
# epoch: [11], step: [130/189], batch loss: 0.40781, batch accuracy: 79.69, data load time: 0.00301, step time: 0.11972
# epoch: [11], step: [140/189], batch loss: 0.47522, batch accuracy: 80.08, data load time: 0.00305, step time: 0.11932
# epoch: [11], step: [150/189], batch loss: 0.43743, batch accuracy: 75.39, data load time: 0.00319, step time: 0.11952
# epoch: [11], step: [160/189], batch loss: 0.46087, batch accuracy: 76.17, data load time: 0.00291, step time: 0.11921
# epoch: [11], step: [170/189], batch loss: 0.48560, batch accuracy: 70.70, data load time: 0.00323, step time: 0.11947
# epoch: [11], step: [180/189], batch loss: 0.42875, batch accuracy: 81.25, data load time: 0.00320, step time: 0.11953
# epoch: [12], step: [1/189], batch loss: 0.40689, batch accuracy: 75.39, data load time: 0.00313, step time: 0.11948
# epoch: [12], step: [11/189], batch loss: 0.44561, batch accuracy: 76.95, data load time: 0.00301, step time: 0.11999
# epoch: [12], step: [21/189], batch loss: 0.50801, batch accuracy: 69.92, data load time: 0.00307, step time: 0.11959
# epoch: [12], step: [31/189], batch loss: 0.39993, batch accuracy: 83.20, data load time: 0.00307, step time: 0.11977
# epoch: [12], step: [41/189], batch loss: 0.39779, batch accuracy: 76.56, data load time: 0.00314, step time: 0.11972
# epoch: [12], step: [51/189], batch loss: 0.37735, batch accuracy: 82.03, data load time: 0.00332, step time: 0.12006
# epoch: [12], step: [61/189], batch loss: 0.44438, batch accuracy: 78.91, data load time: 0.00315, step time: 0.11951
# epoch: [12], step: [71/189], batch loss: 0.42571, batch accuracy: 76.17, data load time: 0.00336, step time: 0.12024
# epoch: [12], step: [81/189], batch loss: 0.41497, batch accuracy: 82.42, data load time: 0.00321, step time: 0.11971
# epoch: [12], step: [91/189], batch loss: 0.40698, batch accuracy: 78.91, data load time: 0.00311, step time: 0.11970
# epoch: [12], step: [101/189], batch loss: 0.46392, batch accuracy: 78.12, data load time: 0.00325, step time: 0.11957
# epoch: [12], step: [111/189], batch loss: 0.46087, batch accuracy: 76.17, data load time: 0.00317, step time: 0.12093
# epoch: [12], step: [121/189], batch loss: 0.41699, batch accuracy: 80.08, data load time: 0.00310, step time: 0.12036
# epoch: [12], step: [131/189], batch loss: 0.44571, batch accuracy: 77.34, data load time: 0.00320, step time: 0.11948
# epoch: [12], step: [141/189], batch loss: 0.41660, batch accuracy: 80.86, data load time: 0.00322, step time: 0.11987
# epoch: [12], step: [151/189], batch loss: 0.38564, batch accuracy: 80.08, data load time: 0.00321, step time: 0.11994
# epoch: [12], step: [161/189], batch loss: 0.37845, batch accuracy: 80.47, data load time: 0.00326, step time: 0.12001
# epoch: [12], step: [171/189], batch loss: 0.40383, batch accuracy: 82.81, data load time: 0.00319, step time: 0.11982
# epoch: [12], step: [181/189], batch loss: 0.37379, batch accuracy: 84.77, data load time: 0.00320, step time: 0.11982
# epoch: [13], step: [2/189], batch loss: 0.36903, batch accuracy: 80.47, data load time: 0.00325, step time: 0.11967
# epoch: [13], step: [12/189], batch loss: 0.40367, batch accuracy: 78.91, data load time: 0.00301, step time: 0.12055
# epoch: [13], step: [22/189], batch loss: 0.47535, batch accuracy: 75.00, data load time: 0.00272, step time: 0.11948
# epoch: [13], step: [32/189], batch loss: 0.39597, batch accuracy: 78.91, data load time: 0.00293, step time: 0.11977
# epoch: [13], step: [42/189], batch loss: 0.43580, batch accuracy: 75.39, data load time: 0.00326, step time: 0.11975
# epoch: [13], step: [52/189], batch loss: 0.45205, batch accuracy: 81.64, data load time: 0.00290, step time: 0.11987
# epoch: [13], step: [62/189], batch loss: 0.42494, batch accuracy: 76.95, data load time: 0.00304, step time: 0.11966
# epoch: [13], step: [72/189], batch loss: 0.46192, batch accuracy: 71.88, data load time: 0.00279, step time: 0.12002
# epoch: [13], step: [82/189], batch loss: 0.43126, batch accuracy: 77.73, data load time: 0.00292, step time: 0.11956
# epoch: [13], step: [92/189], batch loss: 0.40515, batch accuracy: 73.05, data load time: 0.00323, step time: 0.11976
# epoch: [13], step: [102/189], batch loss: 0.37687, batch accuracy: 83.59, data load time: 0.00317, step time: 0.12001
# epoch: [13], step: [112/189], batch loss: 0.44175, batch accuracy: 78.52, data load time: 0.00291, step time: 0.11967
# epoch: [13], step: [122/189], batch loss: 0.47579, batch accuracy: 80.08, data load time: 0.00308, step time: 0.11930
# epoch: [13], step: [132/189], batch loss: 0.43773, batch accuracy: 79.69, data load time: 0.00320, step time: 0.11962
# epoch: [13], step: [142/189], batch loss: 0.44686, batch accuracy: 76.56, data load time: 0.00303, step time: 0.12034
# epoch: [13], step: [152/189], batch loss: 0.40094, batch accuracy: 78.91, data load time: 0.00308, step time: 0.12029
# epoch: [13], step: [162/189], batch loss: 0.41579, batch accuracy: 83.98, data load time: 0.00322, step time: 0.11988
# epoch: [13], step: [172/189], batch loss: 0.47672, batch accuracy: 75.00, data load time: 0.00318, step time: 0.11980
# epoch: [13], step: [182/189], batch loss: 0.38022, batch accuracy: 81.64, data load time: 0.00317, step time: 0.12006
# epoch: [14], step: [3/189], batch loss: 0.40303, batch accuracy: 79.69, data load time: 0.00287, step time: 0.12042
# epoch: [14], step: [13/189], batch loss: 0.39954, batch accuracy: 78.12, data load time: 0.00292, step time: 0.12005
# epoch: [14], step: [23/189], batch loss: 0.33088, batch accuracy: 86.72, data load time: 0.00293, step time: 0.11986
# epoch: [14], step: [33/189], batch loss: 0.36610, batch accuracy: 82.03, data load time: 0.00279, step time: 0.12022
# epoch: [14], step: [43/189], batch loss: 0.42332, batch accuracy: 79.30, data load time: 0.00331, step time: 0.12081
# epoch: [14], step: [53/189], batch loss: 0.38822, batch accuracy: 81.25, data load time: 0.00320, step time: 0.11930
# epoch: [14], step: [63/189], batch loss: 0.35689, batch accuracy: 83.98, data load time: 0.00318, step time: 0.11979
# epoch: [14], step: [73/189], batch loss: 0.33863, batch accuracy: 83.20, data load time: 0.00316, step time: 0.11931
# epoch: [14], step: [83/189], batch loss: 0.37292, batch accuracy: 82.81, data load time: 0.00318, step time: 0.11936
# epoch: [14], step: [93/189], batch loss: 0.49491, batch accuracy: 71.09, data load time: 0.00311, step time: 0.11964
# epoch: [14], step: [103/189], batch loss: 0.35893, batch accuracy: 83.98, data load time: 0.00315, step time: 0.11999
# epoch: [14], step: [113/189], batch loss: 0.35724, batch accuracy: 83.98, data load time: 0.00312, step time: 0.11992
# epoch: [14], step: [123/189], batch loss: 0.43799, batch accuracy: 77.73, data load time: 0.00321, step time: 0.11943
# epoch: [14], step: [133/189], batch loss: 0.39306, batch accuracy: 85.55, data load time: 0.00310, step time: 0.12032
# epoch: [14], step: [143/189], batch loss: 0.36781, batch accuracy: 78.91, data load time: 0.00302, step time: 0.11951
# epoch: [14], step: [153/189], batch loss: 0.37091, batch accuracy: 83.98, data load time: 0.00316, step time: 0.11968
# epoch: [14], step: [163/189], batch loss: 0.36744, batch accuracy: 83.98, data load time: 0.00293, step time: 0.11937
# epoch: [14], step: [173/189], batch loss: 0.37409, batch accuracy: 83.59, data load time: 0.00300, step time: 0.12050
# epoch: [14], step: [183/189], batch loss: 0.38427, batch accuracy: 83.98, data load time: 0.00325, step time: 0.11956
# epoch: [15], step: [4/189], batch loss: 0.36104, batch accuracy: 81.25, data load time: 0.00328, step time: 0.11946
# epoch: [15], step: [14/189], batch loss: 0.34881, batch accuracy: 79.69, data load time: 0.00314, step time: 0.12031
# epoch: [15], step: [24/189], batch loss: 0.32538, batch accuracy: 86.72, data load time: 0.00347, step time: 0.12036
# epoch: [15], step: [34/189], batch loss: 0.33521, batch accuracy: 82.03, data load time: 0.00312, step time: 0.12019
# epoch: [15], step: [44/189], batch loss: 0.43695, batch accuracy: 79.30, data load time: 0.00316, step time: 0.12014
# epoch: [15], step: [54/189], batch loss: 0.36839, batch accuracy: 82.42, data load time: 0.00296, step time: 0.11965
# epoch: [15], step: [64/189], batch loss: 0.33897, batch accuracy: 86.33, data load time: 0.00317, step time: 0.11992
# epoch: [15], step: [74/189], batch loss: 0.37603, batch accuracy: 82.03, data load time: 0.00306, step time: 0.12054
# epoch: [15], step: [84/189], batch loss: 0.31692, batch accuracy: 82.81, data load time: 0.00318, step time: 0.11949
# epoch: [15], step: [94/189], batch loss: 0.26799, batch accuracy: 87.11, data load time: 0.00287, step time: 0.11982
# epoch: [15], step: [104/189], batch loss: 0.32432, batch accuracy: 85.94, data load time: 0.00289, step time: 0.11989
# epoch: [15], step: [114/189], batch loss: 0.32627, batch accuracy: 83.98, data load time: 0.00298, step time: 0.12005
# epoch: [15], step: [124/189], batch loss: 0.32105, batch accuracy: 82.03, data load time: 0.00301, step time: 0.12015
# epoch: [15], step: [134/189], batch loss: 0.34752, batch accuracy: 81.64, data load time: 0.00299, step time: 0.11992
# epoch: [15], step: [144/189], batch loss: 0.28409, batch accuracy: 86.33, data load time: 0.00290, step time: 0.12022
# epoch: [15], step: [154/189], batch loss: 0.30498, batch accuracy: 84.77, data load time: 0.00290, step time: 0.11961
# epoch: [15], step: [164/189], batch loss: 0.34894, batch accuracy: 85.16, data load time: 0.00286, step time: 0.12064
# epoch: [15], step: [174/189], batch loss: 0.31355, batch accuracy: 83.59, data load time: 0.00291, step time: 0.11986
# epoch: [15], step: [184/189], batch loss: 0.29997, batch accuracy: 84.38, data load time: 0.00294, step time: 0.12033
# epoch: [16], step: [5/189], batch loss: 0.36820, batch accuracy: 87.50, data load time: 0.00307, step time: 0.11981
# epoch: [16], step: [15/189], batch loss: 0.43296, batch accuracy: 74.61, data load time: 0.00293, step time: 0.12018
# epoch: [16], step: [25/189], batch loss: 0.32108, batch accuracy: 86.72, data load time: 0.00296, step time: 0.12026
# epoch: [16], step: [35/189], batch loss: 0.36497, batch accuracy: 85.94, data load time: 0.00289, step time: 0.12004
# epoch: [16], step: [45/189], batch loss: 0.34713, batch accuracy: 82.81, data load time: 0.00304, step time: 0.11975
# epoch: [16], step: [55/189], batch loss: 0.28378, batch accuracy: 87.11, data load time: 0.00302, step time: 0.12001
# epoch: [16], step: [65/189], batch loss: 0.31152, batch accuracy: 85.55, data load time: 0.00307, step time: 0.12039
# epoch: [16], step: [75/189], batch loss: 0.31780, batch accuracy: 86.33, data load time: 0.00314, step time: 0.11966
# epoch: [16], step: [85/189], batch loss: 0.26451, batch accuracy: 87.11, data load time: 0.00327, step time: 0.11968
# epoch: [16], step: [95/189], batch loss: 0.33188, batch accuracy: 84.77, data load time: 0.00312, step time: 0.11980
# epoch: [16], step: [105/189], batch loss: 0.33223, batch accuracy: 86.72, data load time: 0.00324, step time: 0.12083
# epoch: [16], step: [115/189], batch loss: 0.37877, batch accuracy: 82.81, data load time: 0.00295, step time: 0.12011
# epoch: [16], step: [125/189], batch loss: 0.30848, batch accuracy: 83.20, data load time: 0.00312, step time: 0.11979
# epoch: [16], step: [135/189], batch loss: 0.23934, batch accuracy: 89.84, data load time: 0.00303, step time: 0.11984
# epoch: [16], step: [145/189], batch loss: 0.27912, batch accuracy: 88.28, data load time: 0.00308, step time: 0.11987
# epoch: [16], step: [155/189], batch loss: 0.25667, batch accuracy: 91.02, data load time: 0.00306, step time: 0.12023
# epoch: [16], step: [165/189], batch loss: 0.30855, batch accuracy: 86.33, data load time: 0.00315, step time: 0.11984
# epoch: [16], step: [175/189], batch loss: 0.34405, batch accuracy: 83.59, data load time: 0.00314, step time: 0.11976
# epoch: [16], step: [185/189], batch loss: 0.29804, batch accuracy: 87.50, data load time: 0.00320, step time: 0.11999
# epoch: [17], step: [6/189], batch loss: 0.30197, batch accuracy: 89.45, data load time: 0.00322, step time: 0.11992
# epoch: [17], step: [16/189], batch loss: 0.34661, batch accuracy: 76.95, data load time: 0.00302, step time: 0.11993
# epoch: [17], step: [26/189], batch loss: 0.32232, batch accuracy: 87.89, data load time: 0.00291, step time: 0.11972
# epoch: [17], step: [36/189], batch loss: 0.26220, batch accuracy: 86.72, data load time: 0.00298, step time: 0.12015
# epoch: [17], step: [46/189], batch loss: 0.28419, batch accuracy: 85.16, data load time: 0.00296, step time: 0.12047
# epoch: [17], step: [56/189], batch loss: 0.26318, batch accuracy: 90.23, data load time: 0.00297, step time: 0.12008
# epoch: [17], step: [66/189], batch loss: 0.29644, batch accuracy: 86.33, data load time: 0.00300, step time: 0.12030
# epoch: [17], step: [76/189], batch loss: 0.30231, batch accuracy: 86.72, data load time: 0.00290, step time: 0.11996
# epoch: [17], step: [86/189], batch loss: 0.28916, batch accuracy: 90.23, data load time: 0.00299, step time: 0.12021
# epoch: [17], step: [96/189], batch loss: 0.29697, batch accuracy: 81.25, data load time: 0.00318, step time: 0.12117
# epoch: [17], step: [106/189], batch loss: 0.29302, batch accuracy: 88.67, data load time: 0.00286, step time: 0.12068
# epoch: [17], step: [116/189], batch loss: 0.30353, batch accuracy: 85.94, data load time: 0.00307, step time: 0.11997
# epoch: [17], step: [126/189], batch loss: 0.31757, batch accuracy: 89.06, data load time: 0.00294, step time: 0.11979
# epoch: [17], step: [136/189], batch loss: 0.34152, batch accuracy: 82.03, data load time: 0.00294, step time: 0.12057
# epoch: [17], step: [146/189], batch loss: 0.26900, batch accuracy: 86.72, data load time: 0.00285, step time: 0.11980
# epoch: [17], step: [156/189], batch loss: 0.25797, batch accuracy: 85.94, data load time: 0.00297, step time: 0.12022
# epoch: [17], step: [166/189], batch loss: 0.22876, batch accuracy: 91.80, data load time: 0.00296, step time: 0.12030
# epoch: [17], step: [176/189], batch loss: 0.25218, batch accuracy: 86.33, data load time: 0.00301, step time: 0.11973
# epoch: [17], step: [186/189], batch loss: 0.27764, batch accuracy: 85.55, data load time: 0.00299, step time: 0.12001
# epoch: [18], step: [7/189], batch loss: 0.28099, batch accuracy: 86.72, data load time: 0.00289, step time: 0.12007
# epoch: [18], step: [17/189], batch loss: 0.27042, batch accuracy: 89.06, data load time: 0.00297, step time: 0.12028
# epoch: [18], step: [27/189], batch loss: 0.26475, batch accuracy: 88.28, data load time: 0.00295, step time: 0.12039
# epoch: [18], step: [37/189], batch loss: 0.20232, batch accuracy: 93.36, data load time: 0.00289, step time: 0.12069
# epoch: [18], step: [47/189], batch loss: 0.23750, batch accuracy: 91.41, data load time: 0.00308, step time: 0.11955
# epoch: [18], step: [57/189], batch loss: 0.29311, batch accuracy: 87.50, data load time: 0.00327, step time: 0.12010
# epoch: [18], step: [67/189], batch loss: 0.28635, batch accuracy: 85.55, data load time: 0.00328, step time: 0.11995
# epoch: [18], step: [77/189], batch loss: 0.25521, batch accuracy: 89.45, data load time: 0.00296, step time: 0.11994
# epoch: [18], step: [87/189], batch loss: 0.22975, batch accuracy: 90.62, data load time: 0.00313, step time: 0.11991
# epoch: [18], step: [97/189], batch loss: 0.24899, batch accuracy: 89.84, data load time: 0.00308, step time: 0.12032
# epoch: [18], step: [107/189], batch loss: 0.21632, batch accuracy: 94.14, data load time: 0.00297, step time: 0.11997
# epoch: [18], step: [117/189], batch loss: 0.31818, batch accuracy: 82.42, data load time: 0.00298, step time: 0.11978
# epoch: [18], step: [127/189], batch loss: 0.31502, batch accuracy: 86.33, data load time: 0.00302, step time: 0.12094
# epoch: [18], step: [137/189], batch loss: 0.18872, batch accuracy: 91.02, data load time: 0.00296, step time: 0.11996
# epoch: [18], step: [147/189], batch loss: 0.23638, batch accuracy: 93.36, data load time: 0.00293, step time: 0.12017
# epoch: [18], step: [157/189], batch loss: 0.18606, batch accuracy: 91.02, data load time: 0.00294, step time: 0.12022
# epoch: [18], step: [167/189], batch loss: 0.18974, batch accuracy: 92.97, data load time: 0.00303, step time: 0.12064
# epoch: [18], step: [177/189], batch loss: 0.21782, batch accuracy: 89.84, data load time: 0.00300, step time: 0.11983
# epoch: [18], step: [187/189], batch loss: 0.20614, batch accuracy: 89.45, data load time: 0.00300, step time: 0.12020
# epoch: [19], step: [8/189], batch loss: 0.21600, batch accuracy: 92.97, data load time: 0.00291, step time: 0.12031
# epoch: [19], step: [18/189], batch loss: 0.17878, batch accuracy: 93.75, data load time: 0.00292, step time: 0.12032
# epoch: [19], step: [28/189], batch loss: 0.18994, batch accuracy: 93.75, data load time: 0.00304, step time: 0.12106
# epoch: [19], step: [38/189], batch loss: 0.19925, batch accuracy: 90.62, data load time: 0.00307, step time: 0.12002
# epoch: [19], step: [48/189], batch loss: 0.23042, batch accuracy: 90.62, data load time: 0.00301, step time: 0.12049
# epoch: [19], step: [58/189], batch loss: 0.19912, batch accuracy: 91.02, data load time: 0.00318, step time: 0.11944
# epoch: [19], step: [68/189], batch loss: 0.16804, batch accuracy: 91.41, data load time: 0.00310, step time: 0.12093
# epoch: [19], step: [78/189], batch loss: 0.20899, batch accuracy: 92.97, data load time: 0.00302, step time: 0.12012
# epoch: [19], step: [88/189], batch loss: 0.20419, batch accuracy: 89.06, data load time: 0.00294, step time: 0.11993
# epoch: [19], step: [98/189], batch loss: 0.24919, batch accuracy: 86.33, data load time: 0.00304, step time: 0.12005
# epoch: [19], step: [108/189], batch loss: 0.25072, batch accuracy: 92.97, data load time: 0.00309, step time: 0.11944
# epoch: [19], step: [118/189], batch loss: 0.22371, batch accuracy: 88.28, data load time: 0.00314, step time: 0.11969
# epoch: [19], step: [128/189], batch loss: 0.22017, batch accuracy: 90.23, data load time: 0.00302, step time: 0.11971
# epoch: [19], step: [138/189], batch loss: 0.18933, batch accuracy: 93.75, data load time: 0.00364, step time: 0.11998
# epoch: [19], step: [148/189], batch loss: 0.21498, batch accuracy: 89.06, data load time: 0.00318, step time: 0.11983
# epoch: [19], step: [158/189], batch loss: 0.15252, batch accuracy: 94.53, data load time: 0.00316, step time: 0.12041
# epoch: [19], step: [168/189], batch loss: 0.14500, batch accuracy: 94.14, data load time: 0.00294, step time: 0.11982
# epoch: [19], step: [178/189], batch loss: 0.25855, batch accuracy: 86.72, data load time: 0.00299, step time: 0.12022
# epoch: [19], step: [188/189], batch loss: 0.18287, batch accuracy: 86.54, data load time: 0.00193, step time: 0.02598
#
# Validating model...
# AUC: 0.8575072503871596 on validation dataset
#
# epoch: [20], step: [9/189], batch loss: 0.13624, batch accuracy: 93.36, data load time: 0.00291, step time: 0.11957
# epoch: [20], step: [19/189], batch loss: 0.13997, batch accuracy: 94.92, data load time: 0.00312, step time: 0.11944
# epoch: [20], step: [29/189], batch loss: 0.16214, batch accuracy: 94.53, data load time: 0.00294, step time: 0.11961
# epoch: [20], step: [39/189], batch loss: 0.13282, batch accuracy: 94.14, data load time: 0.00288, step time: 0.11969
# epoch: [20], step: [49/189], batch loss: 0.11378, batch accuracy: 96.88, data load time: 0.00329, step time: 0.11972
# epoch: [20], step: [59/189], batch loss: 0.13271, batch accuracy: 94.53, data load time: 0.00320, step time: 0.12070
# epoch: [20], step: [69/189], batch loss: 0.13369, batch accuracy: 96.09, data load time: 0.00310, step time: 0.11954
# epoch: [20], step: [79/189], batch loss: 0.19914, batch accuracy: 95.31, data load time: 0.00314, step time: 0.11950
# epoch: [20], step: [89/189], batch loss: 0.21502, batch accuracy: 89.45, data load time: 0.00301, step time: 0.11997
# epoch: [20], step: [99/189], batch loss: 0.17170, batch accuracy: 91.41, data load time: 0.00299, step time: 0.11933
# epoch: [20], step: [109/189], batch loss: 0.21903, batch accuracy: 91.80, data load time: 0.00304, step time: 0.11986
# epoch: [20], step: [119/189], batch loss: 0.20100, batch accuracy: 92.58, data load time: 0.00318, step time: 0.11964
# epoch: [20], step: [129/189], batch loss: 0.16264, batch accuracy: 89.06, data load time: 0.00291, step time: 0.11982
# epoch: [20], step: [139/189], batch loss: 0.14160, batch accuracy: 92.97, data load time: 0.00301, step time: 0.11948
# epoch: [20], step: [149/189], batch loss: 0.19394, batch accuracy: 92.97, data load time: 0.00298, step time: 0.11987
# epoch: [20], step: [159/189], batch loss: 0.18116, batch accuracy: 92.58, data load time: 0.00321, step time: 0.11989
# epoch: [20], step: [169/189], batch loss: 0.16669, batch accuracy: 92.58, data load time: 0.00317, step time: 0.11961
# epoch: [20], step: [179/189], batch loss: 0.29600, batch accuracy: 89.06, data load time: 0.00297, step time: 0.11968
# epoch: [21], step: [0/189], batch loss: 0.16960, batch accuracy: 92.19, data load time: 0.00865, step time: 0.11831
# epoch: [21], step: [10/189], batch loss: 0.16414, batch accuracy: 96.09, data load time: 0.00329, step time: 0.11962
# epoch: [21], step: [20/189], batch loss: 0.17421, batch accuracy: 95.70, data load time: 0.00319, step time: 0.11942
# epoch: [21], step: [30/189], batch loss: 0.16906, batch accuracy: 93.75, data load time: 0.00309, step time: 0.11953
# epoch: [21], step: [40/189], batch loss: 0.15540, batch accuracy: 94.14, data load time: 0.00317, step time: 0.11970
# epoch: [21], step: [50/189], batch loss: 0.09950, batch accuracy: 98.05, data load time: 0.00324, step time: 0.12063
# epoch: [21], step: [60/189], batch loss: 0.14503, batch accuracy: 93.36, data load time: 0.00326, step time: 0.11955
# epoch: [21], step: [70/189], batch loss: 0.11007, batch accuracy: 96.09, data load time: 0.00323, step time: 0.11917
# epoch: [21], step: [80/189], batch loss: 0.14226, batch accuracy: 91.41, data load time: 0.00314, step time: 0.12004
# ...
# epoch: [14], step: [173/189], batch loss: 0.37492, batch accuracy: 78.91, data load time: 0.00309, step time: 0.13048
# epoch: [14], step: [183/189], batch loss: 0.29982, batch accuracy: 84.38, data load time: 0.00312, step time: 0.13075
# epoch: [15], step: [4/189], batch loss: 0.32120, batch accuracy: 85.94, data load time: 0.00299, step time: 0.13025
# epoch: [15], step: [14/189], batch loss: 0.30485, batch accuracy: 89.06, data load time: 0.00316, step time: 0.13170
# epoch: [15], step: [24/189], batch loss: 0.24787, batch accuracy: 89.06, data load time: 0.00296, step time: 0.12962
# epoch: [15], step: [34/189], batch loss: 0.29246, batch accuracy: 86.33, data load time: 0.00338, step time: 0.13003
# epoch: [15], step: [44/189], batch loss: 0.31107, batch accuracy: 83.59, data load time: 0.00303, step time: 0.13074
# epoch: [15], step: [54/189], batch loss: 0.26047, batch accuracy: 89.84, data load time: 0.00300, step time: 0.12973
# epoch: [15], step: [64/189], batch loss: 0.26796, batch accuracy: 89.45, data load time: 0.00315, step time: 0.12930
# epoch: [15], step: [74/189], batch loss: 0.26872, batch accuracy: 86.33, data load time: 0.00297, step time: 0.13074
# epoch: [15], step: [84/189], batch loss: 0.23594, batch accuracy: 90.23, data load time: 0.00324, step time: 0.13202
# epoch: [15], step: [94/189], batch loss: 0.28169, batch accuracy: 83.20, data load time: 0.00301, step time: 0.13114
# epoch: [15], step: [104/189], batch loss: 0.24741, batch accuracy: 91.02, data load time: 0.00378, step time: 0.12996
# epoch: [15], step: [114/189], batch loss: 0.26139, batch accuracy: 88.28, data load time: 0.00291, step time: 0.12972
# epoch: [15], step: [124/189], batch loss: 0.24010, batch accuracy: 85.94, data load time: 0.00322, step time: 0.13088
# epoch: [15], step: [134/189], batch loss: 0.27623, batch accuracy: 86.33, data load time: 0.00320, step time: 0.13025
# epoch: [15], step: [144/189], batch loss: 0.26852, batch accuracy: 87.50, data load time: 0.00325, step time: 0.13076
# epoch: [15], step: [154/189], batch loss: 0.23720, batch accuracy: 89.45, data load time: 0.00331, step time: 0.13047
# epoch: [15], step: [164/189], batch loss: 0.22755, batch accuracy: 91.41, data load time: 0.00296, step time: 0.12997
# epoch: [15], step: [174/189], batch loss: 0.22716, batch accuracy: 90.23, data load time: 0.00295, step time: 0.12995
# epoch: [15], step: [184/189], batch loss: 0.24200, batch accuracy: 87.89, data load time: 0.00297, step time: 0.12943
# epoch: [16], step: [5/189], batch loss: 0.26756, batch accuracy: 89.45, data load time: 0.00341, step time: 0.12985
# epoch: [16], step: [15/189], batch loss: 0.25612, batch accuracy: 90.23, data load time: 0.00341, step time: 0.13099
# epoch: [16], step: [25/189], batch loss: 0.22260, batch accuracy: 88.67, data load time: 0.00313, step time: 0.13067
# epoch: [16], step: [35/189], batch loss: 0.26967, batch accuracy: 87.50, data load time: 0.00285, step time: 0.13064
# epoch: [16], step: [45/189], batch loss: 0.28594, batch accuracy: 82.81, data load time: 0.00302, step time: 0.13065
# epoch: [16], step: [55/189], batch loss: 0.24375, batch accuracy: 89.84, data load time: 0.00300, step time: 0.12986
# epoch: [16], step: [65/189], batch loss: 0.22879, batch accuracy: 89.84, data load time: 0.00315, step time: 0.12926
# epoch: [16], step: [75/189], batch loss: 0.24560, batch accuracy: 87.89, data load time: 0.00303, step time: 0.13060
# epoch: [16], step: [85/189], batch loss: 0.26456, batch accuracy: 89.06, data load time: 0.00301, step time: 0.12916
# epoch: [16], step: [95/189], batch loss: 0.23335, batch accuracy: 91.02, data load time: 0.00306, step time: 0.13000
# epoch: [16], step: [105/189], batch loss: 0.21462, batch accuracy: 87.89, data load time: 0.00291, step time: 0.12911
# epoch: [16], step: [115/189], batch loss: 0.23217, batch accuracy: 92.19, data load time: 0.00329, step time: 0.13057
# epoch: [16], step: [125/189], batch loss: 0.18698, batch accuracy: 91.41, data load time: 0.00324, step time: 0.12940
# epoch: [16], step: [135/189], batch loss: 0.24056, batch accuracy: 89.45, data load time: 0.00312, step time: 0.13129
# epoch: [16], step: [145/189], batch loss: 0.27500, batch accuracy: 82.81, data load time: 0.00313, step time: 0.13019
# epoch: [16], step: [155/189], batch loss: 0.25942, batch accuracy: 89.06, data load time: 0.00294, step time: 0.12947
# epoch: [16], step: [165/189], batch loss: 0.25020, batch accuracy: 89.06, data load time: 0.00286, step time: 0.13036
# epoch: [16], step: [175/189], batch loss: 0.24689, batch accuracy: 92.19, data load time: 0.00307, step time: 0.13090
# epoch: [16], step: [185/189], batch loss: 0.27669, batch accuracy: 82.81, data load time: 0.00289, step time: 0.13164
# epoch: [17], step: [6/189], batch loss: 0.27405, batch accuracy: 90.62, data load time: 0.00301, step time: 0.13125
# epoch: [17], step: [16/189], batch loss: 0.18872, batch accuracy: 89.45, data load time: 0.00296, step time: 0.12968
# epoch: [17], step: [26/189], batch loss: 0.20662, batch accuracy: 93.36, data load time: 0.00317, step time: 0.12952
# epoch: [17], step: [36/189], batch loss: 0.18969, batch accuracy: 91.80, data load time: 0.00290, step time: 0.13057
# epoch: [17], step: [46/189], batch loss: 0.21829, batch accuracy: 93.75, data load time: 0.00296, step time: 0.13049
# epoch: [17], step: [56/189], batch loss: 0.27254, batch accuracy: 85.16, data load time: 0.00296, step time: 0.13083
# epoch: [17], step: [66/189], batch loss: 0.28877, batch accuracy: 87.89, data load time: 0.00287, step time: 0.12868
# epoch: [17], step: [76/189], batch loss: 0.26629, batch accuracy: 82.42, data load time: 0.00292, step time: 0.12786
# epoch: [17], step: [86/189], batch loss: 0.30527, batch accuracy: 83.59, data load time: 0.00286, step time: 0.13107
# epoch: [17], step: [96/189], batch loss: 0.19909, batch accuracy: 88.67, data load time: 0.00291, step time: 0.12947
# epoch: [17], step: [106/189], batch loss: 0.20152, batch accuracy: 91.02, data load time: 0.00301, step time: 0.12878
# epoch: [17], step: [116/189], batch loss: 0.24197, batch accuracy: 90.23, data load time: 0.00288, step time: 0.12836
# epoch: [17], step: [126/189], batch loss: 0.25116, batch accuracy: 91.41, data load time: 0.00302, step time: 0.12966
# epoch: [17], step: [136/189], batch loss: 0.18949, batch accuracy: 91.41, data load time: 0.00300, step time: 0.12982
# epoch: [17], step: [146/189], batch loss: 0.15093, batch accuracy: 91.80, data load time: 0.00289, step time: 0.13023
# epoch: [17], step: [156/189], batch loss: 0.17535, batch accuracy: 93.36, data load time: 0.00294, step time: 0.13009
# epoch: [17], step: [166/189], batch loss: 0.17067, batch accuracy: 92.58, data load time: 0.00292, step time: 0.13022
# epoch: [17], step: [176/189], batch loss: 0.17462, batch accuracy: 92.19, data load time: 0.00315, step time: 0.13084
# epoch: [17], step: [186/189], batch loss: 0.16325, batch accuracy: 92.97, data load time: 0.00297, step time: 0.12977
# epoch: [18], step: [7/189], batch loss: 0.17435, batch accuracy: 92.19, data load time: 0.00303, step time: 0.13045
# epoch: [18], step: [17/189], batch loss: 0.19070, batch accuracy: 92.19, data load time: 0.00303, step time: 0.12895
# epoch: [18], step: [27/189], batch loss: 0.18511, batch accuracy: 91.02, data load time: 0.00321, step time: 0.12965
# epoch: [18], step: [37/189], batch loss: 0.13042, batch accuracy: 94.92, data load time: 0.00291, step time: 0.13049
# epoch: [18], step: [47/189], batch loss: 0.20469, batch accuracy: 90.23, data load time: 0.00302, step time: 0.13050
# epoch: [18], step: [57/189], batch loss: 0.14945, batch accuracy: 93.75, data load time: 0.00316, step time: 0.13036
# epoch: [18], step: [67/189], batch loss: 0.19797, batch accuracy: 89.45, data load time: 0.00310, step time: 0.12991
# epoch: [18], step: [77/189], batch loss: 0.17618, batch accuracy: 92.97, data load time: 0.00319, step time: 0.13036
# epoch: [18], step: [87/189], batch loss: 0.13884, batch accuracy: 94.92, data load time: 0.00327, step time: 0.13221
# epoch: [18], step: [97/189], batch loss: 0.20591, batch accuracy: 88.67, data load time: 0.00325, step time: 0.13647
# epoch: [18], step: [107/189], batch loss: 0.11137, batch accuracy: 96.09, data load time: 0.00304, step time: 0.12870
# epoch: [18], step: [117/189], batch loss: 0.20512, batch accuracy: 92.19, data load time: 0.00317, step time: 0.12967
# epoch: [18], step: [127/189], batch loss: 0.23256, batch accuracy: 88.28, data load time: 0.00293, step time: 0.13539
# epoch: [18], step: [137/189], batch loss: 0.17583, batch accuracy: 93.36, data load time: 0.00333, step time: 0.13464
# epoch: [18], step: [147/189], batch loss: 0.15290, batch accuracy: 94.92, data load time: 0.00322, step time: 0.13223
# epoch: [18], step: [157/189], batch loss: 0.13076, batch accuracy: 96.88, data load time: 0.00318, step time: 0.12896
# epoch: [18], step: [167/189], batch loss: 0.11750, batch accuracy: 95.31, data load time: 0.00340, step time: 0.13785
# epoch: [18], step: [177/189], batch loss: 0.12229, batch accuracy: 96.48, data load time: 0.00317, step time: 0.13010
# epoch: [18], step: [187/189], batch loss: 0.08979, batch accuracy: 96.88, data load time: 0.00318, step time: 0.12968
# epoch: [19], step: [8/189], batch loss: 0.13868, batch accuracy: 91.80, data load time: 0.00314, step time: 0.12977
# epoch: [19], step: [18/189], batch loss: 0.14443, batch accuracy: 94.53, data load time: 0.00333, step time: 0.12947
# epoch: [19], step: [28/189], batch loss: 0.10310, batch accuracy: 95.70, data load time: 0.00304, step time: 0.13010
# epoch: [19], step: [38/189], batch loss: 0.13611, batch accuracy: 94.53, data load time: 0.00373, step time: 0.13681
# epoch: [19], step: [48/189], batch loss: 0.13936, batch accuracy: 93.75, data load time: 0.00325, step time: 0.12789
# epoch: [19], step: [58/189], batch loss: 0.18166, batch accuracy: 92.19, data load time: 0.00318, step time: 0.13169
# epoch: [19], step: [68/189], batch loss: 0.11218, batch accuracy: 94.92, data load time: 0.00319, step time: 0.12970
# epoch: [19], step: [78/189], batch loss: 0.11702, batch accuracy: 94.53, data load time: 0.00319, step time: 0.13084
# epoch: [19], step: [88/189], batch loss: 0.12773, batch accuracy: 95.31, data load time: 0.00326, step time: 0.12893
# epoch: [19], step: [98/189], batch loss: 0.10384, batch accuracy: 95.31, data load time: 0.00298, step time: 0.13012
# epoch: [19], step: [108/189], batch loss: 0.18341, batch accuracy: 90.62, data load time: 0.00298, step time: 0.12978
# epoch: [19], step: [118/189], batch loss: 0.17725, batch accuracy: 91.02, data load time: 0.00295, step time: 0.12898
# epoch: [19], step: [128/189], batch loss: 0.13470, batch accuracy: 95.70, data load time: 0.00289, step time: 0.12813
# epoch: [19], step: [138/189], batch loss: 0.11139, batch accuracy: 95.31, data load time: 0.00332, step time: 0.13235
# epoch: [19], step: [148/189], batch loss: 0.13628, batch accuracy: 95.70, data load time: 0.00320, step time: 0.12998
# epoch: [19], step: [158/189], batch loss: 0.13018, batch accuracy: 97.27, data load time: 0.00298, step time: 0.13036
# epoch: [19], step: [168/189], batch loss: 0.15033, batch accuracy: 91.80, data load time: 0.00328, step time: 0.12930
# epoch: [19], step: [178/189], batch loss: 0.13492, batch accuracy: 95.31, data load time: 0.00320, step time: 0.13037
# epoch: [19], step: [188/189], batch loss: 0.10507, batch accuracy: 98.08, data load time: 0.00214, step time: 0.02804
#
# Validating model...
# AUC: 0.8114427837653128 on validation dataset
#
# epoch: [20], step: [9/189], batch loss: 0.10659, batch accuracy: 96.48, data load time: 0.00314, step time: 0.12988
# epoch: [20], step: [19/189], batch loss: 0.11228, batch accuracy: 94.92, data load time: 0.00311, step time: 0.12805
# epoch: [20], step: [29/189], batch loss: 0.12144, batch accuracy: 96.88, data load time: 0.00311, step time: 0.13037
# epoch: [20], step: [39/189], batch loss: 0.10954, batch accuracy: 94.53, data load time: 0.00317, step time: 0.12865
# epoch: [20], step: [49/189], batch loss: 0.07413, batch accuracy: 98.05, data load time: 0.00323, step time: 0.12766
# epoch: [20], step: [59/189], batch loss: 0.09446, batch accuracy: 95.31, data load time: 0.00286, step time: 0.12808
# epoch: [20], step: [69/189], batch loss: 0.10096, batch accuracy: 96.09, data load time: 0.00297, step time: 0.13018
# epoch: [20], step: [79/189], batch loss: 0.10690, batch accuracy: 94.14, data load time: 0.00306, step time: 0.12881
# epoch: [20], step: [89/189], batch loss: 0.07730, batch accuracy: 97.66, data load time: 0.00305, step time: 0.12906
# epoch: [20], step: [99/189], batch loss: 0.13964, batch accuracy: 96.48, data load time: 0.00286, step time: 0.13097
# epoch: [20], step: [109/189], batch loss: 0.10314, batch accuracy: 95.31, data load time: 0.00319, step time: 0.12951
# epoch: [20], step: [119/189], batch loss: 0.10523, batch accuracy: 96.09, data load time: 0.00297, step time: 0.12942
# epoch: [20], step: [129/189], batch loss: 0.12891, batch accuracy: 93.75, data load time: 0.00303, step time: 0.12951
# epoch: [20], step: [139/189], batch loss: 0.15823, batch accuracy: 92.58, data load time: 0.00331, step time: 0.13058
# epoch: [20], step: [149/189], batch loss: 0.17937, batch accuracy: 95.31, data load time: 0.00314, step time: 0.12864
# epoch: [20], step: [159/189], batch loss: 0.11364, batch accuracy: 94.53, data load time: 0.00299, step time: 0.13061
# epoch: [20], step: [169/189], batch loss: 0.13588, batch accuracy: 92.58, data load time: 0.00336, step time: 0.12807
# epoch: [20], step: [179/189], batch loss: 0.12785, batch accuracy: 93.36, data load time: 0.00344, step time: 0.12982
# epoch: [21], step: [0/189], batch loss: 0.11130, batch accuracy: 97.27, data load time: 0.00901, step time: 0.12688
# epoch: [21], step: [10/189], batch loss: 0.08016, batch accuracy: 96.88, data load time: 0.00296, step time: 0.12834
# epoch: [21], step: [20/189], batch loss: 0.10610, batch accuracy: 95.31, data load time: 0.00309, step time: 0.12962
# epoch: [21], step: [30/189], batch loss: 0.07790, batch accuracy: 96.09, data load time: 0.00298, step time: 0.12883
# epoch: [21], step: [40/189], batch loss: 0.09038, batch accuracy: 96.48, data load time: 0.00317, step time: 0.12906
# epoch: [21], step: [50/189], batch loss: 0.07924, batch accuracy: 97.66, data load time: 0.00317, step time: 0.13104
# epoch: [21], step: [60/189], batch loss: 0.09639, batch accuracy: 96.09, data load time: 0.00310, step time: 0.12900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 412
#     410 if __name__ == "__main__":
#     411     args, _ = parser.parse_known_args()
# --> 412     main(args)
#
# Cell In[18], line 140, in main(args)
#     135 trainer = Trainer(
#     136     model, train_loader, test_loader, criterion, optimizer, summary_writer, DEVICE, args
#     137 )
#     139 print("About to train...")
# --> 140 trainer.train(
#     141     args.epochs,
#     142     args.val_frequency,
#     143     print_frequency=args.print_frequency,
#     144     log_frequency=args.log_frequency,
#     145 )
#     146 print("Finished training.")
#     147 summary_writer.close()
#
# Cell In[18], line 225, in Trainer.train(self, epochs, val_frequency, print_frequency, log_frequency, start_epoch)
#     223 with torch.no_grad():
#     224     preds = (logits > 0.5).float()
# --> 225     accuracy = compute_accuracy(labels, preds)
#     227 data_load_time = data_load_end_time - data_load_start_time
#     228 step_time = time.time() - data_load_end_time
#
# Cell In[18], line 378, in compute_accuracy(labels, preds)
#     372 """
#     373 Args:
#     374     labels: ``(batch_size, class_count)`` tensor or array containing example labels
#     375     preds: ``(batch_size, class_count)`` tensor or array containing model prediction
#     376 """
#     377 assert len(labels) == len(preds)
# --> 378 return float((labels == preds).sum()) / len(labels)
#
# KeyboardInterrupt:

# %%
# code for CBAM parts inspired (taken from and modified accordingly) by code at https://github.com/w6688j/CBAM/blob/master/model/resnet_cbam.py
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        # self.fc1   = nn.Conv2d(in_planes, in_planes // ratio, 1, bias=False)
        self.fc1 = nn.Linear(in_planes, in_planes // ratio, bias=False)
        # self.fc2 = nn.Conv2d(in_planes // ratio, in_planes, 1, bias=False)
        self.fc2 = nn.Linear(in_planes // ratio, in_planes, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):

        # print("shapeee", x.shape)
        # import sys ; sys.exit(0)

        avg_out = self.avg_pool(x).squeeze().squeeze()
        avg_out = self.fc1(avg_out)
        avg_out = F.relu(avg_out)
        avg_out = self.fc2(avg_out)

        max_out = self.max_pool(x).squeeze().squeeze()
        max_out = self.fc1(max_out)
        max_out = F.relu(max_out)
        max_out = self.fc2(max_out)

        # avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        # max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))

        out = (avg_out + max_out).unsqueeze(2).unsqueeze(3)
        return self.sigmoid(out)

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super().__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return self.sigmoid(x)




class CNN(nn.Module):
    def __init__(self, height: int, width: int, channels: int, class_count: int, dropout:float):
        super().__init__()
        self.input_shape = ImageShape(height=height, width=width, channels=channels)
        self.class_count = class_count

        self.dropout = nn.Dropout(p=dropout)
        self.dropout2d = nn.Dropout2d(p=dropout)

        # Define 1st Conv, Pool, and BatchNorm
    
        # Conv 1
        self.conv1 = nn.Conv2d(
            in_channels=self.input_shape.channels,
            out_channels=96,
            kernel_size=(7, 7),
            padding= (0,0), #(2, 2),
        )
        self.initialise_layer(self.conv1)
        
        # Pool 1
        self.pool1 = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))

        # BatchNorm 1
        self.batchnorm1 = nn.BatchNorm2d(self.conv1.out_channels)

        # attention 1
        self.ca1 = ChannelAttention(96)
        self.sa1 = SpatialAttention()

        # Define 2nd Conv, Pool, and BatchNorm
        
        # Conv 2
        self.conv2 = nn.Conv2d(
            in_channels=96,
            out_channels=160,
            kernel_size=(3, 3),
            padding= (0,0) #(2, 2)
        )

        self.initialise_layer(self.conv2)
        
        # Pool 2
        self.pool2 = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))

        # BatchNorm 2
        self.batchnorm2 = nn.BatchNorm2d(num_features=self.conv2.out_channels)

        # attention 2
        self.ca2 = ChannelAttention(160)
        self.sa2 = SpatialAttention()
        
        # Define 3rd Conv, Pool, and BatchNorm
        
        # Conv 3
        self.conv3 = nn.Conv2d(
            in_channels=160,
            out_channels=288,
            kernel_size=(3, 3),
            padding= (0,0) #(2, 2)
        )

        self.initialise_layer(self.conv3)
        
        # Pool 3
        self.pool3 = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))

        # BatchNorm 3
        self.batchnorm3 = nn.BatchNorm2d(num_features=self.conv3.out_channels)

        # attention 3
        self.ca3 = ChannelAttention(288)
        self.sa3 = SpatialAttention()


        # Define FC 1

        self.fc1 = nn.Linear(2592, 512)
        self.initialise_layer(self.fc1)

        # BatchNorm layer after first FC layer
        # import pdb; pdb.set_trace()
        self.batchnorm4 = nn.BatchNorm1d(num_features=self.fc1.out_features)

        
        # Define FC 2

        # self.fc2 = nn.Linear(1536, 512)
        self.fc2 = nn.Linear(1536, 512)

        self.initialise_layer(self.fc2)

        # BatchNorm layer after second FC layer

        self.batchnorm5 = nn.BatchNorm1d(num_features=self.fc2.out_features)
        
        # Define FC 3

        self.fc3 = nn.Linear(512, 1)
        self.initialise_layer(self.fc3)

        # BatchNorm layer after third FC layer
        self.batchnorm6 = nn.BatchNorm1d(num_features=self.fc3.out_features)
    
    # FORWARD METHOD
    def forward(self, images: torch.Tensor) -> torch.Tensor:

        batch_size = images.shape[0]

        images = images.reshape(-1, 3, 42, 42)
        
        x = F.relu(self.conv1(images))
        x = self.pool1(x)
        # x = self.batchnorm1(x)

        x = self.ca1(x) * x
        x = self.sa1(x) * x

        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        # x = self.batchnorm2(x)


        x = self.ca2(x) * x
        x = self.sa2(x) * x

        
        x = F.relu(self.conv3(x))
        x = self.pool3(x)
        # x = self.dropout2d(x)
        # x = self.batchnorm3(x)

        # x = x.reshape(-1, 3, 42, 42)

        # print(x.shape)
        # print(x_ca.shape)

        # import sys ; sys.exit(0)

        x = self.ca3(x) * x
        x = self.sa3(x) * x


        # Flatten the output of the pooling layer so it is of shape (batch_size, 4096)
        x = torch.flatten(x, start_dim=1)

        # print(x.shape)
        
        # Pass x through the first fully connected layer
        x = F.relu(self.fc1(x))
        # x = self.dropout(x)
        # x = self.batchnorm4(x)


        x = x.reshape(batch_size, -1)


        # x = self.fc2(xCat)
        x = F.relu(self.fc2(x))
        # x = self.dropout(x)

        # x = self.batchnorm5(x)
        
        x = self.fc3(x)
        #x = self.batchnorm6(x)

        return x

    @staticmethod
    def initialise_layer(layer):
        if hasattr(layer, "bias"):
            nn.init.zeros_(layer.bias)
        if hasattr(layer, "weight"):
            nn.init.kaiming_normal_(layer.weight)

# %% [markdown]
# # Qualitative Analysis

# %%
import os

def list_files_in_directory(directory):
    try:
        # Get the list of all files and directories
        files = os.listdir(directory)

        # Iterate through the list
        for file in files:
            # Join the directory path and file name
            file_path = os.path.join(directory, file)
            # Check if it's a file
            if os.path.isfile(file_path):
                model_file_path = file_path

                trained_model = torch.load(model_file_path)
                trained_model.eval()

                test_preds_dict = get_preds_dict(trained_model, testingdata, DEVICE)
                model_test_auc = calculate_auc(test_preds_dict, test_ground_truth_dict)
                s_auc = calculate_shuffled_auc(test_preds_dict, test_ground_truth_dict)

                print(file)
                print(model_test_auc, s_auc)
                print()
                


    except FileNotFoundError:
        print(f"The directory '{directory}' does not exist.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
directory = "./model/hp_ext"
list_files_in_directory(directory)
# Out:
# /tmp/ipykernel_732741/996030407.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trained_model = torch.load(model_file_path)
# model_val_0.002_128_0.4
# 0.8603213734544561 0.660390984135106
#
# model_val_0.002_256_0.2
# 0.8527955351321332 0.6587440862977507
#
# model_val_0.0002_256_0.3
# 0.8146867855370836 0.720794354561892
#
# model_val_0.0011_256_0.2
# 0.861490089034154 0.6559530914101278
#
# model_val_0.002_128_0.5
# 0.8448479719236006 0.6922655120980175
#
# model_val_0.0002_128_0.3
# 0.8353829979559576 0.6702147128502222
#
# model_val_0.0002_256_0.4
# 0.759294131999566 0.7631514316077646
#
# model_val_0.0002_256_0.5
# 0.7905212358542968 0.7571606251349711
#
# model_val_0.002_128_0.3
# 0.8725779207220471 0.6536392530470913
#
# model_val_0.0002_256_0.2
# 0.7935088601621142 0.73555624967519
#
# model_val_0.0011_256_0.5
# 0.8649260361418353 0.6235759554276767
#
# model_val_0.002_128_0.2
# 0.8813679516136074 0.6587722932558167
#
# model_val_0.002_256_0.4
# 0.8460643001653892 0.6247535850442041
#
# model_val_0.002_256_0.5
# 0.8073881594616624 0.6406983741854231
#
# model_val_0.0011_256_0.4
# 0.8825076929836314 0.5931800410689566
#
# model_val_0.0011_128_0.5
# 0.8335301378348698 0.6378987097069813
#
# model_val_0.0011_128_0.2
# 0.8673414498676142 0.6030634691603822
#
# model_val_0.0011_128_0.3
# 0.853736034836813 0.6267135418258076
#
# model_val_0.002_256_0.3
# 0.8633133585803725 0.6424074764351089
#
# model_val_0.0002_128_0.4
# 0.8368310882614438 0.6551946740880707
#
# model_val_0.0011_256_0.3
# 0.8622204611852436 0.6087892375279566
#
# model_val_0.0002_128_0.5
# 0.8299909052266742 0.7020539420290294
#
# model_val_0.0011_128_0.4
# 0.8774310864727003 0.6534760858627082
#
# model_val_0.0002_128_0.2
# 0.8093174794370624 0.6678255848179997

# %%
# load model

model_file_path1 = "./model/hp_ext/" + "model_val_0.0011_256_0.4"
model_file_path2 = "./model/hp_ext/" + "model_val_0.0002_256_0.4"

trained_model1 = torch.load(model_file_path1)
trained_model1.eval()
trained_model2 = torch.load(model_file_path2)
trained_model2.eval()
# Out:
# /tmp/ipykernel_732741/484157445.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trained_model1 = torch.load(model_file_path1)
# /tmp/ipykernel_732741/484157445.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trained_model2 = torch.load(model_file_path2)
# CNN(
#   (dropout): Dropout(p=0.4, inplace=False)
#   (dropout2d): Dropout2d(p=0.4, inplace=False)
#   (conv1): Conv2d(3, 96, kernel_size=(7, 7), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca1): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=96, out_features=6, bias=False)
#     (fc2): Linear(in_features=6, out_features=96, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa1): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (conv2): Conv2d(96, 160, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca2): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=160, out_features=10, bias=False)
#     (fc2): Linear(in_features=10, out_features=160, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa2): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (conv3): Conv2d(160, 288, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm3): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca3): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=288, out_features=18, bias=False)
#     (fc2): Linear(in_features=18, out_features=288, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa3): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (fc1): Linear(in_features=2592, out_features=512, bias=True)
#   (batchnorm4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1536, out_features=512, bias=True)
#   (batchnorm5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=512, out_features=1, bias=True)
#   (batchnorm6): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
model_file_path3 = "./model/hp_ext/" + "model_val_0.002_128_0.5"
model_file_path4 = "./model/hp_ext/" + "model_val_0.0011_128_0.4"

trained_model3 = torch.load(model_file_path1)
trained_model3.eval()
trained_model4 = torch.load(model_file_path2)
trained_model4.eval()
# Out:
# /tmp/ipykernel_732741/3073785970.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trained_model3 = torch.load(model_file_path1)
# /tmp/ipykernel_732741/3073785970.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trained_model4 = torch.load(model_file_path2)
# CNN(
#   (dropout): Dropout(p=0.4, inplace=False)
#   (dropout2d): Dropout2d(p=0.4, inplace=False)
#   (conv1): Conv2d(3, 96, kernel_size=(7, 7), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca1): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=96, out_features=6, bias=False)
#     (fc2): Linear(in_features=6, out_features=96, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa1): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (conv2): Conv2d(96, 160, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca2): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=160, out_features=10, bias=False)
#     (fc2): Linear(in_features=10, out_features=160, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa2): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (conv3): Conv2d(160, 288, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (batchnorm3): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ca3): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Linear(in_features=288, out_features=18, bias=False)
#     (fc2): Linear(in_features=18, out_features=288, bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa3): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (fc1): Linear(in_features=2592, out_features=512, bias=True)
#   (batchnorm4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1536, out_features=512, bias=True)
#   (batchnorm5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=512, out_features=1, bias=True)
#   (batchnorm6): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def visualise_sal_map(sal_map):

    # Convert the tensor to a numpy array (matplotlib works well with numpy arrays)
    map_np = sal_map.numpy()

    # Plot the tensor as an image
    plt.imshow(map_np, cmap='gray', interpolation='nearest')
    # plt.colorbar()  # Optional: add a colorbar to visualize the range of values
    plt.title('Saliency Map')
    plt.axis('off')  # Turn off axis ticks
    plt.show()

def visualise_triple(pred_sal_map, gt_sal_map, img):
    pred_map_np = pred_sal_map.numpy()
    gt_map_np = gt_sal_map.numpy()

    fig, axes = plt.subplots(1, 3, figsize=(18, 6))

    # Plot the tensor as an image
    axes[0].imshow(pred_map_np, cmap='gray', interpolation='nearest')
    axes[1].imshow(gt_map_np, cmap='gray', interpolation='nearest')
    axes[2].imshow(img)
    # plt.colorbar()  # Optional: add a colorbar to visualize the range of values
    axes[0].set_title('Prediction')
    axes[1].set_title('GT')
    axes[2].set_title('Image')
    axes[0].axis('off')  # Turn off axis ticks
    axes[1].axis('off')  # Turn off axis ticks
    axes[2].axis('off')  # Turn off axis ticks
    plt.tight_layout()  # Adjust layout for better spacing
    plt.show()

# %%
def get_preds_dict(model, dataMIT, device):
    
    model.eval()

    dataset_size = len(dataMIT.dataset)

    batch_size = 50
    num_batches = int(2500 / batch_size)

    preds_dict = {}

    sigmoid = nn.Sigmoid()

    for i in range (dataset_size):

        # potential bug: getting height and width mixed up, so if results look bad, make sure to check this is right

        formatted_filename = format_file_name_fixMap_jpg(dataMIT.dataset[i]['file'])
        height = dataMIT.dataset[i]['X'].shape[1]
        width = dataMIT.dataset[i]['X'].shape[2]

        rescale_to_img = transforms.Resize((height, width))

        img_crops = torch.stack([dataMIT.__getitem__(i * 2500 + j)[0] for j in range(2500)])

        preds_rows = []

        for j in range(num_batches):
            
            batch = img_crops[j * batch_size:(j * batch_size) + batch_size,:,:,:,:]

            batch = batch.to(device)

            preds = sigmoid(model(batch).detach().cpu().reshape(1, 50))
            preds_rows.append(preds)


        sal_map = torch.cat(preds_rows, 0) * 255

        sal_map = rescale_to_img(sal_map.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)    # unsqueezing and squeezing done because transforms.Resize requires (., ., H, W) shape tensor

        preds_dict[formatted_filename] = sal_map

    return preds_dict

# %%
val_preds_dict = get_preds_dict(trained_model, valdata, DEVICE)

# %%
test_preds_dict = get_preds_dict(trained_model, testingdata, DEVICE)
model_test_auc = calculate_auc(test_preds_dict, test_ground_truth_dict)
print(model_test_auc)
# Out:
# 0.8450883129583484

# %%
test_preds_dict1 = get_preds_dict(trained_model1, testingdata, DEVICE)
test_preds_dict2 = get_preds_dict(trained_model2, testingdata, DEVICE)

# %%
test_preds_dict2 = get_preds_dict(trained_model2, testingdata, DEVICE)

# %%
test_preds_dict3 = get_preds_dict(trained_model3, testingdata, DEVICE)
test_preds_dict4 = get_preds_dict(trained_model4, testingdata, DEVICE)

# %%
def get_sal_maps(i, preds_dict, ground_truth_dict):
    file_name = list(preds_dict.keys())[i]

    for img_dict in testingdata.dataset:
        if img_dict['file'] == f"{file_name[:-11]}.jpeg":
            return preds_dict[file_name], ground_truth_dict[file_name], img_dict['X']

    # return preds_dict[file_name], ground_truth_dict[file_name], img

# %%
testingdata.dataset[0]['file']
# Out:
# 'i1182505554.jpeg'

# %%
test_preds_dict.keys()
# Out:
# dict_keys(['i1182505554_fixMap.jpg', 'i110996888_fixMap.jpg', 'i2168982172_fixMap.jpg', 'i10feb04_static_techsquare_img_0873_fixMap.jpg', 'i1560309298_fixMap.jpg', 'i2133522539_fixMap.jpg', 'i1425519942_fixMap.jpg', 'istatic_outdoor_road_mallorca_spain_IMG_0540_fixMap.jpg', 'i1163341362_fixMap.jpg', 'i2125430605_fixMap.jpg', 'i1064228254_fixMap.jpg', 'i1247865242_fixMap.jpg', 'i2197089389_fixMap.jpg', 'i1022085609_fixMap.jpg', 'i2289350187_fixMap.jpg', 'i19023164_fixMap.jpg', 'i111369435_fixMap.jpg', 'i2244445589_fixMap.jpg', 'i2260404605_fixMap.jpg', 'i2051249439_fixMap.jpg', 'i2078195666_fixMap.jpg', 'i1799873859_fixMap.jpg', 'i1394080896_fixMap.jpg', 'i206881209_fixMap.jpg', 'i1486171792_fixMap.jpg', 'imadrid_static_street_p9110480_fixMap.jpg', 'i1425518494_fixMap.jpg', 'i2285904669_fixMap.jpg', 'i201161868_fixMap.jpg', 'i1526935589_fixMap.jpg', 'i182708511_fixMap.jpg', 'i2117655611_fixMap.jpg', 'istatic_houses_boston_2005_IMG_3629_fixMap.jpg', 'i2291139547_fixMap.jpg', 'istatic_barcelona_street_city_outdoor_2_2005_dsc04417_fixMap.jpg', 'i1343103601_fixMap.jpg', 'syntheticData1_fixMap.jpg', 'i2271918453_fixMap.jpg', 'i1818663426_fixMap.jpg', 'i2205555719_fixMap.jpg', 'i2145575787_fixMap.jpg', 'istatic_barcelona_street_city_outdoor_2_2005_img_0625_fixMap.jpg', 'i1583042749_fixMap.jpg', 'i111366726_fixMap.jpg', 'i2285475491_fixMap.jpg', 'i2158540867_fixMap.jpg', 'istatic_submitted_saxena_chung_ng_nips2005_learningdepth_img_gatesback2_p_15t0_fixMap.jpg', 'i114124777_fixMap.jpg', 'i2305300253_fixMap.jpg', 'i2130718051_fixMap.jpg', 'i1166229983_fixMap.jpg', 'istatic_houses_boston_2005_IMG_4024_fixMap.jpg', 'i2285970199_fixMap.jpg', 'i2279208009_fixMap.jpg', 'i1164346942_fixMap.jpg', 'i2275159166_fixMap.jpg', 'i2274292178_fixMap.jpg', 'i2312211495_fixMap.jpg', 'i1061875704_fixMap.jpg', 'i1131124824_fixMap.jpg', 'i1246347137_fixMap.jpg', 'i1918259724_fixMap.jpg', 'i2214763761_fixMap.jpg', 'i111373642_fixMap.jpg', 'i1040585936_fixMap.jpg', 'i436895919_fixMap.jpg', 'i2190576311_fixMap.jpg', 'i1065019259_fixMap.jpg', 'i245864757_fixMap.jpg', 'i2197862712_fixMap.jpg', 'i2141160962_fixMap.jpg', 'i30may05_static_street_cambridge_p1010735_fixMap.jpg', 'i2067603576_fixMap.jpg', 'i2274770415_fixMap.jpg', 'i1865602483_fixMap.jpg', 'i1492679408_fixMap.jpg', 'i207806307_fixMap.jpg', 'istatic_street_outdoor_palma_mallorca_spain_IMG_0459_fixMap.jpg', 'i1843338577_fixMap.jpg', 'i1158903665_fixMap.jpg', 'i2294701937_fixMap.jpg', 'i1426163477_fixMap.jpg', 'i2286258230_fixMap.jpg', 'i1143924367_fixMap.jpg', 'i2206349266_fixMap.jpg', 'i2265201355_fixMap.jpg', 'i1276571229_fixMap.jpg', 'i2238758189_fixMap.jpg', 'istatic_barcelona_street_city_outdoor_2_2005_dsc04121_fixMap.jpg', 'i2238477160_fixMap.jpg', 'i2257330951_fixMap.jpg', 'i126605331_fixMap.jpg', 'i2069913521_fixMap.jpg', 'i2294898365_fixMap.jpg', 'i2309997405_fixMap.jpg', 'i1473135008_fixMap.jpg', 'i2171576731_fixMap.jpg', 'i2172660077_fixMap.jpg', 'i2300299195_fixMap.jpg', 'i2301233235_fixMap.jpg'])

# %%
j = 0

# %%
j += 1

# %%
for j in [85, 63, 15]:

    pred_sal_map, gt_sal_map, img = get_sal_maps(j, test_preds_dict3, test_ground_truth_dict)

    # visualise_sal_map(pred_sal_map)
    # visualise_sal_map(gt_sal_map)

    img = img.permute(1, 2, 0).numpy()
    visualise_triple(pred_sal_map, gt_sal_map, img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
